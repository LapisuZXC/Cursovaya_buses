# %%
import random
import numpy as np
import time
from datetime import timedelta, datetime


class BusStop:
    def __init__(self, passengers_waiting: int):
        self.passengers_waiting = passengers_waiting

    def board_passengers(self, available_seats: int) -> int:
        board_count = min(self.passengers_waiting, available_seats)
        self.passengers_waiting -= board_count
        return board_count

    def add_passengers(self, peak: bool):
        chance = random.random()
        if peak:
            if chance < 0.7:  
                self.passengers_waiting += random.randint(3, 7)
        else:
            if chance < 0.3:  
                self.passengers_waiting += random.randint(1, 3)

class Route:
    def __init__(self, bus_stops_num: int, route_duration: int, peak: bool, upper_limit: int):
        self.num_stops = bus_stops_num
        self.time_between_stops = route_duration // bus_stops_num  
        self.bus_stops = [
            BusStop(random.randint(0, int(upper_limit * (0.7 if peak else 0.3))))
            for _ in range(bus_stops_num)
        ]
class Driver:
    def __init__(self, name: str, shift_duration: int, break_duration: int, schedule_type: str):
        self.name = name
        self.shift_duration = shift_duration
        self.break_duration = break_duration
        self.schedule_type = schedule_type  
        self.time_worked = 0
        self.on_break = False
        self.break_time_remaining = 0

    def work(self, is_peak: bool = False):
        if self.on_break:
            self.break_time_remaining -= 1
            if self.break_time_remaining <= 0:
                self.on_break = False
            return False

        self.time_worked += 1

        if self.schedule_type == "standard":
            if self.time_worked >= self.shift_duration:
                self.start_break()
        elif self.schedule_type == "night":
            if self.time_worked % 120 == 0 and not is_peak: 
                self.start_break()
        return True

    def start_break(self):
        self.on_break = True
        self.break_time_remaining = self.break_duration
        self.time_worked = 0 if self.schedule_type == "standard" else self.time_worked  
class Bus:
    def __init__(self, capacity: int = 20, driver: Driver = None):
        self.capacity = capacity
        self.currently_onboard = 0
        self.driver = driver

    def load_passengers(self, bus_stop):
        if self.driver and not self.driver.work():
            #print(f"Driver {self.driver.name} is on break. Bus cannot load passengers.")
            return 0

        available_seats = self.capacity - self.currently_onboard
        boarding_passengers = bus_stop.board_passengers(available_seats=available_seats)
        self.currently_onboard += boarding_passengers
        return boarding_passengers

    def unload_all_passengers(self):
        exiting_passengers = self.currently_onboard
        self.currently_onboard = 0
        return exiting_passengers
class Simulation:
    def __init__(
        self,
        bus_num: int,
        route_duration: int,
        bus_stops_num: int,
        start_time: np.datetime64,
        end_time: np.datetime64,
        tag: str,
        driver_schedule_type: str,
        driver_shift_duration: int,
        driver_break_duration: int,
        driver_num: int,
    ):
        self.tag = tag
        self.tick = 0
        self.route = Route(bus_stops_num, route_duration, tag in {"monday", "tuesday", "wednesday", "thursday", "friday"}, 100)
        self.time_between_stops = self.route.time_between_stops
        self.end_tick = ((end_time - start_time).astype("timedelta64[m]").item().seconds // self.time_between_stops)
        self.drivers = [
            Driver(
                name=f"Driver {i}",
                shift_duration=driver_shift_duration,
                break_duration=driver_break_duration,
                schedule_type=driver_schedule_type,
            )
            for i in range(driver_num)
        ]
        self.buses = [Bus(driver=self.drivers[i]) for i in range(bus_num)]
        self.bus_positions = [0 for _ in range(bus_num)]
        self.bus_intervals = route_duration // bus_num
        self.start_time = start_time

        self.schedule = {i: [] for i in range(self.route.num_stops)}
        self.bus_start_ticks = [i * self.bus_intervals for i in range(bus_num)]

    def play_simulation(self):
        total_passengers_dropped = 0
        while self.tick < self.end_tick:
            current_time_in_seconds = int((self.start_time + np.timedelta64(self.tick * self.time_between_stops, 'm')).astype("timedelta64[s]").item().seconds % 86400)
            current_hour = current_time_in_seconds // 3600
            is_peak = (7 <= current_hour < 9) or (17 <= current_hour < 19)

            for stop in self.route.bus_stops:
                stop.add_passengers(peak=is_peak if self.tag not in {"saturday", "sunday"} else random.random() < 0.5)

            for i, bus in enumerate(self.buses):
                if self.tick < self.bus_start_ticks[i]:
                    continue

                stop_index = self.bus_positions[i]
                current_time = self.start_time + np.timedelta64(self.tick * self.time_between_stops, 'm')
                self.schedule[stop_index].append(str(current_time))

                if stop_index == len(self.route.bus_stops) - 1:
                    total_passengers_dropped += bus.unload_all_passengers()

                if not bus.driver.work(is_peak):
                    continue

                boarding = bus.load_passengers(self.route.bus_stops[stop_index])
                self.bus_positions[i] = (stop_index + 1) % self.route.num_stops

            self.tick += 1

        remaining_passengers = sum(stop.passengers_waiting for stop in self.route.bus_stops)
        print(f"Simulation finished. Total passengers dropped: {total_passengers_dropped}. Remaining passengers: {remaining_passengers}.")

    def print_schedule(self):
        print("\nBus Schedule:")
        for stop, times in self.schedule.items():
            print(f"Stop {stop}: {', '.join(times)}")

def simulate_with_parameters(bus_num, driver_num, driver_schedule_type, route_duration, bus_stops_num, start_time, end_time, driver_shift_duration, driver_break_duration):
    if driver_num < bus_num: 
        return float("inf") 
    sim = Simulation(
        bus_num=bus_num,
        route_duration=route_duration,
        bus_stops_num=bus_stops_num,
        start_time=start_time,
        end_time=end_time,
        tag="monday",  # Use weekday for peak load
        driver_schedule_type=driver_schedule_type,
        driver_shift_duration=driver_shift_duration,
        driver_break_duration=driver_break_duration,
        driver_num=driver_num
    )
    sim.play_simulation()

    remaining_passengers = sum(stop.passengers_waiting for stop in sim.route.bus_stops)
    return remaining_passengers

def brute_force_optimization(route_duration, bus_stops_num, start_time, end_time, driver_shift_duration, driver_break_duration):
    best_bus_num = None
    best_driver_num = None
    min_remaining_passengers = float("inf")
    start_time_exec = time.time()

    with open("brute_force_results.txt", "w") as f, open("best_results_brute_force.txt", "w") as best_f:
        for bus_num in range(8, 21):
            for driver_num in range(bus_num, 21):  # Ensure drivers >= buses
                for schedule_type in ["standard", "night"]:
                    remaining_passengers = simulate_with_parameters(
                        bus_num=bus_num,
                        driver_num=driver_num,
                        driver_schedule_type=schedule_type,
                        route_duration=route_duration,
                        bus_stops_num=bus_stops_num,
                        start_time=start_time,
                        end_time=end_time,
                        driver_shift_duration=driver_shift_duration,
                        driver_break_duration=driver_break_duration,
                    )

                    if remaining_passengers < min_remaining_passengers:
                        best_bus_num = bus_num
                        best_driver_num = driver_num
                        min_remaining_passengers = remaining_passengers

                    f.write(f"Buses: {bus_num}, Drivers: {driver_num}, Type: {schedule_type}, Remaining: {remaining_passengers}\n")

        exec_time = time.time() - start_time_exec
        best_f.write(f"Best Buses: {best_bus_num}, Best Drivers: {best_driver_num}, Execution Time: {exec_time:.2f} seconds\n")
    return best_bus_num, best_driver_num

def genetic_algorithm_optimization(
    route_duration, 
    bus_stops_num, 
    start_time, 
    end_time, 
    driver_shift_duration, 
    driver_break_duration,
    population_size=10, 
    generations=50, 
    patience=10, 
    log_file="genetic_algorithm_log.txt",
):
    start_time_exec = time.time()

    population = [
        {
            "bus_num": random.randint(bus_stops_num, 20),
            "driver_num": random.randint(bus_stops_num, 20),
            "schedule_type": random.choice(["standard", "night"]),
        }
        for _ in range(population_size)
    ]

    best_solution = None
    best_fitness = float("inf")
    generations_without_improvement = 0

    with open(log_file, "w") as log, open("best_results_genetic_algorithm.txt", "w") as best_f:
        log.write("Generation,Bus_Num,Driver_Num,Schedule_Type,Remaining_Passengers\n")

        for generation in range(generations):
            fitness_scores = []
            for individual in population:
                if individual["driver_num"] < individual["bus_num"]:  # Ensure drivers >= buses
                    fitness_scores.append((individual, float("inf")))
                    continue

                remaining_passengers = simulate_with_parameters(
                    bus_num=individual["bus_num"],
                    driver_num=individual["driver_num"],
                    driver_schedule_type=individual["schedule_type"],
                    route_duration=route_duration,
                    bus_stops_num=bus_stops_num,
                    start_time=start_time,
                    end_time=end_time,
                    driver_shift_duration=driver_shift_duration,
                    driver_break_duration=driver_break_duration,
                )

                fitness_scores.append((individual, remaining_passengers))

                if remaining_passengers < best_fitness:
                    best_solution = individual
                    best_fitness = remaining_passengers
                    generations_without_improvement = 0

            fitness_scores.sort(key=lambda x: x[1])

            top_individuals = [fs[0] for fs in fitness_scores[: population_size // 2]]

            new_population = []
            for _ in range(population_size):
                parent1, parent2 = random.sample(top_individuals, 2)
                child = {
                    "bus_num": max(1, (parent1["bus_num"] + parent2["bus_num"]) // 2),
                    "driver_num": max(parent1["bus_num"], (parent1["driver_num"] + parent2["driver_num"]) // 2),
                    "schedule_type": random.choice([parent1["schedule_type"], parent2["schedule_type"]]),
                }

                if random.random() < 0.1:
                    child["bus_num"] = max(1, min(20, child["bus_num"] + random.choice([-1, 1])))
                    child["driver_num"] = max(child["bus_num"], min(20, child["driver_num"] + random.choice([-1, 1])))

                new_population.append(child)

            population = new_population
            generations_without_improvement += 1

            if generations_without_improvement >= patience:
                break

        exec_time = time.time() - start_time_exec
        best_f.write(f"Best Solution: {best_solution}, Execution Time: {exec_time:.2f} seconds\n")

    return best_solution

route_duration = 70
bus_stops_num = 7
start_time = np.datetime64('2024-12-14T06:00')
end_time = np.datetime64('2024-12-15T03:00')
driver_shift_duration = 420
driver_break_duration = 60

best_bus_num, best_driver_num = brute_force_optimization(
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
)
print(f"Best configuration from brute force: Buses = {best_bus_num}, Drivers = {best_driver_num}")

best_solution = genetic_algorithm_optimization(
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
)
print(f"Best configuration from genetic algorithm: {best_solution}")
# Out:
# Simulation finished. Total passengers dropped: 58387. Remaining passengers: 2858.
# Simulation finished. Total passengers dropped: 51972. Remaining passengers: 8299.
# Simulation finished. Total passengers dropped: 58269. Remaining passengers: 2470.
# Simulation finished. Total passengers dropped: 52802. Remaining passengers: 8436.
# Simulation finished. Total passengers dropped: 58664. Remaining passengers: 2829.
# Simulation finished. Total passengers dropped: 53045. Remaining passengers: 7990.
# Simulation finished. Total passengers dropped: 58398. Remaining passengers: 2416.
# Simulation finished. Total passengers dropped: 53201. Remaining passengers: 8107.
# Simulation finished. Total passengers dropped: 58837. Remaining passengers: 2776.
# Simulation finished. Total passengers dropped: 53085. Remaining passengers: 8270.
# Simulation finished. Total passengers dropped: 58391. Remaining passengers: 2611.
# Simulation finished. Total passengers dropped: 53221. Remaining passengers: 8071.
# Simulation finished. Total passengers dropped: 58142. Remaining passengers: 2834.
# Simulation finished. Total passengers dropped: 53011. Remaining passengers: 7858.
# Simulation finished. Total passengers dropped: 58277. Remaining passengers: 2980.
# Simulation finished. Total passengers dropped: 53550. Remaining passengers: 7949.
# Simulation finished. Total passengers dropped: 57898. Remaining passengers: 2704.
# Simulation finished. Total passengers dropped: 53061. Remaining passengers: 8389.
# Simulation finished. Total passengers dropped: 58490. Remaining passengers: 2954.
# Simulation finished. Total passengers dropped: 53121. Remaining passengers: 8075.
# Simulation finished. Total passengers dropped: 58991. Remaining passengers: 2627.
# Simulation finished. Total passengers dropped: 53607. Remaining passengers: 8041.
# Simulation finished. Total passengers dropped: 58422. Remaining passengers: 2458.
# Simulation finished. Total passengers dropped: 52871. Remaining passengers: 8112.
# Simulation finished. Total passengers dropped: 58340. Remaining passengers: 2861.
# Simulation finished. Total passengers dropped: 53366. Remaining passengers: 8003.
# Simulation finished. Total passengers dropped: 60432. Remaining passengers: 998.
# Simulation finished. Total passengers dropped: 54716. Remaining passengers: 6685.
# Simulation finished. Total passengers dropped: 59994. Remaining passengers: 724.
# Simulation finished. Total passengers dropped: 54542. Remaining passengers: 6734.
# Simulation finished. Total passengers dropped: 60452. Remaining passengers: 819.
# Simulation finished. Total passengers dropped: 54076. Remaining passengers: 6997.
# Simulation finished. Total passengers dropped: 60203. Remaining passengers: 736.
# Simulation finished. Total passengers dropped: 54314. Remaining passengers: 7079.
# Simulation finished. Total passengers dropped: 60450. Remaining passengers: 820.
# Simulation finished. Total passengers dropped: 54451. Remaining passengers: 6940.
# Simulation finished. Total passengers dropped: 60735. Remaining passengers: 741.
# Simulation finished. Total passengers dropped: 54060. Remaining passengers: 6908.
# Simulation finished. Total passengers dropped: 60277. Remaining passengers: 599.
# Simulation finished. Total passengers dropped: 54082. Remaining passengers: 7076.
# Simulation finished. Total passengers dropped: 61040. Remaining passengers: 723.
# Simulation finished. Total passengers dropped: 54071. Remaining passengers: 6724.
# Simulation finished. Total passengers dropped: 60655. Remaining passengers: 848.
# Simulation finished. Total passengers dropped: 53916. Remaining passengers: 6987.
# Simulation finished. Total passengers dropped: 60126. Remaining passengers: 805.
# Simulation finished. Total passengers dropped: 54283. Remaining passengers: 6719.
# Simulation finished. Total passengers dropped: 60411. Remaining passengers: 813.
# Simulation finished. Total passengers dropped: 54609. Remaining passengers: 7026.
# Simulation finished. Total passengers dropped: 60659. Remaining passengers: 1010.
# Simulation finished. Total passengers dropped: 54642. Remaining passengers: 6977.
# Simulation finished. Total passengers dropped: 60911. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 55858. Remaining passengers: 5591.
# Simulation finished. Total passengers dropped: 61015. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 55658. Remaining passengers: 5663.
# Simulation finished. Total passengers dropped: 61367. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 55302. Remaining passengers: 5685.
# Simulation finished. Total passengers dropped: 60821. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 55375. Remaining passengers: 5594.
# Simulation finished. Total passengers dropped: 60412. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 55518. Remaining passengers: 5155.
# Simulation finished. Total passengers dropped: 61380. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 55595. Remaining passengers: 6212.
# Simulation finished. Total passengers dropped: 61055. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 55797. Remaining passengers: 5533.
# Simulation finished. Total passengers dropped: 61974. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 55711. Remaining passengers: 5330.
# Simulation finished. Total passengers dropped: 61556. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 55324. Remaining passengers: 6103.
# Simulation finished. Total passengers dropped: 61865. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 55374. Remaining passengers: 5712.
# Simulation finished. Total passengers dropped: 61019. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 55287. Remaining passengers: 5681.
# Simulation finished. Total passengers dropped: 61652. Remaining passengers: 24.
# Simulation finished. Total passengers dropped: 57098. Remaining passengers: 4286.
# Simulation finished. Total passengers dropped: 61167. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 56970. Remaining passengers: 4227.
# Simulation finished. Total passengers dropped: 61023. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 57087. Remaining passengers: 4367.
# Simulation finished. Total passengers dropped: 60772. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 57135. Remaining passengers: 4381.
# Simulation finished. Total passengers dropped: 61455. Remaining passengers: 31.
# Simulation finished. Total passengers dropped: 56626. Remaining passengers: 4403.
# Simulation finished. Total passengers dropped: 60855. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 56743. Remaining passengers: 4404.
# Simulation finished. Total passengers dropped: 61225. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 57189. Remaining passengers: 4294.
# Simulation finished. Total passengers dropped: 61496. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 56709. Remaining passengers: 4075.
# Simulation finished. Total passengers dropped: 60837. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 56833. Remaining passengers: 4302.
# Simulation finished. Total passengers dropped: 61275. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 57214. Remaining passengers: 4371.
# Simulation finished. Total passengers dropped: 61494. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 58235. Remaining passengers: 3091.
# Simulation finished. Total passengers dropped: 61363. Remaining passengers: 36.
# Simulation finished. Total passengers dropped: 57793. Remaining passengers: 3367.
# Simulation finished. Total passengers dropped: 61375. Remaining passengers: 38.
# Simulation finished. Total passengers dropped: 58253. Remaining passengers: 3352.
# Simulation finished. Total passengers dropped: 61195. Remaining passengers: 50.
# Simulation finished. Total passengers dropped: 58504. Remaining passengers: 3344.
# Simulation finished. Total passengers dropped: 61007. Remaining passengers: 38.
# Simulation finished. Total passengers dropped: 58692. Remaining passengers: 3131.
# Simulation finished. Total passengers dropped: 60745. Remaining passengers: 23.
# Simulation finished. Total passengers dropped: 58017. Remaining passengers: 3283.
# Simulation finished. Total passengers dropped: 60992. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 57443. Remaining passengers: 2859.
# Simulation finished. Total passengers dropped: 60858. Remaining passengers: 43.
# Simulation finished. Total passengers dropped: 57639. Remaining passengers: 3356.
# Simulation finished. Total passengers dropped: 61403. Remaining passengers: 31.
# Simulation finished. Total passengers dropped: 58262. Remaining passengers: 3208.
# Simulation finished. Total passengers dropped: 61443. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 59311. Remaining passengers: 1915.
# Simulation finished. Total passengers dropped: 61534. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 59435. Remaining passengers: 1819.
# Simulation finished. Total passengers dropped: 61040. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 59341. Remaining passengers: 1660.
# Simulation finished. Total passengers dropped: 60908. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 59327. Remaining passengers: 1842.
# Simulation finished. Total passengers dropped: 61122. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 58972. Remaining passengers: 1672.
# Simulation finished. Total passengers dropped: 61318. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 59844. Remaining passengers: 1947.
# Simulation finished. Total passengers dropped: 60780. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 59636. Remaining passengers: 1765.
# Simulation finished. Total passengers dropped: 61209. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 59470. Remaining passengers: 2017.
# Simulation finished. Total passengers dropped: 61061. Remaining passengers: 4.
# Simulation finished. Total passengers dropped: 60621. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 60831. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60465. Remaining passengers: 682.
# Simulation finished. Total passengers dropped: 60326. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 61145. Remaining passengers: 557.
# Simulation finished. Total passengers dropped: 61791. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60728. Remaining passengers: 398.
# Simulation finished. Total passengers dropped: 61167. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 60506. Remaining passengers: 374.
# Simulation finished. Total passengers dropped: 61211. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60732. Remaining passengers: 408.
# Simulation finished. Total passengers dropped: 61216. Remaining passengers: 7.
# Simulation finished. Total passengers dropped: 60293. Remaining passengers: 416.
# Simulation finished. Total passengers dropped: 61624. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 60578. Remaining passengers: 28.
# Simulation finished. Total passengers dropped: 61025. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 61046. Remaining passengers: 35.
# Simulation finished. Total passengers dropped: 61087. Remaining passengers: 30.
# Simulation finished. Total passengers dropped: 61078. Remaining passengers: 23.
# Simulation finished. Total passengers dropped: 61400. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 60831. Remaining passengers: 44.
# Simulation finished. Total passengers dropped: 60957. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 61324. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 60539. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 60924. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61014. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61045. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60797. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 61119. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61519. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61074. Remaining passengers: 4.
# Simulation finished. Total passengers dropped: 61266. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61832. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61337. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61685. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60932. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61821. Remaining passengers: 2.
# Simulation finished. Total passengers dropped: 61215. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60702. Remaining passengers: 4.
# Simulation finished. Total passengers dropped: 61525. Remaining passengers: 3.
# Simulation finished. Total passengers dropped: 61472. Remaining passengers: 3.
# Simulation finished. Total passengers dropped: 61587. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61505. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61829. Remaining passengers: 38.
# Simulation finished. Total passengers dropped: 61532. Remaining passengers: 47.
# Simulation finished. Total passengers dropped: 61533. Remaining passengers: 50.
# Simulation finished. Total passengers dropped: 61504. Remaining passengers: 61.
# Simulation finished. Total passengers dropped: 61758. Remaining passengers: 40.
# Simulation finished. Total passengers dropped: 61197. Remaining passengers: 53.
# Simulation finished. Total passengers dropped: 60822. Remaining passengers: 28.
# Simulation finished. Total passengers dropped: 61272. Remaining passengers: 39.
# Simulation finished. Total passengers dropped: 61340. Remaining passengers: 35.
# Simulation finished. Total passengers dropped: 61422. Remaining passengers: 24.
# Simulation finished. Total passengers dropped: 61371. Remaining passengers: 29.
# Simulation finished. Total passengers dropped: 60963. Remaining passengers: 26.
# Best configuration from brute force: Buses = 17, Drivers = 17
# Simulation finished. Total passengers dropped: 33226. Remaining passengers: 28228.
# Simulation finished. Total passengers dropped: 61140. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 52223. Remaining passengers: 8607.
# Simulation finished. Total passengers dropped: 60845. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 50493. Remaining passengers: 10510.
# Simulation finished. Total passengers dropped: 52121. Remaining passengers: 9419.
# Simulation finished. Total passengers dropped: 58034. Remaining passengers: 3093.
# Simulation finished. Total passengers dropped: 56674. Remaining passengers: 4441.
# Simulation finished. Total passengers dropped: 58196. Remaining passengers: 2755.
# Simulation finished. Total passengers dropped: 54506. Remaining passengers: 6849.
# Simulation finished. Total passengers dropped: 56709. Remaining passengers: 4271.
# Simulation finished. Total passengers dropped: 58887. Remaining passengers: 2493.
# Simulation finished. Total passengers dropped: 61254. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61747. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 61226. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 57023. Remaining passengers: 4444.
# Simulation finished. Total passengers dropped: 61323. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60639. Remaining passengers: 869.
# Simulation finished. Total passengers dropped: 58562. Remaining passengers: 2833.
# Simulation finished. Total passengers dropped: 61768. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61425. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 61629. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60492. Remaining passengers: 612.
# Simulation finished. Total passengers dropped: 60302. Remaining passengers: 854.
# Simulation finished. Total passengers dropped: 60240. Remaining passengers: 792.
# Simulation finished. Total passengers dropped: 61250. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61329. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61003. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61245. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 60996. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61375. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61444. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 61290. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61216. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 60642. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61202. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 60989. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61131. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61372. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 61213. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61050. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61531. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60875. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61509. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 60570. Remaining passengers: 792.
# Simulation finished. Total passengers dropped: 61624. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 60230. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61435. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61107. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60999. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 60178. Remaining passengers: 994.
# Simulation finished. Total passengers dropped: 61507. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61583. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 61310. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 60657. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 61116. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 61012. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 60951. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61188. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 61230. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 60876. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 61144. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 61184. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60995. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61071. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 60584. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 61778. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 60936. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61477. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 61495. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61345. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 61090. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 60689. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61024. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60843. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61400. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61551. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61259. Remaining passengers: 7.
# Simulation finished. Total passengers dropped: 60708. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 60836. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61103. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 60815. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61098. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61310. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 60496. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60976. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61044. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61472. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61024. Remaining passengers: 23.
# Simulation finished. Total passengers dropped: 61186. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61446. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61056. Remaining passengers: 28.
# Simulation finished. Total passengers dropped: 61243. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61116. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 60790. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61465. Remaining passengers: 13.
# Best configuration from genetic algorithm: {'bus_num': 10, 'driver_num': 11, 'schedule_type': 'standard'}

# %%
def simulate_week_with_parameters(bus_num, driver_num, driver_schedule_type, route_duration, bus_stops_num, start_time, end_time, driver_shift_duration, driver_break_duration):
    days = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]
    total_remaining_passengers = 0  # Суммируем оставшихся пассажиров за неделю

    for day in days:
        sim = Simulation(
            bus_num=bus_num,
            route_duration=route_duration,
            bus_stops_num=bus_stops_num,
            start_time=start_time,
            end_time=end_time,
            tag=day,
            driver_schedule_type=driver_schedule_type,
            driver_shift_duration=driver_shift_duration,
            driver_break_duration=driver_break_duration,
            driver_num=driver_num
        )
        sim.play_simulation()
        total_remaining_passengers += sum(stop.passengers_waiting for stop in sim.route.bus_stops)

    return total_remaining_passengers

def brute_force_optimization(route_duration, bus_stops_num, start_time, end_time, driver_shift_duration, driver_break_duration):
    best_bus_num = None
    best_driver_num = None
    best_schedule_type = None
    min_remaining_passengers = float("inf")
    start_time_exec = time.time()

    with open("brute_force_weekly_results.txt", "w") as f, open("best_results_brute_force_weekly.txt", "w") as best_f:
        for bus_num in range(8, 21):
            for driver_num in range(bus_num, 21):  # Ensure drivers >= buses
                for schedule_type in ["standard", "night"]:
                    remaining_passengers = simulate_week_with_parameters(
                        bus_num=bus_num,
                        driver_num=driver_num,
                        driver_schedule_type=schedule_type,
                        route_duration=route_duration,
                        bus_stops_num=bus_stops_num,
                        start_time=start_time,
                        end_time=end_time,
                        driver_shift_duration=driver_shift_duration,
                        driver_break_duration=driver_break_duration,
                    )

                    if remaining_passengers < min_remaining_passengers:
                        best_bus_num = bus_num
                        best_driver_num = driver_num
                        best_schedule_type = schedule_type
                        min_remaining_passengers = remaining_passengers

                    f.write(f"Buses: {bus_num}, Drivers: {driver_num}, Type: {schedule_type}, Remaining: {remaining_passengers}\n")

        exec_time = time.time() - start_time_exec
        best_f.write(f"Best Buses: {best_bus_num}, Best Drivers: {best_driver_num}, Type: {best_schedule_type}, Execution Time: {exec_time:.2f} seconds\n")
    return best_bus_num, best_driver_num, best_schedule_type

def genetic_algorithm_optimization(
    route_duration, 
    bus_stops_num, 
    start_time, 
    end_time, 
    driver_shift_duration, 
    driver_break_duration, 
    population_size=10, 
    generations=50, 
    patience=10, 
    log_file="genetic_algorithm_weekly_log.txt"
):
    start_time_exec = time.time()

    population = [
        {
            "bus_num": random.randint(1, 20),
            "driver_num": random.randint(1, 20),
            "schedule_type": random.choice(["standard", "night"]),
        }
        for _ in range(population_size)
    ]

    best_solution = None
    best_fitness = float("inf")
    generations_without_improvement = 0

    with open(log_file, "w") as log, open("best_results_genetic_algorithm_weekly.txt", "w") as best_f:
        log.write("Generation,Bus_Num,Driver_Num,Schedule_Type,Remaining_Passengers\n")

        for generation in range(generations):
            fitness_scores = []
            for individual in population:
                if individual["driver_num"] < individual["bus_num"]:  # Ensure drivers >= buses
                    fitness_scores.append((individual, float("inf")))
                    continue

                remaining_passengers = simulate_week_with_parameters(
                    bus_num=individual["bus_num"],
                    driver_num=individual["driver_num"],
                    driver_schedule_type=individual["schedule_type"],
                    route_duration=route_duration,
                    bus_stops_num=bus_stops_num,
                    start_time=start_time,
                    end_time=end_time,
                    driver_shift_duration=driver_shift_duration,
                    driver_break_duration=driver_break_duration,
                )

                fitness_scores.append((individual, remaining_passengers))

                if remaining_passengers < best_fitness:
                    best_solution = individual
                    best_fitness = remaining_passengers
                    generations_without_improvement = 0

            fitness_scores.sort(key=lambda x: x[1])

            top_individuals = [fs[0] for fs in fitness_scores[: population_size // 2]]

            new_population = []
            for _ in range(population_size):
                parent1, parent2 = random.sample(top_individuals, 2)
                child = {
                    "bus_num": max(1, (parent1["bus_num"] + parent2["bus_num"]) // 2),
                    "driver_num": max(parent1["bus_num"], (parent1["driver_num"] + parent2["driver_num"]) // 2),
                    "schedule_type": random.choice([parent1["schedule_type"], parent2["schedule_type"]]),
                }

                if random.random() < 0.1:
                    child["bus_num"] = max(1, min(20, child["bus_num"] + random.choice([-1, 1])))
                    child["driver_num"] = max(child["bus_num"], min(20, child["driver_num"] + random.choice([-1, 1])))

                new_population.append(child)

            population = new_population
            generations_without_improvement += 1

            if generations_without_improvement >= patience:
                break

        exec_time = time.time() - start_time_exec
        best_f.write(f"Best Solution: {best_solution}, Execution Time: {exec_time:.2f} seconds\n")

    return best_solution

# %%
best_bus_num, best_driver_num, best_schedule_type = brute_force_optimization(
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
)

print(f"Лучший результат brute-force:")
print(f"Автобусы: {best_bus_num}, Водители: {best_driver_num}, Тип расписания: {best_schedule_type}")
best_solution = genetic_algorithm_optimization(
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
    population_size=10,  
    generations=50,  
    patience=10  
)

print(f"Лучший результат генетического алгоритма:")
print(best_solution)
simulation = Simulation(
    bus_num=best_solution["bus_num"],
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    driver_num=best_solution['driver_num'],
    end_time=end_time,
    tag="monday",  # Пример дня для анализа
    driver_schedule_type=best_solution["schedule_type"],
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
)

simulation.play_simulation()
simulation.print_schedule()
with open("results_summary.txt", "w") as f:
    f.write(f"Brute-force: Buses = {best_bus_num}, Drivers = {best_driver_num}, Schedule Type = {best_schedule_type}\n")
    f.write(f"Genetic Algorithm: {best_solution}\n")
# Out:
# Simulation finished. Total passengers dropped: 58315. Remaining passengers: 2714.
# Simulation finished. Total passengers dropped: 58335. Remaining passengers: 2415.
# Simulation finished. Total passengers dropped: 58425. Remaining passengers: 2974.
# Simulation finished. Total passengers dropped: 58453. Remaining passengers: 2591.
# Simulation finished. Total passengers dropped: 58307. Remaining passengers: 2927.
# Simulation finished. Total passengers dropped: 109206. Remaining passengers: 291.
# Simulation finished. Total passengers dropped: 108650. Remaining passengers: 332.
# Simulation finished. Total passengers dropped: 53441. Remaining passengers: 7998.
# Simulation finished. Total passengers dropped: 52583. Remaining passengers: 8064.
# Simulation finished. Total passengers dropped: 53317. Remaining passengers: 7914.
# Simulation finished. Total passengers dropped: 53220. Remaining passengers: 8313.
# Simulation finished. Total passengers dropped: 53178. Remaining passengers: 8638.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22954.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21404.
# Simulation finished. Total passengers dropped: 58524. Remaining passengers: 2705.
# Simulation finished. Total passengers dropped: 58700. Remaining passengers: 2679.
# Simulation finished. Total passengers dropped: 58932. Remaining passengers: 2816.
# Simulation finished. Total passengers dropped: 58679. Remaining passengers: 2283.
# Simulation finished. Total passengers dropped: 58698. Remaining passengers: 2371.
# Simulation finished. Total passengers dropped: 108464. Remaining passengers: 273.
# Simulation finished. Total passengers dropped: 108731. Remaining passengers: 312.
# Simulation finished. Total passengers dropped: 53234. Remaining passengers: 8293.
# Simulation finished. Total passengers dropped: 53321. Remaining passengers: 8117.
# Simulation finished. Total passengers dropped: 53420. Remaining passengers: 8200.
# Simulation finished. Total passengers dropped: 52988. Remaining passengers: 8198.
# Simulation finished. Total passengers dropped: 52963. Remaining passengers: 8140.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22427.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21745.
# Simulation finished. Total passengers dropped: 57840. Remaining passengers: 2313.
# Simulation finished. Total passengers dropped: 58437. Remaining passengers: 2589.
# Simulation finished. Total passengers dropped: 58891. Remaining passengers: 2599.
# Simulation finished. Total passengers dropped: 58249. Remaining passengers: 2717.
# Simulation finished. Total passengers dropped: 58351. Remaining passengers: 2569.
# Simulation finished. Total passengers dropped: 108547. Remaining passengers: 284.
# Simulation finished. Total passengers dropped: 108724. Remaining passengers: 273.
# Simulation finished. Total passengers dropped: 52709. Remaining passengers: 8237.
# Simulation finished. Total passengers dropped: 53197. Remaining passengers: 8366.
# Simulation finished. Total passengers dropped: 52446. Remaining passengers: 8346.
# Simulation finished. Total passengers dropped: 52893. Remaining passengers: 8336.
# Simulation finished. Total passengers dropped: 53069. Remaining passengers: 7671.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21911.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21879.
# Simulation finished. Total passengers dropped: 58310. Remaining passengers: 2601.
# Simulation finished. Total passengers dropped: 58022. Remaining passengers: 2810.
# Simulation finished. Total passengers dropped: 58474. Remaining passengers: 2890.
# Simulation finished. Total passengers dropped: 58459. Remaining passengers: 2764.
# Simulation finished. Total passengers dropped: 58526. Remaining passengers: 2471.
# Simulation finished. Total passengers dropped: 108719. Remaining passengers: 255.
# Simulation finished. Total passengers dropped: 108073. Remaining passengers: 302.
# Simulation finished. Total passengers dropped: 53048. Remaining passengers: 7985.
# Simulation finished. Total passengers dropped: 53170. Remaining passengers: 8195.
# Simulation finished. Total passengers dropped: 53126. Remaining passengers: 8098.
# Simulation finished. Total passengers dropped: 52891. Remaining passengers: 8024.
# Simulation finished. Total passengers dropped: 53023. Remaining passengers: 7706.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21893.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22045.
# Simulation finished. Total passengers dropped: 58529. Remaining passengers: 2791.
# Simulation finished. Total passengers dropped: 58225. Remaining passengers: 2825.
# Simulation finished. Total passengers dropped: 58447. Remaining passengers: 2773.
# Simulation finished. Total passengers dropped: 58627. Remaining passengers: 2651.
# Simulation finished. Total passengers dropped: 58850. Remaining passengers: 3053.
# Simulation finished. Total passengers dropped: 107142. Remaining passengers: 333.
# Simulation finished. Total passengers dropped: 107544. Remaining passengers: 261.
# Simulation finished. Total passengers dropped: 53133. Remaining passengers: 8167.
# Simulation finished. Total passengers dropped: 52807. Remaining passengers: 8549.
# Simulation finished. Total passengers dropped: 53051. Remaining passengers: 8179.
# Simulation finished. Total passengers dropped: 52954. Remaining passengers: 8323.
# Simulation finished. Total passengers dropped: 53176. Remaining passengers: 8462.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22710.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22015.
# Simulation finished. Total passengers dropped: 58510. Remaining passengers: 2648.
# Simulation finished. Total passengers dropped: 58191. Remaining passengers: 2789.
# Simulation finished. Total passengers dropped: 58574. Remaining passengers: 2685.
# Simulation finished. Total passengers dropped: 58495. Remaining passengers: 2394.
# Simulation finished. Total passengers dropped: 58687. Remaining passengers: 2732.
# Simulation finished. Total passengers dropped: 107287. Remaining passengers: 236.
# Simulation finished. Total passengers dropped: 108973. Remaining passengers: 221.
# Simulation finished. Total passengers dropped: 52735. Remaining passengers: 8541.
# Simulation finished. Total passengers dropped: 52675. Remaining passengers: 8305.
# Simulation finished. Total passengers dropped: 53218. Remaining passengers: 7989.
# Simulation finished. Total passengers dropped: 52914. Remaining passengers: 8129.
# Simulation finished. Total passengers dropped: 52368. Remaining passengers: 8111.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22496.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21653.
# Simulation finished. Total passengers dropped: 58945. Remaining passengers: 2576.
# Simulation finished. Total passengers dropped: 58804. Remaining passengers: 2382.
# Simulation finished. Total passengers dropped: 58490. Remaining passengers: 2699.
# Simulation finished. Total passengers dropped: 58452. Remaining passengers: 3223.
# Simulation finished. Total passengers dropped: 58505. Remaining passengers: 2759.
# Simulation finished. Total passengers dropped: 109003. Remaining passengers: 310.
# Simulation finished. Total passengers dropped: 107636. Remaining passengers: 237.
# Simulation finished. Total passengers dropped: 53413. Remaining passengers: 8061.
# Simulation finished. Total passengers dropped: 53141. Remaining passengers: 8428.
# Simulation finished. Total passengers dropped: 53334. Remaining passengers: 8072.
# Simulation finished. Total passengers dropped: 53063. Remaining passengers: 7894.
# Simulation finished. Total passengers dropped: 53175. Remaining passengers: 8035.
# Simulation finished. Total passengers dropped: 86373. Remaining passengers: 21907.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22274.
# Simulation finished. Total passengers dropped: 58641. Remaining passengers: 2571.
# Simulation finished. Total passengers dropped: 58419. Remaining passengers: 2759.
# Simulation finished. Total passengers dropped: 58329. Remaining passengers: 2935.
# Simulation finished. Total passengers dropped: 58638. Remaining passengers: 2571.
# Simulation finished. Total passengers dropped: 58538. Remaining passengers: 2480.
# Simulation finished. Total passengers dropped: 108729. Remaining passengers: 239.
# Simulation finished. Total passengers dropped: 108060. Remaining passengers: 281.
# Simulation finished. Total passengers dropped: 52961. Remaining passengers: 8030.
# Simulation finished. Total passengers dropped: 52915. Remaining passengers: 8222.
# Simulation finished. Total passengers dropped: 53208. Remaining passengers: 8318.
# Simulation finished. Total passengers dropped: 53672. Remaining passengers: 8415.
# Simulation finished. Total passengers dropped: 53397. Remaining passengers: 8350.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22366.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22641.
# Simulation finished. Total passengers dropped: 58584. Remaining passengers: 2655.
# Simulation finished. Total passengers dropped: 58592. Remaining passengers: 2877.
# Simulation finished. Total passengers dropped: 58638. Remaining passengers: 2931.
# Simulation finished. Total passengers dropped: 58424. Remaining passengers: 2669.
# Simulation finished. Total passengers dropped: 58423. Remaining passengers: 2693.
# Simulation finished. Total passengers dropped: 107847. Remaining passengers: 295.
# Simulation finished. Total passengers dropped: 108219. Remaining passengers: 229.
# Simulation finished. Total passengers dropped: 53202. Remaining passengers: 8072.
# Simulation finished. Total passengers dropped: 53110. Remaining passengers: 8029.
# Simulation finished. Total passengers dropped: 53001. Remaining passengers: 8359.
# Simulation finished. Total passengers dropped: 52955. Remaining passengers: 8336.
# Simulation finished. Total passengers dropped: 52989. Remaining passengers: 8410.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22493.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22435.
# Simulation finished. Total passengers dropped: 58251. Remaining passengers: 2751.
# Simulation finished. Total passengers dropped: 58317. Remaining passengers: 2972.
# Simulation finished. Total passengers dropped: 58235. Remaining passengers: 2790.
# Simulation finished. Total passengers dropped: 58545. Remaining passengers: 2582.
# Simulation finished. Total passengers dropped: 58129. Remaining passengers: 2787.
# Simulation finished. Total passengers dropped: 109205. Remaining passengers: 318.
# Simulation finished. Total passengers dropped: 108000. Remaining passengers: 318.
# Simulation finished. Total passengers dropped: 52775. Remaining passengers: 8150.
# Simulation finished. Total passengers dropped: 52795. Remaining passengers: 7969.
# Simulation finished. Total passengers dropped: 53440. Remaining passengers: 8356.
# Simulation finished. Total passengers dropped: 53035. Remaining passengers: 8005.
# Simulation finished. Total passengers dropped: 53284. Remaining passengers: 8288.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21938.
# Simulation finished. Total passengers dropped: 86351. Remaining passengers: 22410.
# Simulation finished. Total passengers dropped: 58500. Remaining passengers: 2399.
# Simulation finished. Total passengers dropped: 58604. Remaining passengers: 2764.
# Simulation finished. Total passengers dropped: 58431. Remaining passengers: 2727.
# Simulation finished. Total passengers dropped: 58481. Remaining passengers: 2813.
# Simulation finished. Total passengers dropped: 58890. Remaining passengers: 2261.
# Simulation finished. Total passengers dropped: 108485. Remaining passengers: 277.
# Simulation finished. Total passengers dropped: 109480. Remaining passengers: 302.
# Simulation finished. Total passengers dropped: 53124. Remaining passengers: 8049.
# Simulation finished. Total passengers dropped: 52686. Remaining passengers: 8157.
# Simulation finished. Total passengers dropped: 52896. Remaining passengers: 8318.
# Simulation finished. Total passengers dropped: 53204. Remaining passengers: 8295.
# Simulation finished. Total passengers dropped: 53277. Remaining passengers: 8345.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21698.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21211.
# Simulation finished. Total passengers dropped: 58237. Remaining passengers: 2293.
# Simulation finished. Total passengers dropped: 58755. Remaining passengers: 2538.
# Simulation finished. Total passengers dropped: 58556. Remaining passengers: 3016.
# Simulation finished. Total passengers dropped: 58738. Remaining passengers: 2632.
# Simulation finished. Total passengers dropped: 58191. Remaining passengers: 2831.
# Simulation finished. Total passengers dropped: 107691. Remaining passengers: 228.
# Simulation finished. Total passengers dropped: 107841. Remaining passengers: 348.
# Simulation finished. Total passengers dropped: 53277. Remaining passengers: 8495.
# Simulation finished. Total passengers dropped: 52843. Remaining passengers: 7975.
# Simulation finished. Total passengers dropped: 52995. Remaining passengers: 8286.
# Simulation finished. Total passengers dropped: 52833. Remaining passengers: 8180.
# Simulation finished. Total passengers dropped: 52727. Remaining passengers: 8349.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22101.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 23026.
# Simulation finished. Total passengers dropped: 58884. Remaining passengers: 2324.
# Simulation finished. Total passengers dropped: 57997. Remaining passengers: 2594.
# Simulation finished. Total passengers dropped: 58629. Remaining passengers: 2962.
# Simulation finished. Total passengers dropped: 58410. Remaining passengers: 2784.
# Simulation finished. Total passengers dropped: 58685. Remaining passengers: 2891.
# Simulation finished. Total passengers dropped: 108671. Remaining passengers: 314.
# Simulation finished. Total passengers dropped: 107970. Remaining passengers: 270.
# Simulation finished. Total passengers dropped: 53202. Remaining passengers: 8107.
# Simulation finished. Total passengers dropped: 53401. Remaining passengers: 8091.
# Simulation finished. Total passengers dropped: 53071. Remaining passengers: 8339.
# Simulation finished. Total passengers dropped: 53211. Remaining passengers: 8271.
# Simulation finished. Total passengers dropped: 52666. Remaining passengers: 8078.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21951.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21912.
# Simulation finished. Total passengers dropped: 60833. Remaining passengers: 894.
# Simulation finished. Total passengers dropped: 59863. Remaining passengers: 887.
# Simulation finished. Total passengers dropped: 60966. Remaining passengers: 409.
# Simulation finished. Total passengers dropped: 59818. Remaining passengers: 842.
# Simulation finished. Total passengers dropped: 60514. Remaining passengers: 771.
# Simulation finished. Total passengers dropped: 108267. Remaining passengers: 234.
# Simulation finished. Total passengers dropped: 108072. Remaining passengers: 289.
# Simulation finished. Total passengers dropped: 54312. Remaining passengers: 6889.
# Simulation finished. Total passengers dropped: 54786. Remaining passengers: 7017.
# Simulation finished. Total passengers dropped: 53915. Remaining passengers: 6845.
# Simulation finished. Total passengers dropped: 53803. Remaining passengers: 6886.
# Simulation finished. Total passengers dropped: 54610. Remaining passengers: 7197.
# Simulation finished. Total passengers dropped: 97050. Remaining passengers: 11979.
# Simulation finished. Total passengers dropped: 97090. Remaining passengers: 10918.
# Simulation finished. Total passengers dropped: 60105. Remaining passengers: 958.
# Simulation finished. Total passengers dropped: 60671. Remaining passengers: 1087.
# Simulation finished. Total passengers dropped: 60316. Remaining passengers: 723.
# Simulation finished. Total passengers dropped: 60816. Remaining passengers: 785.
# Simulation finished. Total passengers dropped: 60901. Remaining passengers: 792.
# Simulation finished. Total passengers dropped: 109079. Remaining passengers: 254.
# Simulation finished. Total passengers dropped: 108156. Remaining passengers: 280.
# Simulation finished. Total passengers dropped: 54091. Remaining passengers: 7267.
# Simulation finished. Total passengers dropped: 53988. Remaining passengers: 6918.
# Simulation finished. Total passengers dropped: 54258. Remaining passengers: 7014.
# Simulation finished. Total passengers dropped: 54365. Remaining passengers: 6916.
# Simulation finished. Total passengers dropped: 53777. Remaining passengers: 6849.
# Simulation finished. Total passengers dropped: 97090. Remaining passengers: 11621.
# Simulation finished. Total passengers dropped: 97111. Remaining passengers: 11095.
# Simulation finished. Total passengers dropped: 60238. Remaining passengers: 639.
# Simulation finished. Total passengers dropped: 60339. Remaining passengers: 565.
# Simulation finished. Total passengers dropped: 59666. Remaining passengers: 378.
# Simulation finished. Total passengers dropped: 60229. Remaining passengers: 818.
# Simulation finished. Total passengers dropped: 60234. Remaining passengers: 722.
# Simulation finished. Total passengers dropped: 108803. Remaining passengers: 249.
# Simulation finished. Total passengers dropped: 106566. Remaining passengers: 308.
# Simulation finished. Total passengers dropped: 53947. Remaining passengers: 6658.
# Simulation finished. Total passengers dropped: 54260. Remaining passengers: 6953.
# Simulation finished. Total passengers dropped: 54509. Remaining passengers: 7021.
# Simulation finished. Total passengers dropped: 54199. Remaining passengers: 7138.
# Simulation finished. Total passengers dropped: 54492. Remaining passengers: 7091.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 11974.
# Simulation finished. Total passengers dropped: 97043. Remaining passengers: 11380.
# Simulation finished. Total passengers dropped: 60639. Remaining passengers: 904.
# Simulation finished. Total passengers dropped: 60381. Remaining passengers: 541.
# Simulation finished. Total passengers dropped: 60846. Remaining passengers: 815.
# Simulation finished. Total passengers dropped: 59881. Remaining passengers: 724.
# Simulation finished. Total passengers dropped: 60039. Remaining passengers: 907.
# Simulation finished. Total passengers dropped: 108841. Remaining passengers: 310.
# Simulation finished. Total passengers dropped: 107988. Remaining passengers: 314.
# Simulation finished. Total passengers dropped: 54453. Remaining passengers: 6710.
# Simulation finished. Total passengers dropped: 53903. Remaining passengers: 6965.
# Simulation finished. Total passengers dropped: 54009. Remaining passengers: 7021.
# Simulation finished. Total passengers dropped: 54412. Remaining passengers: 6864.
# Simulation finished. Total passengers dropped: 54190. Remaining passengers: 6775.
# Simulation finished. Total passengers dropped: 97191. Remaining passengers: 12615.
# Simulation finished. Total passengers dropped: 97182. Remaining passengers: 12859.
# Simulation finished. Total passengers dropped: 60598. Remaining passengers: 890.
# Simulation finished. Total passengers dropped: 60884. Remaining passengers: 853.
# Simulation finished. Total passengers dropped: 60301. Remaining passengers: 733.
# Simulation finished. Total passengers dropped: 60215. Remaining passengers: 626.
# Simulation finished. Total passengers dropped: 60713. Remaining passengers: 1032.
# Simulation finished. Total passengers dropped: 107662. Remaining passengers: 273.
# Simulation finished. Total passengers dropped: 108863. Remaining passengers: 263.
# Simulation finished. Total passengers dropped: 54680. Remaining passengers: 7237.
# Simulation finished. Total passengers dropped: 54444. Remaining passengers: 7015.
# Simulation finished. Total passengers dropped: 54308. Remaining passengers: 6993.
# Simulation finished. Total passengers dropped: 54520. Remaining passengers: 6953.
# Simulation finished. Total passengers dropped: 54411. Remaining passengers: 7192.
# Simulation finished. Total passengers dropped: 97109. Remaining passengers: 11428.
# Simulation finished. Total passengers dropped: 97129. Remaining passengers: 10664.
# Simulation finished. Total passengers dropped: 60527. Remaining passengers: 1052.
# Simulation finished. Total passengers dropped: 60284. Remaining passengers: 735.
# Simulation finished. Total passengers dropped: 60614. Remaining passengers: 571.
# Simulation finished. Total passengers dropped: 60794. Remaining passengers: 1165.
# Simulation finished. Total passengers dropped: 60300. Remaining passengers: 990.
# Simulation finished. Total passengers dropped: 108249. Remaining passengers: 231.
# Simulation finished. Total passengers dropped: 108836. Remaining passengers: 291.
# Simulation finished. Total passengers dropped: 53717. Remaining passengers: 6791.
# Simulation finished. Total passengers dropped: 54482. Remaining passengers: 6840.
# Simulation finished. Total passengers dropped: 54439. Remaining passengers: 6658.
# Simulation finished. Total passengers dropped: 54115. Remaining passengers: 7250.
# Simulation finished. Total passengers dropped: 54208. Remaining passengers: 6762.
# Simulation finished. Total passengers dropped: 97153. Remaining passengers: 12279.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 11891.
# Simulation finished. Total passengers dropped: 60412. Remaining passengers: 767.
# Simulation finished. Total passengers dropped: 59884. Remaining passengers: 970.
# Simulation finished. Total passengers dropped: 60634. Remaining passengers: 647.
# Simulation finished. Total passengers dropped: 60357. Remaining passengers: 932.
# Simulation finished. Total passengers dropped: 60418. Remaining passengers: 712.
# Simulation finished. Total passengers dropped: 107851. Remaining passengers: 255.
# Simulation finished. Total passengers dropped: 108806. Remaining passengers: 287.
# Simulation finished. Total passengers dropped: 53934. Remaining passengers: 7223.
# Simulation finished. Total passengers dropped: 54308. Remaining passengers: 6783.
# Simulation finished. Total passengers dropped: 53718. Remaining passengers: 6688.
# Simulation finished. Total passengers dropped: 53904. Remaining passengers: 7029.
# Simulation finished. Total passengers dropped: 54692. Remaining passengers: 6870.
# Simulation finished. Total passengers dropped: 97151. Remaining passengers: 11837.
# Simulation finished. Total passengers dropped: 97070. Remaining passengers: 11088.
# Simulation finished. Total passengers dropped: 61519. Remaining passengers: 605.
# Simulation finished. Total passengers dropped: 60123. Remaining passengers: 765.
# Simulation finished. Total passengers dropped: 60338. Remaining passengers: 858.
# Simulation finished. Total passengers dropped: 59873. Remaining passengers: 783.
# Simulation finished. Total passengers dropped: 60188. Remaining passengers: 1000.
# Simulation finished. Total passengers dropped: 108292. Remaining passengers: 262.
# Simulation finished. Total passengers dropped: 107450. Remaining passengers: 241.
# Simulation finished. Total passengers dropped: 54387. Remaining passengers: 7106.
# Simulation finished. Total passengers dropped: 54299. Remaining passengers: 7058.
# Simulation finished. Total passengers dropped: 54188. Remaining passengers: 6767.
# Simulation finished. Total passengers dropped: 54395. Remaining passengers: 6930.
# Simulation finished. Total passengers dropped: 54280. Remaining passengers: 7080.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 10901.
# Simulation finished. Total passengers dropped: 97151. Remaining passengers: 10226.
# Simulation finished. Total passengers dropped: 60363. Remaining passengers: 698.
# Simulation finished. Total passengers dropped: 60121. Remaining passengers: 740.
# Simulation finished. Total passengers dropped: 60307. Remaining passengers: 963.
# Simulation finished. Total passengers dropped: 60451. Remaining passengers: 860.
# Simulation finished. Total passengers dropped: 59898. Remaining passengers: 834.
# Simulation finished. Total passengers dropped: 108142. Remaining passengers: 263.
# Simulation finished. Total passengers dropped: 109116. Remaining passengers: 286.
# Simulation finished. Total passengers dropped: 54025. Remaining passengers: 7021.
# Simulation finished. Total passengers dropped: 54196. Remaining passengers: 6995.
# Simulation finished. Total passengers dropped: 54250. Remaining passengers: 7043.
# Simulation finished. Total passengers dropped: 54404. Remaining passengers: 7119.
# Simulation finished. Total passengers dropped: 54121. Remaining passengers: 6907.
# Simulation finished. Total passengers dropped: 97042. Remaining passengers: 11404.
# Simulation finished. Total passengers dropped: 96990. Remaining passengers: 11967.
# Simulation finished. Total passengers dropped: 60472. Remaining passengers: 595.
# Simulation finished. Total passengers dropped: 60242. Remaining passengers: 729.
# Simulation finished. Total passengers dropped: 59797. Remaining passengers: 1190.
# Simulation finished. Total passengers dropped: 60542. Remaining passengers: 698.
# Simulation finished. Total passengers dropped: 60597. Remaining passengers: 937.
# Simulation finished. Total passengers dropped: 107790. Remaining passengers: 204.
# Simulation finished. Total passengers dropped: 107655. Remaining passengers: 223.
# Simulation finished. Total passengers dropped: 54531. Remaining passengers: 7491.
# Simulation finished. Total passengers dropped: 54488. Remaining passengers: 6883.
# Simulation finished. Total passengers dropped: 53957. Remaining passengers: 6900.
# Simulation finished. Total passengers dropped: 54151. Remaining passengers: 6798.
# Simulation finished. Total passengers dropped: 54107. Remaining passengers: 7049.
# Simulation finished. Total passengers dropped: 97095. Remaining passengers: 10704.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 11327.
# Simulation finished. Total passengers dropped: 60870. Remaining passengers: 744.
# Simulation finished. Total passengers dropped: 59973. Remaining passengers: 477.
# Simulation finished. Total passengers dropped: 60522. Remaining passengers: 605.
# Simulation finished. Total passengers dropped: 60122. Remaining passengers: 1001.
# Simulation finished. Total passengers dropped: 60198. Remaining passengers: 871.
# Simulation finished. Total passengers dropped: 107269. Remaining passengers: 279.
# Simulation finished. Total passengers dropped: 108973. Remaining passengers: 241.
# Simulation finished. Total passengers dropped: 54164. Remaining passengers: 6822.
# Simulation finished. Total passengers dropped: 53826. Remaining passengers: 6828.
# Simulation finished. Total passengers dropped: 53361. Remaining passengers: 7020.
# Simulation finished. Total passengers dropped: 54348. Remaining passengers: 7015.
# Simulation finished. Total passengers dropped: 54661. Remaining passengers: 6773.
# Simulation finished. Total passengers dropped: 97071. Remaining passengers: 11817.
# Simulation finished. Total passengers dropped: 97198. Remaining passengers: 11260.
# Simulation finished. Total passengers dropped: 60470. Remaining passengers: 1135.
# Simulation finished. Total passengers dropped: 60937. Remaining passengers: 684.
# Simulation finished. Total passengers dropped: 60168. Remaining passengers: 1129.
# Simulation finished. Total passengers dropped: 60824. Remaining passengers: 898.
# Simulation finished. Total passengers dropped: 60336. Remaining passengers: 710.
# Simulation finished. Total passengers dropped: 108073. Remaining passengers: 250.
# Simulation finished. Total passengers dropped: 109220. Remaining passengers: 274.
# Simulation finished. Total passengers dropped: 54271. Remaining passengers: 6773.
# Simulation finished. Total passengers dropped: 54049. Remaining passengers: 6683.
# Simulation finished. Total passengers dropped: 54385. Remaining passengers: 6817.
# Simulation finished. Total passengers dropped: 54348. Remaining passengers: 6852.
# Simulation finished. Total passengers dropped: 54500. Remaining passengers: 6896.
# Simulation finished. Total passengers dropped: 97042. Remaining passengers: 11585.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 10906.
# Simulation finished. Total passengers dropped: 61326. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61197. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61535. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 61637. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60947. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 108696. Remaining passengers: 167.
# Simulation finished. Total passengers dropped: 108903. Remaining passengers: 173.
# Simulation finished. Total passengers dropped: 56115. Remaining passengers: 5398.
# Simulation finished. Total passengers dropped: 55443. Remaining passengers: 5528.
# Simulation finished. Total passengers dropped: 55236. Remaining passengers: 5327.
# Simulation finished. Total passengers dropped: 56106. Remaining passengers: 5786.
# Simulation finished. Total passengers dropped: 55968. Remaining passengers: 5480.
# Simulation finished. Total passengers dropped: 107877. Remaining passengers: 1208.
# Simulation finished. Total passengers dropped: 107767. Remaining passengers: 571.
# Simulation finished. Total passengers dropped: 61658. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 60832. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60935. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 60969. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 61014. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 108360. Remaining passengers: 208.
# Simulation finished. Total passengers dropped: 108842. Remaining passengers: 171.
# Simulation finished. Total passengers dropped: 55362. Remaining passengers: 5811.
# Simulation finished. Total passengers dropped: 54880. Remaining passengers: 5268.
# Simulation finished. Total passengers dropped: 55829. Remaining passengers: 6089.
# Simulation finished. Total passengers dropped: 55569. Remaining passengers: 5461.
# Simulation finished. Total passengers dropped: 55819. Remaining passengers: 5550.
# Simulation finished. Total passengers dropped: 107235. Remaining passengers: 577.
# Simulation finished. Total passengers dropped: 107498. Remaining passengers: 1001.
# Simulation finished. Total passengers dropped: 61190. Remaining passengers: 27.
# Simulation finished. Total passengers dropped: 61019. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61126. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 61203. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 60895. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 108345. Remaining passengers: 138.
# Simulation finished. Total passengers dropped: 108462. Remaining passengers: 170.
# Simulation finished. Total passengers dropped: 55290. Remaining passengers: 5735.
# Simulation finished. Total passengers dropped: 55213. Remaining passengers: 5326.
# Simulation finished. Total passengers dropped: 55045. Remaining passengers: 5333.
# Simulation finished. Total passengers dropped: 55491. Remaining passengers: 5901.
# Simulation finished. Total passengers dropped: 55596. Remaining passengers: 5649.
# Simulation finished. Total passengers dropped: 107796. Remaining passengers: 1272.
# Simulation finished. Total passengers dropped: 107673. Remaining passengers: 1044.
# Simulation finished. Total passengers dropped: 60513. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61383. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 60800. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61407. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61215. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 109340. Remaining passengers: 177.
# Simulation finished. Total passengers dropped: 107809. Remaining passengers: 145.
# Simulation finished. Total passengers dropped: 55419. Remaining passengers: 5463.
# Simulation finished. Total passengers dropped: 55829. Remaining passengers: 5483.
# Simulation finished. Total passengers dropped: 55756. Remaining passengers: 5520.
# Simulation finished. Total passengers dropped: 56237. Remaining passengers: 5599.
# Simulation finished. Total passengers dropped: 55810. Remaining passengers: 5557.
# Simulation finished. Total passengers dropped: 107704. Remaining passengers: 720.
# Simulation finished. Total passengers dropped: 107842. Remaining passengers: 912.
# Simulation finished. Total passengers dropped: 61399. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61264. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61498. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 61205. Remaining passengers: 3.
# Simulation finished. Total passengers dropped: 61089. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 107785. Remaining passengers: 164.
# Simulation finished. Total passengers dropped: 108253. Remaining passengers: 132.
# Simulation finished. Total passengers dropped: 55870. Remaining passengers: 5479.
# Simulation finished. Total passengers dropped: 56238. Remaining passengers: 5470.
# Simulation finished. Total passengers dropped: 55666. Remaining passengers: 5290.
# Simulation finished. Total passengers dropped: 55058. Remaining passengers: 5496.
# Simulation finished. Total passengers dropped: 55408. Remaining passengers: 5567.
# Simulation finished. Total passengers dropped: 107418. Remaining passengers: 1118.
# Simulation finished. Total passengers dropped: 107758. Remaining passengers: 539.
# Simulation finished. Total passengers dropped: 61084. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 60752. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 60681. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61239. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60845. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 109475. Remaining passengers: 188.
# Simulation finished. Total passengers dropped: 108811. Remaining passengers: 174.
# Simulation finished. Total passengers dropped: 56237. Remaining passengers: 5678.
# Simulation finished. Total passengers dropped: 55384. Remaining passengers: 5910.
# Simulation finished. Total passengers dropped: 55377. Remaining passengers: 5403.
# Simulation finished. Total passengers dropped: 55745. Remaining passengers: 5580.
# Simulation finished. Total passengers dropped: 55416. Remaining passengers: 5676.
# Simulation finished. Total passengers dropped: 107687. Remaining passengers: 1041.
# Simulation finished. Total passengers dropped: 107691. Remaining passengers: 1175.
# Simulation finished. Total passengers dropped: 61237. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61872. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61008. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60583. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61086. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 106696. Remaining passengers: 121.
# Simulation finished. Total passengers dropped: 107845. Remaining passengers: 166.
# Simulation finished. Total passengers dropped: 55529. Remaining passengers: 5661.
# Simulation finished. Total passengers dropped: 55485. Remaining passengers: 5282.
# Simulation finished. Total passengers dropped: 55620. Remaining passengers: 5492.
# Simulation finished. Total passengers dropped: 55735. Remaining passengers: 5584.
# Simulation finished. Total passengers dropped: 55342. Remaining passengers: 5581.
# Simulation finished. Total passengers dropped: 107717. Remaining passengers: 1138.
# Simulation finished. Total passengers dropped: 107598. Remaining passengers: 473.
# Simulation finished. Total passengers dropped: 61808. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 60986. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61072. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61632. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61515. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 108269. Remaining passengers: 125.
# Simulation finished. Total passengers dropped: 108146. Remaining passengers: 182.
# Simulation finished. Total passengers dropped: 55534. Remaining passengers: 5989.
# Simulation finished. Total passengers dropped: 56050. Remaining passengers: 5453.
# Simulation finished. Total passengers dropped: 55269. Remaining passengers: 5813.
# Simulation finished. Total passengers dropped: 56128. Remaining passengers: 6017.
# Simulation finished. Total passengers dropped: 55296. Remaining passengers: 6112.
# Simulation finished. Total passengers dropped: 107262. Remaining passengers: 887.
# Simulation finished. Total passengers dropped: 107500. Remaining passengers: 1073.
# Simulation finished. Total passengers dropped: 61270. Remaining passengers: 30.
# Simulation finished. Total passengers dropped: 61200. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61163. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61558. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 60983. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 108964. Remaining passengers: 205.
# Simulation finished. Total passengers dropped: 108555. Remaining passengers: 166.
# Simulation finished. Total passengers dropped: 55929. Remaining passengers: 5622.
# Simulation finished. Total passengers dropped: 55618. Remaining passengers: 5266.
# Simulation finished. Total passengers dropped: 55530. Remaining passengers: 5667.
# Simulation finished. Total passengers dropped: 55333. Remaining passengers: 5573.
# Simulation finished. Total passengers dropped: 55704. Remaining passengers: 6012.
# Simulation finished. Total passengers dropped: 107498. Remaining passengers: 902.
# Simulation finished. Total passengers dropped: 107318. Remaining passengers: 341.
# Simulation finished. Total passengers dropped: 61055. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61057. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61652. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61258. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61553. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 107791. Remaining passengers: 183.
# Simulation finished. Total passengers dropped: 108608. Remaining passengers: 192.
# Simulation finished. Total passengers dropped: 55659. Remaining passengers: 5801.
# Simulation finished. Total passengers dropped: 55095. Remaining passengers: 5415.
# Simulation finished. Total passengers dropped: 55253. Remaining passengers: 5403.
# Simulation finished. Total passengers dropped: 55880. Remaining passengers: 5723.
# Simulation finished. Total passengers dropped: 55658. Remaining passengers: 5607.
# Simulation finished. Total passengers dropped: 107644. Remaining passengers: 712.
# Simulation finished. Total passengers dropped: 107677. Remaining passengers: 1154.
# Simulation finished. Total passengers dropped: 60430. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61187. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61501. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61165. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61533. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 108845. Remaining passengers: 153.
# Simulation finished. Total passengers dropped: 107488. Remaining passengers: 182.
# Simulation finished. Total passengers dropped: 55083. Remaining passengers: 5763.
# Simulation finished. Total passengers dropped: 55812. Remaining passengers: 5548.
# Simulation finished. Total passengers dropped: 55588. Remaining passengers: 5696.
# Simulation finished. Total passengers dropped: 55559. Remaining passengers: 5401.
# Simulation finished. Total passengers dropped: 55655. Remaining passengers: 5311.
# Simulation finished. Total passengers dropped: 107194. Remaining passengers: 1094.
# Simulation finished. Total passengers dropped: 107555. Remaining passengers: 982.
# Simulation finished. Total passengers dropped: 61113. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61389. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 61297. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61402. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 60726. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 109237. Remaining passengers: 200.
# Simulation finished. Total passengers dropped: 107880. Remaining passengers: 166.
# Simulation finished. Total passengers dropped: 56735. Remaining passengers: 4393.
# Simulation finished. Total passengers dropped: 56439. Remaining passengers: 4074.
# Simulation finished. Total passengers dropped: 56557. Remaining passengers: 4312.
# Simulation finished. Total passengers dropped: 57057. Remaining passengers: 4305.
# Simulation finished. Total passengers dropped: 56517. Remaining passengers: 4325.
# Simulation finished. Total passengers dropped: 108668. Remaining passengers: 175.
# Simulation finished. Total passengers dropped: 107641. Remaining passengers: 235.
# Simulation finished. Total passengers dropped: 60473. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60581. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61293. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 60946. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61436. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 108424. Remaining passengers: 214.
# Simulation finished. Total passengers dropped: 107774. Remaining passengers: 217.
# Simulation finished. Total passengers dropped: 57020. Remaining passengers: 4178.
# Simulation finished. Total passengers dropped: 56933. Remaining passengers: 4238.
# Simulation finished. Total passengers dropped: 56615. Remaining passengers: 4285.
# Simulation finished. Total passengers dropped: 56842. Remaining passengers: 4472.
# Simulation finished. Total passengers dropped: 57155. Remaining passengers: 4562.
# Simulation finished. Total passengers dropped: 109840. Remaining passengers: 191.
# Simulation finished. Total passengers dropped: 109085. Remaining passengers: 206.
# Simulation finished. Total passengers dropped: 61743. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 60696. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 61194. Remaining passengers: 28.
# Simulation finished. Total passengers dropped: 61178. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 61705. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 108392. Remaining passengers: 162.
# Simulation finished. Total passengers dropped: 108350. Remaining passengers: 179.
# Simulation finished. Total passengers dropped: 56906. Remaining passengers: 4471.
# Simulation finished. Total passengers dropped: 56923. Remaining passengers: 4213.
# Simulation finished. Total passengers dropped: 56428. Remaining passengers: 4425.
# Simulation finished. Total passengers dropped: 56563. Remaining passengers: 4427.
# Simulation finished. Total passengers dropped: 56990. Remaining passengers: 4223.
# Simulation finished. Total passengers dropped: 109123. Remaining passengers: 145.
# Simulation finished. Total passengers dropped: 108385. Remaining passengers: 174.
# Simulation finished. Total passengers dropped: 60865. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60968. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61304. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 61430. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 61454. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 109266. Remaining passengers: 198.
# Simulation finished. Total passengers dropped: 107721. Remaining passengers: 181.
# Simulation finished. Total passengers dropped: 57359. Remaining passengers: 4262.
# Simulation finished. Total passengers dropped: 56757. Remaining passengers: 4285.
# Simulation finished. Total passengers dropped: 57204. Remaining passengers: 4187.
# Simulation finished. Total passengers dropped: 57441. Remaining passengers: 4370.
# Simulation finished. Total passengers dropped: 56771. Remaining passengers: 4511.
# Simulation finished. Total passengers dropped: 108656. Remaining passengers: 169.
# Simulation finished. Total passengers dropped: 108418. Remaining passengers: 147.
# Simulation finished. Total passengers dropped: 61641. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 60448. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61181. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61314. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61679. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 108285. Remaining passengers: 199.
# Simulation finished. Total passengers dropped: 108594. Remaining passengers: 148.
# Simulation finished. Total passengers dropped: 56797. Remaining passengers: 4175.
# Simulation finished. Total passengers dropped: 56848. Remaining passengers: 4173.
# Simulation finished. Total passengers dropped: 57132. Remaining passengers: 4216.
# Simulation finished. Total passengers dropped: 56765. Remaining passengers: 4113.
# Simulation finished. Total passengers dropped: 56474. Remaining passengers: 4171.
# Simulation finished. Total passengers dropped: 108466. Remaining passengers: 175.
# Simulation finished. Total passengers dropped: 109070. Remaining passengers: 187.
# Simulation finished. Total passengers dropped: 61646. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61351. Remaining passengers: 32.
# Simulation finished. Total passengers dropped: 61775. Remaining passengers: 27.
# Simulation finished. Total passengers dropped: 61791. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 60748. Remaining passengers: 7.
# Simulation finished. Total passengers dropped: 107229. Remaining passengers: 213.
# Simulation finished. Total passengers dropped: 108276. Remaining passengers: 175.
# Simulation finished. Total passengers dropped: 56714. Remaining passengers: 4371.
# Simulation finished. Total passengers dropped: 56777. Remaining passengers: 4182.
# Simulation finished. Total passengers dropped: 56754. Remaining passengers: 4487.
# Simulation finished. Total passengers dropped: 57165. Remaining passengers: 4195.
# Simulation finished. Total passengers dropped: 56692. Remaining passengers: 4618.
# Simulation finished. Total passengers dropped: 108796. Remaining passengers: 247.
# ...
# Stop 4: 2024-12-14T06:40, 2024-12-14T07:50, 2024-12-14T07:50, 2024-12-14T09:00, 2024-12-14T09:00, 2024-12-14T09:00, 2024-12-14T10:10, 2024-12-14T10:10, 2024-12-14T10:10, 2024-12-14T10:10, 2024-12-14T11:20, 2024-12-14T11:20, 2024-12-14T11:20, 2024-12-14T11:20, 2024-12-14T11:20, 2024-12-14T12:30, 2024-12-14T12:30, 2024-12-14T12:30, 2024-12-14T12:30, 2024-12-14T12:30, 2024-12-14T12:30, 2024-12-14T13:40, 2024-12-14T13:40, 2024-12-14T13:40, 2024-12-14T13:40, 2024-12-14T13:40, 2024-12-14T13:40, 2024-12-14T13:40, 2024-12-14T14:50, 2024-12-14T14:50, 2024-12-14T14:50, 2024-12-14T14:50, 2024-12-14T14:50, 2024-12-14T14:50, 2024-12-14T14:50, 2024-12-14T14:50, 2024-12-14T16:00, 2024-12-14T16:00, 2024-12-14T16:00, 2024-12-14T16:00, 2024-12-14T16:00, 2024-12-14T16:00, 2024-12-14T16:00, 2024-12-14T16:00, 2024-12-14T16:00, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T20:40, 2024-12-14T20:40, 2024-12-14T20:40, 2024-12-14T20:40, 2024-12-14T20:40, 2024-12-14T20:40, 2024-12-14T20:40, 2024-12-14T20:40, 2024-12-14T20:40, 2024-12-14T21:50, 2024-12-14T21:50, 2024-12-14T21:50, 2024-12-14T21:50, 2024-12-14T21:50, 2024-12-14T21:50, 2024-12-14T21:50, 2024-12-14T21:50, 2024-12-14T21:50, 2024-12-14T23:00, 2024-12-14T23:00, 2024-12-14T23:00, 2024-12-14T23:00, 2024-12-14T23:00, 2024-12-14T23:00, 2024-12-14T23:00, 2024-12-14T23:00, 2024-12-14T23:00, 2024-12-15T00:10, 2024-12-15T00:10, 2024-12-15T00:10, 2024-12-15T00:10, 2024-12-15T00:10, 2024-12-15T00:10, 2024-12-15T00:10, 2024-12-15T00:10, 2024-12-15T00:10, 2024-12-15T01:20, 2024-12-15T01:20, 2024-12-15T01:20, 2024-12-15T01:20, 2024-12-15T01:20, 2024-12-15T01:20, 2024-12-15T01:20, 2024-12-15T01:20, 2024-12-15T01:20, 2024-12-15T02:30, 2024-12-15T02:30, 2024-12-15T02:30, 2024-12-15T02:30, 2024-12-15T02:30, 2024-12-15T02:30, 2024-12-15T02:30, 2024-12-15T02:30, 2024-12-15T02:30, 2024-12-15T03:40, 2024-12-15T03:40, 2024-12-15T03:40, 2024-12-15T03:40, 2024-12-15T03:40, 2024-12-15T03:40, 2024-12-15T03:40, 2024-12-15T03:40, 2024-12-15T03:40, 2024-12-15T04:50, 2024-12-15T04:50, 2024-12-15T04:50, 2024-12-15T04:50, 2024-12-15T04:50, 2024-12-15T04:50, 2024-12-15T04:50, 2024-12-15T04:50, 2024-12-15T04:50, 2024-12-15T06:00, 2024-12-15T06:00, 2024-12-15T06:00, 2024-12-15T06:00, 2024-12-15T06:00, 2024-12-15T06:00, 2024-12-15T06:00, 2024-12-15T06:00, 2024-12-15T06:00, 2024-12-15T07:10, 2024-12-15T07:10, 2024-12-15T07:10, 2024-12-15T07:10, 2024-12-15T07:10, 2024-12-15T07:10, 2024-12-15T07:10, 2024-12-15T07:10, 2024-12-15T07:10, 2024-12-15T08:20, 2024-12-15T08:20, 2024-12-15T08:20, 2024-12-15T08:20, 2024-12-15T08:20, 2024-12-15T08:20, 2024-12-15T08:20, 2024-12-15T08:20, 2024-12-15T08:20, 2024-12-15T09:30, 2024-12-15T09:30, 2024-12-15T09:30, 2024-12-15T09:30, 2024-12-15T09:30, 2024-12-15T09:30, 2024-12-15T09:30, 2024-12-15T09:30, 2024-12-15T09:30, 2024-12-15T10:40, 2024-12-15T10:40, 2024-12-15T10:40, 2024-12-15T10:40, 2024-12-15T10:40, 2024-12-15T10:40, 2024-12-15T10:40, 2024-12-15T10:40, 2024-12-15T10:40, 2024-12-15T11:50, 2024-12-15T11:50, 2024-12-15T11:50, 2024-12-15T11:50, 2024-12-15T11:50, 2024-12-15T11:50, 2024-12-15T11:50, 2024-12-15T11:50, 2024-12-15T11:50, 2024-12-15T13:00, 2024-12-15T13:00, 2024-12-15T13:00, 2024-12-15T13:00, 2024-12-15T13:00, 2024-12-15T13:00, 2024-12-15T13:00, 2024-12-15T13:00, 2024-12-15T13:00, 2024-12-15T14:10, 2024-12-15T14:10, 2024-12-15T14:10, 2024-12-15T14:10, 2024-12-15T14:10, 2024-12-15T14:10, 2024-12-15T14:10, 2024-12-15T14:10, 2024-12-15T14:10, 2024-12-15T15:20, 2024-12-15T15:20, 2024-12-15T15:20, 2024-12-15T15:20, 2024-12-15T15:20, 2024-12-15T15: ...
# Stop 5: 2024-12-14T06:50, 2024-12-14T08:00, 2024-12-14T08:00, 2024-12-14T09:10, 2024-12-14T09:10, 2024-12-14T09:10, 2024-12-14T10:20, 2024-12-14T10:20, 2024-12-14T10:20, 2024-12-14T10:20, 2024-12-14T11:30, 2024-12-14T11:30, 2024-12-14T11:30, 2024-12-14T11:30, 2024-12-14T11:30, 2024-12-14T12:40, 2024-12-14T12:40, 2024-12-14T12:40, 2024-12-14T12:40, 2024-12-14T12:40, 2024-12-14T12:40, 2024-12-14T13:50, 2024-12-14T13:50, 2024-12-14T13:50, 2024-12-14T13:50, 2024-12-14T13:50, 2024-12-14T13:50, 2024-12-14T13:50, 2024-12-14T15:00, 2024-12-14T15:00, 2024-12-14T15:00, 2024-12-14T15:00, 2024-12-14T15:00, 2024-12-14T15:00, 2024-12-14T15:00, 2024-12-14T15:00, 2024-12-14T16:10, 2024-12-14T16:10, 2024-12-14T16:10, 2024-12-14T16:10, 2024-12-14T16:10, 2024-12-14T16:10, 2024-12-14T16:10, 2024-12-14T16:10, 2024-12-14T16:10, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T20:50, 2024-12-14T20:50, 2024-12-14T20:50, 2024-12-14T20:50, 2024-12-14T20:50, 2024-12-14T20:50, 2024-12-14T20:50, 2024-12-14T20:50, 2024-12-14T20:50, 2024-12-14T22:00, 2024-12-14T22:00, 2024-12-14T22:00, 2024-12-14T22:00, 2024-12-14T22:00, 2024-12-14T22:00, 2024-12-14T22:00, 2024-12-14T22:00, 2024-12-14T22:00, 2024-12-14T23:10, 2024-12-14T23:10, 2024-12-14T23:10, 2024-12-14T23:10, 2024-12-14T23:10, 2024-12-14T23:10, 2024-12-14T23:10, 2024-12-14T23:10, 2024-12-14T23:10, 2024-12-15T00:20, 2024-12-15T00:20, 2024-12-15T00:20, 2024-12-15T00:20, 2024-12-15T00:20, 2024-12-15T00:20, 2024-12-15T00:20, 2024-12-15T00:20, 2024-12-15T00:20, 2024-12-15T01:30, 2024-12-15T01:30, 2024-12-15T01:30, 2024-12-15T01:30, 2024-12-15T01:30, 2024-12-15T01:30, 2024-12-15T01:30, 2024-12-15T01:30, 2024-12-15T01:30, 2024-12-15T02:40, 2024-12-15T02:40, 2024-12-15T02:40, 2024-12-15T02:40, 2024-12-15T02:40, 2024-12-15T02:40, 2024-12-15T02:40, 2024-12-15T02:40, 2024-12-15T02:40, 2024-12-15T03:50, 2024-12-15T03:50, 2024-12-15T03:50, 2024-12-15T03:50, 2024-12-15T03:50, 2024-12-15T03:50, 2024-12-15T03:50, 2024-12-15T03:50, 2024-12-15T03:50, 2024-12-15T05:00, 2024-12-15T05:00, 2024-12-15T05:00, 2024-12-15T05:00, 2024-12-15T05:00, 2024-12-15T05:00, 2024-12-15T05:00, 2024-12-15T05:00, 2024-12-15T05:00, 2024-12-15T06:10, 2024-12-15T06:10, 2024-12-15T06:10, 2024-12-15T06:10, 2024-12-15T06:10, 2024-12-15T06:10, 2024-12-15T06:10, 2024-12-15T06:10, 2024-12-15T06:10, 2024-12-15T07:20, 2024-12-15T07:20, 2024-12-15T07:20, 2024-12-15T07:20, 2024-12-15T07:20, 2024-12-15T07:20, 2024-12-15T07:20, 2024-12-15T07:20, 2024-12-15T07:20, 2024-12-15T08:30, 2024-12-15T08:30, 2024-12-15T08:30, 2024-12-15T08:30, 2024-12-15T08:30, 2024-12-15T08:30, 2024-12-15T08:30, 2024-12-15T08:30, 2024-12-15T08:30, 2024-12-15T09:40, 2024-12-15T09:40, 2024-12-15T09:40, 2024-12-15T09:40, 2024-12-15T09:40, 2024-12-15T09:40, 2024-12-15T09:40, 2024-12-15T09:40, 2024-12-15T09:40, 2024-12-15T10:50, 2024-12-15T10:50, 2024-12-15T10:50, 2024-12-15T10:50, 2024-12-15T10:50, 2024-12-15T10:50, 2024-12-15T10:50, 2024-12-15T10:50, 2024-12-15T10:50, 2024-12-15T12:00, 2024-12-15T12:00, 2024-12-15T12:00, 2024-12-15T12:00, 2024-12-15T12:00, 2024-12-15T12:00, 2024-12-15T12:00, 2024-12-15T12:00, 2024-12-15T12:00, 2024-12-15T13:10, 2024-12-15T13:10, 2024-12-15T13:10, 2024-12-15T13:10, 2024-12-15T13:10, 2024-12-15T13:10, 2024-12-15T13:10, 2024-12-15T13:10, 2024-12-15T13:10, 2024-12-15T14:20, 2024-12-15T14:20, 2024-12-15T14:20, 2024-12-15T14:20, 2024-12-15T14:20, 2024-12-15T14:20, 2024-12-15T14:20, 2024-12-15T14:20, 2024-12-15T14:20, 2024-12-15T15:30, 2024-12-15T15:30, 2024-12-15T15:30, 2024-12-15T15:30, 2024-12-15T15:30, 2024-12-15T15: ...
# Stop 6: 2024-12-14T07:00, 2024-12-14T08:10, 2024-12-14T08:10, 2024-12-14T09:20, 2024-12-14T09:20, 2024-12-14T09:20, 2024-12-14T10:30, 2024-12-14T10:30, 2024-12-14T10:30, 2024-12-14T10:30, 2024-12-14T11:40, 2024-12-14T11:40, 2024-12-14T11:40, 2024-12-14T11:40, 2024-12-14T11:40, 2024-12-14T12:50, 2024-12-14T12:50, 2024-12-14T12:50, 2024-12-14T12:50, 2024-12-14T12:50, 2024-12-14T12:50, 2024-12-14T14:00, 2024-12-14T14:00, 2024-12-14T14:00, 2024-12-14T14:00, 2024-12-14T14:00, 2024-12-14T14:00, 2024-12-14T14:00, 2024-12-14T15:10, 2024-12-14T15:10, 2024-12-14T15:10, 2024-12-14T15:10, 2024-12-14T15:10, 2024-12-14T15:10, 2024-12-14T15:10, 2024-12-14T15:10, 2024-12-14T16:20, 2024-12-14T16:20, 2024-12-14T16:20, 2024-12-14T16:20, 2024-12-14T16:20, 2024-12-14T16:20, 2024-12-14T16:20, 2024-12-14T16:20, 2024-12-14T16:20, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T21:00, 2024-12-14T21:00, 2024-12-14T21:00, 2024-12-14T21:00, 2024-12-14T21:00, 2024-12-14T21:00, 2024-12-14T21:00, 2024-12-14T21:00, 2024-12-14T21:00, 2024-12-14T22:10, 2024-12-14T22:10, 2024-12-14T22:10, 2024-12-14T22:10, 2024-12-14T22:10, 2024-12-14T22:10, 2024-12-14T22:10, 2024-12-14T22:10, 2024-12-14T22:10, 2024-12-14T23:20, 2024-12-14T23:20, 2024-12-14T23:20, 2024-12-14T23:20, 2024-12-14T23:20, 2024-12-14T23:20, 2024-12-14T23:20, 2024-12-14T23:20, 2024-12-14T23:20, 2024-12-15T00:30, 2024-12-15T00:30, 2024-12-15T00:30, 2024-12-15T00:30, 2024-12-15T00:30, 2024-12-15T00:30, 2024-12-15T00:30, 2024-12-15T00:30, 2024-12-15T00:30, 2024-12-15T01:40, 2024-12-15T01:40, 2024-12-15T01:40, 2024-12-15T01:40, 2024-12-15T01:40, 2024-12-15T01:40, 2024-12-15T01:40, 2024-12-15T01:40, 2024-12-15T01:40, 2024-12-15T02:50, 2024-12-15T02:50, 2024-12-15T02:50, 2024-12-15T02:50, 2024-12-15T02:50, 2024-12-15T02:50, 2024-12-15T02:50, 2024-12-15T02:50, 2024-12-15T02:50, 2024-12-15T04:00, 2024-12-15T04:00, 2024-12-15T04:00, 2024-12-15T04:00, 2024-12-15T04:00, 2024-12-15T04:00, 2024-12-15T04:00, 2024-12-15T04:00, 2024-12-15T04:00, 2024-12-15T05:10, 2024-12-15T05:10, 2024-12-15T05:10, 2024-12-15T05:10, 2024-12-15T05:10, 2024-12-15T05:10, 2024-12-15T05:10, 2024-12-15T05:10, 2024-12-15T05:10, 2024-12-15T06:20, 2024-12-15T06:20, 2024-12-15T06:20, 2024-12-15T06:20, 2024-12-15T06:20, 2024-12-15T06:20, 2024-12-15T06:20, 2024-12-15T06:20, 2024-12-15T06:20, 2024-12-15T07:30, 2024-12-15T07:30, 2024-12-15T07:30, 2024-12-15T07:30, 2024-12-15T07:30, 2024-12-15T07:30, 2024-12-15T07:30, 2024-12-15T07:30, 2024-12-15T07:30, 2024-12-15T08:40, 2024-12-15T08:40, 2024-12-15T08:40, 2024-12-15T08:40, 2024-12-15T08:40, 2024-12-15T08:40, 2024-12-15T08:40, 2024-12-15T08:40, 2024-12-15T08:40, 2024-12-15T09:50, 2024-12-15T09:50, 2024-12-15T09:50, 2024-12-15T09:50, 2024-12-15T09:50, 2024-12-15T09:50, 2024-12-15T09:50, 2024-12-15T09:50, 2024-12-15T09:50, 2024-12-15T11:00, 2024-12-15T11:00, 2024-12-15T11:00, 2024-12-15T11:00, 2024-12-15T11:00, 2024-12-15T11:00, 2024-12-15T11:00, 2024-12-15T11:00, 2024-12-15T11:00, 2024-12-15T12:10, 2024-12-15T12:10, 2024-12-15T12:10, 2024-12-15T12:10, 2024-12-15T12:10, 2024-12-15T12:10, 2024-12-15T12:10, 2024-12-15T12:10, 2024-12-15T12:10, 2024-12-15T13:20, 2024-12-15T13:20, 2024-12-15T13:20, 2024-12-15T13:20, 2024-12-15T13:20, 2024-12-15T13:20, 2024-12-15T13:20, 2024-12-15T13:20, 2024-12-15T13:20, 2024-12-15T14:30, 2024-12-15T14:30, 2024-12-15T14:30, 2024-12-15T14:30, 2024-12-15T14:30, 2024-12-15T14:30, 2024-12-15T14:30, 2024-12-15T14:30, 2024-12-15T14:30, 2024-12-15T15:40, 2024-12-15T15:40, 2024-12-15T15:40, 2024-12-15T15:40, 2024-12-15T15:40, 2024-12-15T15: ...

# %%
import pandas as pd

def generate_schedule_tables(simulation, is_weekday=True):
    day_type = "Weekday" if is_weekday else "Weekend"
    schedule_tables = {}
    
    for stop, times in simulation.schedule.items():
        filtered_times = []
        for time in times:
            time_obj = pd.Timestamp(time)
            hour = time_obj.hour
            if (6 <= hour < 24) or (hour < 3):  # Рабочие часы: с 6 утра до 3 ночи
                filtered_times.append(time_obj.strftime("%H:%M"))
        
        # Удаляем дубликаты и сортируем
        unique_times = sorted(set(filtered_times))

        # Создаем DataFrame для расписания
        df = pd.DataFrame({"Time": unique_times})
        schedule_tables[f"Stop {stop} ({day_type})"] = df

    return schedule_tables


def save_schedule_to_file(schedule_tables, filename_prefix):
    for stop, table in schedule_tables.items():
        filename = f"{filename_prefix}_{stop.replace(' ', '_').replace('(', '').replace(')', '')}.csv"
        table.to_csv(filename, index=False, encoding="utf-8")
        print(f"Saved {stop} schedule to file: {filename}")

def decide(best_bus_num_g, best_driver_num_g, best_schedule_g, best_bus_num_b, best_driver_num_b, best_schedule_b):
    g = best_bus_num_g < best_bus_num_b + best_driver_num_g < best_bus_num_b
    if g>1:
        return best_bus_num_g,best_driver_num_g,best_schedule_g
    else:
        return best_bus_num_b, best_driver_num_b, best_schedule_b
    
bus_num, driver_num, schedule = decide(best_solution['bus_num'],best_solution['driver_num'], best_solution['schedule_type'], best_bus_num,best_driver_num,best_schedule_type)
print(bus_num,driver_num,schedule)
simulation = Simulation(
    bus_num=bus_num,  # Примерное количество автобусов
    route_duration=70,
    bus_stops_num=7,
    start_time=np.datetime64("2024-12-18T06:00"),
    end_time=np.datetime64("2024-12-18T23:00"),
    tag="monday",  # Пример буднего дня
    driver_schedule_type=schedule,
    driver_shift_duration=420,
    driver_break_duration=60,
    driver_num = driver_num
)
simulation.play_simulation()
simulation.print_schedule()
weekday_tables = generate_schedule_tables(simulation, is_weekday=True)
save_schedule_to_file(weekday_tables, filename_prefix="weekday_schedule")


weekend_tables = generate_schedule_tables(simulation, is_weekday=False)
save_schedule_to_file(weekend_tables, filename_prefix="weekend_schedule")
# Out:
# 14 16 standard
# Simulation finished. Total passengers dropped: 40813. Remaining passengers: 0.
#
# Bus Schedule:
# Stop 0: 2024-12-18T06:00, 2024-12-18T06:50, 2024-12-18T07:10, 2024-12-18T07:40, 2024-12-18T08:00, 2024-12-18T08:20, 2024-12-18T08:30, 2024-12-18T08:50, 2024-12-18T09:10, 2024-12-18T09:20, 2024-12-18T09:30, 2024-12-18T09:40, 2024-12-18T10:00, 2024-12-18T10:10, 2024-12-18T10:20, 2024-12-18T10:30, 2024-12-18T10:40, 2024-12-18T10:50, 2024-12-18T11:00, 2024-12-18T11:10, 2024-12-18T11:20, 2024-12-18T11:30, 2024-12-18T11:40, 2024-12-18T11:50, 2024-12-18T11:50, 2024-12-18T12:00, 2024-12-18T12:10, 2024-12-18T12:20, 2024-12-18T12:30, 2024-12-18T12:40, 2024-12-18T12:40, 2024-12-18T12:50, 2024-12-18T13:00, 2024-12-18T13:00, 2024-12-18T13:10, 2024-12-18T13:20, 2024-12-18T13:30, 2024-12-18T13:30, 2024-12-18T13:40, 2024-12-18T13:50, 2024-12-18T13:50, 2024-12-18T14:00, 2024-12-18T14:10, 2024-12-18T14:10, 2024-12-18T14:20, 2024-12-18T14:20, 2024-12-18T14:30, 2024-12-18T14:40, 2024-12-18T14:40, 2024-12-18T14:50, 2024-12-18T15:00, 2024-12-18T15:00, 2024-12-18T15:10, 2024-12-18T15:10, 2024-12-18T15:20, 2024-12-18T15:20, 2024-12-18T15:30, 2024-12-18T15:30, 2024-12-18T15:40, 2024-12-18T15:50, 2024-12-18T15:50, 2024-12-18T16:00, 2024-12-18T16:00, 2024-12-18T16:10, 2024-12-18T16:10, 2024-12-18T16:20, 2024-12-18T16:20, 2024-12-18T16:30, 2024-12-18T16:30, 2024-12-18T16:40, 2024-12-18T16:40, 2024-12-18T16:50, 2024-12-18T16:50, 2024-12-18T17:00, 2024-12-18T17:00, 2024-12-18T17:10, 2024-12-18T17:10, 2024-12-18T17:20, 2024-12-18T17:20, 2024-12-18T17:30, 2024-12-18T17:30, 2024-12-18T17:40, 2024-12-18T17:40, 2024-12-18T17:50, 2024-12-18T17:50, 2024-12-18T18:00, 2024-12-18T18:00, 2024-12-18T18:10, 2024-12-18T18:10, 2024-12-18T18:20, 2024-12-18T18:20, 2024-12-18T18:30, 2024-12-18T18:30, 2024-12-18T18:40, 2024-12-18T18:40, 2024-12-18T18:50, 2024-12-18T18:50, 2024-12-18T19:00, 2024-12-18T19:00, 2024-12-18T19:10, 2024-12-18T19:10, 2024-12-18T19:20, 2024-12-18T19:20, 2024-12-18T19:30, 2024-12-18T19:30, 2024-12-18T19:40, 2024-12-18T19:40, 2024-12-18T19:50, 2024-12-18T19:50, 2024-12-18T20:00, 2024-12-18T20:00, 2024-12-18T20:10, 2024-12-18T20:10, 2024-12-18T20:20, 2024-12-18T20:20, 2024-12-18T20:30, 2024-12-18T20:30, 2024-12-18T20:40, 2024-12-18T20:40, 2024-12-18T20:50, 2024-12-18T20:50, 2024-12-18T21:00, 2024-12-18T21:00, 2024-12-18T21:10, 2024-12-18T21:10, 2024-12-18T21:20, 2024-12-18T21:20, 2024-12-18T21:30, 2024-12-18T21:30, 2024-12-18T21:40, 2024-12-18T21:40, 2024-12-18T21:50, 2024-12-18T21:50, 2024-12-18T22:00, 2024-12-18T22:00, 2024-12-18T22:10, 2024-12-18T22:10, 2024-12-18T22:20, 2024-12-18T22:20, 2024-12-18T22:30, 2024-12-18T22:30, 2024-12-18T22:40, 2024-12-18T22:40, 2024-12-18T22:50, 2024-12-18T22:50, 2024-12-18T23:00, 2024-12-18T23:00, 2024-12-18T23:10, 2024-12-18T23:10, 2024-12-18T23:20, 2024-12-18T23:20, 2024-12-18T23:30, 2024-12-18T23:30, 2024-12-18T23:40, 2024-12-18T23:40, 2024-12-18T23:50, 2024-12-18T23:50, 2024-12-19T00:00, 2024-12-19T00:00, 2024-12-19T00:10, 2024-12-19T00:10, 2024-12-19T00:20, 2024-12-19T00:20, 2024-12-19T00:30, 2024-12-19T00:30, 2024-12-19T00:40, 2024-12-19T00:40, 2024-12-19T00:50, 2024-12-19T00:50, 2024-12-19T01:00, 2024-12-19T01:00, 2024-12-19T01:10, 2024-12-19T01:10, 2024-12-19T01:20, 2024-12-19T01:20, 2024-12-19T01:30, 2024-12-19T01:30, 2024-12-19T01:40, 2024-12-19T01:40, 2024-12-19T01:50, 2024-12-19T01:50, 2024-12-19T02:00, 2024-12-19T02:00, 2024-12-19T02:10, 2024-12-19T02:10, 2024-12-19T02:20, 2024-12-19T02:20, 2024-12-19T02:30, 2024-12-19T02:30, 2024-12-19T02:40, 2024-12-19T02:40, 2024-12-19T02:50, 2024-12-19T02:50, 2024-12-19T03:00, 2024-12-19T03:00, 2024-12-19T03:10, 2024-12-19T03:10, 2024-12-19T03:20, 2024-12-19T03:20, 2024-12-19T03:30, 2024-12-19T03:30, 2024-12-19T03:40, 2024-12-19T03:40, 2024-12-19T03:50, 2024-12-19T03:50, 2024-12-19T04:00, 2024-12-19T04:00, 2024-12-19T04:10, 2024-12-19T04:10, 2024-12-19T04:20, 2024-12-19T04:20, 2024-12-19T04:30, 2024-12-19T04:30, 2024-12-19T04:40, 2024-12-19T04:40, 2024-12-19T04:50, 2024-12-19T04:50, 2024-12-19T05:00, 2024-12-19T05:00, 2024-12-19T05:10, 2024-12-19T05:10, 2024-12-19T05: ...
# Stop 1: 2024-12-18T06:10, 2024-12-18T07:00, 2024-12-18T07:20, 2024-12-18T07:50, 2024-12-18T08:10, 2024-12-18T08:30, 2024-12-18T08:40, 2024-12-18T09:00, 2024-12-18T09:20, 2024-12-18T09:30, 2024-12-18T09:40, 2024-12-18T09:50, 2024-12-18T10:10, 2024-12-18T10:20, 2024-12-18T10:30, 2024-12-18T10:40, 2024-12-18T10:50, 2024-12-18T11:00, 2024-12-18T11:10, 2024-12-18T11:20, 2024-12-18T11:30, 2024-12-18T11:40, 2024-12-18T11:50, 2024-12-18T12:00, 2024-12-18T12:00, 2024-12-18T12:10, 2024-12-18T12:20, 2024-12-18T12:30, 2024-12-18T12:40, 2024-12-18T12:50, 2024-12-18T12:50, 2024-12-18T13:00, 2024-12-18T13:10, 2024-12-18T13:10, 2024-12-18T13:20, 2024-12-18T13:30, 2024-12-18T13:40, 2024-12-18T13:40, 2024-12-18T13:50, 2024-12-18T14:00, 2024-12-18T14:00, 2024-12-18T14:10, 2024-12-18T14:20, 2024-12-18T14:20, 2024-12-18T14:30, 2024-12-18T14:30, 2024-12-18T14:40, 2024-12-18T14:50, 2024-12-18T14:50, 2024-12-18T15:00, 2024-12-18T15:10, 2024-12-18T15:10, 2024-12-18T15:20, 2024-12-18T15:20, 2024-12-18T15:30, 2024-12-18T15:30, 2024-12-18T15:40, 2024-12-18T15:40, 2024-12-18T15:50, 2024-12-18T16:00, 2024-12-18T16:00, 2024-12-18T16:10, 2024-12-18T16:10, 2024-12-18T16:20, 2024-12-18T16:20, 2024-12-18T16:30, 2024-12-18T16:30, 2024-12-18T16:40, 2024-12-18T16:40, 2024-12-18T16:50, 2024-12-18T16:50, 2024-12-18T17:00, 2024-12-18T17:00, 2024-12-18T17:10, 2024-12-18T17:10, 2024-12-18T17:20, 2024-12-18T17:20, 2024-12-18T17:30, 2024-12-18T17:30, 2024-12-18T17:40, 2024-12-18T17:40, 2024-12-18T17:50, 2024-12-18T17:50, 2024-12-18T18:00, 2024-12-18T18:00, 2024-12-18T18:10, 2024-12-18T18:10, 2024-12-18T18:20, 2024-12-18T18:20, 2024-12-18T18:30, 2024-12-18T18:30, 2024-12-18T18:40, 2024-12-18T18:40, 2024-12-18T18:50, 2024-12-18T18:50, 2024-12-18T19:00, 2024-12-18T19:00, 2024-12-18T19:10, 2024-12-18T19:10, 2024-12-18T19:20, 2024-12-18T19:20, 2024-12-18T19:30, 2024-12-18T19:30, 2024-12-18T19:40, 2024-12-18T19:40, 2024-12-18T19:50, 2024-12-18T19:50, 2024-12-18T20:00, 2024-12-18T20:00, 2024-12-18T20:10, 2024-12-18T20:10, 2024-12-18T20:20, 2024-12-18T20:20, 2024-12-18T20:30, 2024-12-18T20:30, 2024-12-18T20:40, 2024-12-18T20:40, 2024-12-18T20:50, 2024-12-18T20:50, 2024-12-18T21:00, 2024-12-18T21:00, 2024-12-18T21:10, 2024-12-18T21:10, 2024-12-18T21:20, 2024-12-18T21:20, 2024-12-18T21:30, 2024-12-18T21:30, 2024-12-18T21:40, 2024-12-18T21:40, 2024-12-18T21:50, 2024-12-18T21:50, 2024-12-18T22:00, 2024-12-18T22:00, 2024-12-18T22:10, 2024-12-18T22:10, 2024-12-18T22:20, 2024-12-18T22:20, 2024-12-18T22:30, 2024-12-18T22:30, 2024-12-18T22:40, 2024-12-18T22:40, 2024-12-18T22:50, 2024-12-18T22:50, 2024-12-18T23:00, 2024-12-18T23:00, 2024-12-18T23:10, 2024-12-18T23:10, 2024-12-18T23:20, 2024-12-18T23:20, 2024-12-18T23:30, 2024-12-18T23:30, 2024-12-18T23:40, 2024-12-18T23:40, 2024-12-18T23:50, 2024-12-18T23:50, 2024-12-19T00:00, 2024-12-19T00:00, 2024-12-19T00:10, 2024-12-19T00:10, 2024-12-19T00:20, 2024-12-19T00:20, 2024-12-19T00:30, 2024-12-19T00:30, 2024-12-19T00:40, 2024-12-19T00:40, 2024-12-19T00:50, 2024-12-19T00:50, 2024-12-19T01:00, 2024-12-19T01:00, 2024-12-19T01:10, 2024-12-19T01:10, 2024-12-19T01:20, 2024-12-19T01:20, 2024-12-19T01:30, 2024-12-19T01:30, 2024-12-19T01:40, 2024-12-19T01:40, 2024-12-19T01:50, 2024-12-19T01:50, 2024-12-19T02:00, 2024-12-19T02:00, 2024-12-19T02:10, 2024-12-19T02:10, 2024-12-19T02:20, 2024-12-19T02:20, 2024-12-19T02:30, 2024-12-19T02:30, 2024-12-19T02:40, 2024-12-19T02:40, 2024-12-19T02:50, 2024-12-19T02:50, 2024-12-19T03:00, 2024-12-19T03:00, 2024-12-19T03:10, 2024-12-19T03:10, 2024-12-19T03:20, 2024-12-19T03:20, 2024-12-19T03:30, 2024-12-19T03:30, 2024-12-19T03:40, 2024-12-19T03:40, 2024-12-19T03:50, 2024-12-19T03:50, 2024-12-19T04:00, 2024-12-19T04:00, 2024-12-19T04:10, 2024-12-19T04:10, 2024-12-19T04:20, 2024-12-19T04:20, 2024-12-19T04:30, 2024-12-19T04:30, 2024-12-19T04:40, 2024-12-19T04:40, 2024-12-19T04:50, 2024-12-19T04:50, 2024-12-19T05:00, 2024-12-19T05:00, 2024-12-19T05:10, 2024-12-19T05:10, 2024-12-19T05:20, 2024-12-19T05:20, 2024-12-19T05: ...
# Stop 2: 2024-12-18T06:20, 2024-12-18T07:10, 2024-12-18T07:30, 2024-12-18T08:00, 2024-12-18T08:20, 2024-12-18T08:40, 2024-12-18T08:50, 2024-12-18T09:10, 2024-12-18T09:30, 2024-12-18T09:40, 2024-12-18T09:50, 2024-12-18T10:00, 2024-12-18T10:20, 2024-12-18T10:30, 2024-12-18T10:40, 2024-12-18T10:50, 2024-12-18T11:00, 2024-12-18T11:10, 2024-12-18T11:20, 2024-12-18T11:30, 2024-12-18T11:40, 2024-12-18T11:50, 2024-12-18T12:00, 2024-12-18T12:10, 2024-12-18T12:10, 2024-12-18T12:20, 2024-12-18T12:30, 2024-12-18T12:40, 2024-12-18T12:50, 2024-12-18T13:00, 2024-12-18T13:00, 2024-12-18T13:10, 2024-12-18T13:20, 2024-12-18T13:20, 2024-12-18T13:30, 2024-12-18T13:40, 2024-12-18T13:50, 2024-12-18T13:50, 2024-12-18T14:00, 2024-12-18T14:10, 2024-12-18T14:10, 2024-12-18T14:20, 2024-12-18T14:30, 2024-12-18T14:30, 2024-12-18T14:40, 2024-12-18T14:40, 2024-12-18T14:50, 2024-12-18T15:00, 2024-12-18T15:00, 2024-12-18T15:10, 2024-12-18T15:20, 2024-12-18T15:20, 2024-12-18T15:30, 2024-12-18T15:30, 2024-12-18T15:40, 2024-12-18T15:40, 2024-12-18T15:50, 2024-12-18T15:50, 2024-12-18T16:00, 2024-12-18T16:10, 2024-12-18T16:10, 2024-12-18T16:20, 2024-12-18T16:20, 2024-12-18T16:30, 2024-12-18T16:30, 2024-12-18T16:40, 2024-12-18T16:40, 2024-12-18T16:50, 2024-12-18T16:50, 2024-12-18T17:00, 2024-12-18T17:00, 2024-12-18T17:10, 2024-12-18T17:10, 2024-12-18T17:20, 2024-12-18T17:20, 2024-12-18T17:30, 2024-12-18T17:30, 2024-12-18T17:40, 2024-12-18T17:40, 2024-12-18T17:50, 2024-12-18T17:50, 2024-12-18T18:00, 2024-12-18T18:00, 2024-12-18T18:10, 2024-12-18T18:10, 2024-12-18T18:20, 2024-12-18T18:20, 2024-12-18T18:30, 2024-12-18T18:30, 2024-12-18T18:40, 2024-12-18T18:40, 2024-12-18T18:50, 2024-12-18T18:50, 2024-12-18T19:00, 2024-12-18T19:00, 2024-12-18T19:10, 2024-12-18T19:10, 2024-12-18T19:20, 2024-12-18T19:20, 2024-12-18T19:30, 2024-12-18T19:30, 2024-12-18T19:40, 2024-12-18T19:40, 2024-12-18T19:50, 2024-12-18T19:50, 2024-12-18T20:00, 2024-12-18T20:00, 2024-12-18T20:10, 2024-12-18T20:10, 2024-12-18T20:20, 2024-12-18T20:20, 2024-12-18T20:30, 2024-12-18T20:30, 2024-12-18T20:40, 2024-12-18T20:40, 2024-12-18T20:50, 2024-12-18T20:50, 2024-12-18T21:00, 2024-12-18T21:00, 2024-12-18T21:10, 2024-12-18T21:10, 2024-12-18T21:20, 2024-12-18T21:20, 2024-12-18T21:30, 2024-12-18T21:30, 2024-12-18T21:40, 2024-12-18T21:40, 2024-12-18T21:50, 2024-12-18T21:50, 2024-12-18T22:00, 2024-12-18T22:00, 2024-12-18T22:10, 2024-12-18T22:10, 2024-12-18T22:20, 2024-12-18T22:20, 2024-12-18T22:30, 2024-12-18T22:30, 2024-12-18T22:40, 2024-12-18T22:40, 2024-12-18T22:50, 2024-12-18T22:50, 2024-12-18T23:00, 2024-12-18T23:00, 2024-12-18T23:10, 2024-12-18T23:10, 2024-12-18T23:20, 2024-12-18T23:20, 2024-12-18T23:30, 2024-12-18T23:30, 2024-12-18T23:40, 2024-12-18T23:40, 2024-12-18T23:50, 2024-12-18T23:50, 2024-12-19T00:00, 2024-12-19T00:00, 2024-12-19T00:10, 2024-12-19T00:10, 2024-12-19T00:20, 2024-12-19T00:20, 2024-12-19T00:30, 2024-12-19T00:30, 2024-12-19T00:40, 2024-12-19T00:40, 2024-12-19T00:50, 2024-12-19T00:50, 2024-12-19T01:00, 2024-12-19T01:00, 2024-12-19T01:10, 2024-12-19T01:10, 2024-12-19T01:20, 2024-12-19T01:20, 2024-12-19T01:30, 2024-12-19T01:30, 2024-12-19T01:40, 2024-12-19T01:40, 2024-12-19T01:50, 2024-12-19T01:50, 2024-12-19T02:00, 2024-12-19T02:00, 2024-12-19T02:10, 2024-12-19T02:10, 2024-12-19T02:20, 2024-12-19T02:20, 2024-12-19T02:30, 2024-12-19T02:30, 2024-12-19T02:40, 2024-12-19T02:40, 2024-12-19T02:50, 2024-12-19T02:50, 2024-12-19T03:00, 2024-12-19T03:00, 2024-12-19T03:10, 2024-12-19T03:10, 2024-12-19T03:20, 2024-12-19T03:20, 2024-12-19T03:30, 2024-12-19T03:30, 2024-12-19T03:40, 2024-12-19T03:40, 2024-12-19T03:50, 2024-12-19T03:50, 2024-12-19T04:00, 2024-12-19T04:00, 2024-12-19T04:10, 2024-12-19T04:10, 2024-12-19T04:20, 2024-12-19T04:20, 2024-12-19T04:30, 2024-12-19T04:30, 2024-12-19T04:40, 2024-12-19T04:40, 2024-12-19T04:50, 2024-12-19T04:50, 2024-12-19T05:00, 2024-12-19T05:00, 2024-12-19T05:10, 2024-12-19T05:10, 2024-12-19T05:20, 2024-12-19T05:20, 2024-12-19T05:30, 2024-12-19T05:30, 2024-12-19T05: ...
# Stop 3: 2024-12-18T06:30, 2024-12-18T07:20, 2024-12-18T07:40, 2024-12-18T08:10, 2024-12-18T08:30, 2024-12-18T08:50, 2024-12-18T09:00, 2024-12-18T09:20, 2024-12-18T09:40, 2024-12-18T09:50, 2024-12-18T10:00, 2024-12-18T10:10, 2024-12-18T10:30, 2024-12-18T10:40, 2024-12-18T10:50, 2024-12-18T11:00, 2024-12-18T11:10, 2024-12-18T11:20, 2024-12-18T11:30, 2024-12-18T11:40, 2024-12-18T11:50, 2024-12-18T12:00, 2024-12-18T12:10, 2024-12-18T12:20, 2024-12-18T12:20, 2024-12-18T12:30, 2024-12-18T12:40, 2024-12-18T12:50, 2024-12-18T13:00, 2024-12-18T13:10, 2024-12-18T13:10, 2024-12-18T13:20, 2024-12-18T13:30, 2024-12-18T13:30, 2024-12-18T13:40, 2024-12-18T13:50, 2024-12-18T14:00, 2024-12-18T14:00, 2024-12-18T14:10, 2024-12-18T14:20, 2024-12-18T14:20, 2024-12-18T14:30, 2024-12-18T14:40, 2024-12-18T14:40, 2024-12-18T14:50, 2024-12-18T14:50, 2024-12-18T15:00, 2024-12-18T15:10, 2024-12-18T15:10, 2024-12-18T15:20, 2024-12-18T15:30, 2024-12-18T15:30, 2024-12-18T15:40, 2024-12-18T15:40, 2024-12-18T15:50, 2024-12-18T15:50, 2024-12-18T16:00, 2024-12-18T16:00, 2024-12-18T16:10, 2024-12-18T16:20, 2024-12-18T16:20, 2024-12-18T16:30, 2024-12-18T16:30, 2024-12-18T16:40, 2024-12-18T16:40, 2024-12-18T16:50, 2024-12-18T16:50, 2024-12-18T17:00, 2024-12-18T17:00, 2024-12-18T17:10, 2024-12-18T17:10, 2024-12-18T17:20, 2024-12-18T17:20, 2024-12-18T17:30, 2024-12-18T17:30, 2024-12-18T17:40, 2024-12-18T17:40, 2024-12-18T17:50, 2024-12-18T17:50, 2024-12-18T18:00, 2024-12-18T18:00, 2024-12-18T18:10, 2024-12-18T18:10, 2024-12-18T18:20, 2024-12-18T18:20, 2024-12-18T18:30, 2024-12-18T18:30, 2024-12-18T18:40, 2024-12-18T18:40, 2024-12-18T18:50, 2024-12-18T18:50, 2024-12-18T19:00, 2024-12-18T19:00, 2024-12-18T19:10, 2024-12-18T19:10, 2024-12-18T19:20, 2024-12-18T19:20, 2024-12-18T19:30, 2024-12-18T19:30, 2024-12-18T19:40, 2024-12-18T19:40, 2024-12-18T19:50, 2024-12-18T19:50, 2024-12-18T20:00, 2024-12-18T20:00, 2024-12-18T20:10, 2024-12-18T20:10, 2024-12-18T20:20, 2024-12-18T20:20, 2024-12-18T20:30, 2024-12-18T20:30, 2024-12-18T20:40, 2024-12-18T20:40, 2024-12-18T20:50, 2024-12-18T20:50, 2024-12-18T21:00, 2024-12-18T21:00, 2024-12-18T21:10, 2024-12-18T21:10, 2024-12-18T21:20, 2024-12-18T21:20, 2024-12-18T21:30, 2024-12-18T21:30, 2024-12-18T21:40, 2024-12-18T21:40, 2024-12-18T21:50, 2024-12-18T21:50, 2024-12-18T22:00, 2024-12-18T22:00, 2024-12-18T22:10, 2024-12-18T22:10, 2024-12-18T22:20, 2024-12-18T22:20, 2024-12-18T22:30, 2024-12-18T22:30, 2024-12-18T22:40, 2024-12-18T22:40, 2024-12-18T22:50, 2024-12-18T22:50, 2024-12-18T23:00, 2024-12-18T23:00, 2024-12-18T23:10, 2024-12-18T23:10, 2024-12-18T23:20, 2024-12-18T23:20, 2024-12-18T23:30, 2024-12-18T23:30, 2024-12-18T23:40, 2024-12-18T23:40, 2024-12-18T23:50, 2024-12-18T23:50, 2024-12-19T00:00, 2024-12-19T00:00, 2024-12-19T00:10, 2024-12-19T00:10, 2024-12-19T00:20, 2024-12-19T00:20, 2024-12-19T00:30, 2024-12-19T00:30, 2024-12-19T00:40, 2024-12-19T00:40, 2024-12-19T00:50, 2024-12-19T00:50, 2024-12-19T01:00, 2024-12-19T01:00, 2024-12-19T01:10, 2024-12-19T01:10, 2024-12-19T01:20, 2024-12-19T01:20, 2024-12-19T01:30, 2024-12-19T01:30, 2024-12-19T01:40, 2024-12-19T01:40, 2024-12-19T01:50, 2024-12-19T01:50, 2024-12-19T02:00, 2024-12-19T02:00, 2024-12-19T02:10, 2024-12-19T02:10, 2024-12-19T02:20, 2024-12-19T02:20, 2024-12-19T02:30, 2024-12-19T02:30, 2024-12-19T02:40, 2024-12-19T02:40, 2024-12-19T02:50, 2024-12-19T02:50, 2024-12-19T03:00, 2024-12-19T03:00, 2024-12-19T03:10, 2024-12-19T03:10, 2024-12-19T03:20, 2024-12-19T03:20, 2024-12-19T03:30, 2024-12-19T03:30, 2024-12-19T03:40, 2024-12-19T03:40, 2024-12-19T03:50, 2024-12-19T03:50, 2024-12-19T04:00, 2024-12-19T04:00, 2024-12-19T04:10, 2024-12-19T04:10, 2024-12-19T04:20, 2024-12-19T04:20, 2024-12-19T04:30, 2024-12-19T04:30, 2024-12-19T04:40, 2024-12-19T04:40, 2024-12-19T04:50, 2024-12-19T04:50, 2024-12-19T05:00, 2024-12-19T05:00, 2024-12-19T05:10, 2024-12-19T05:10, 2024-12-19T05:20, 2024-12-19T05:20, 2024-12-19T05:30, 2024-12-19T05:30, 2024-12-19T05:40, 2024-12-19T05:40, 2024-12-19T05: ...
# Stop 4: 2024-12-18T06:40, 2024-12-18T07:30, 2024-12-18T07:50, 2024-12-18T08:20, 2024-12-18T08:40, 2024-12-18T09:00, 2024-12-18T09:10, 2024-12-18T09:30, 2024-12-18T09:50, 2024-12-18T10:00, 2024-12-18T10:10, 2024-12-18T10:20, 2024-12-18T10:40, 2024-12-18T10:50, 2024-12-18T11:00, 2024-12-18T11:10, 2024-12-18T11:20, 2024-12-18T11:30, 2024-12-18T11:40, 2024-12-18T11:50, 2024-12-18T12:00, 2024-12-18T12:10, 2024-12-18T12:20, 2024-12-18T12:30, 2024-12-18T12:30, 2024-12-18T12:40, 2024-12-18T12:50, 2024-12-18T13:00, 2024-12-18T13:10, 2024-12-18T13:20, 2024-12-18T13:20, 2024-12-18T13:30, 2024-12-18T13:40, 2024-12-18T13:40, 2024-12-18T13:50, 2024-12-18T14:00, 2024-12-18T14:10, 2024-12-18T14:10, 2024-12-18T14:20, 2024-12-18T14:30, 2024-12-18T14:30, 2024-12-18T14:40, 2024-12-18T14:50, 2024-12-18T14:50, 2024-12-18T15:00, 2024-12-18T15:00, 2024-12-18T15:10, 2024-12-18T15:20, 2024-12-18T15:20, 2024-12-18T15:30, 2024-12-18T15:40, 2024-12-18T15:40, 2024-12-18T15:50, 2024-12-18T15:50, 2024-12-18T16:00, 2024-12-18T16:00, 2024-12-18T16:10, 2024-12-18T16:10, 2024-12-18T16:20, 2024-12-18T16:30, 2024-12-18T16:30, 2024-12-18T16:40, 2024-12-18T16:40, 2024-12-18T16:50, 2024-12-18T16:50, 2024-12-18T17:00, 2024-12-18T17:00, 2024-12-18T17:10, 2024-12-18T17:10, 2024-12-18T17:20, 2024-12-18T17:20, 2024-12-18T17:30, 2024-12-18T17:30, 2024-12-18T17:40, 2024-12-18T17:40, 2024-12-18T17:50, 2024-12-18T17:50, 2024-12-18T18:00, 2024-12-18T18:00, 2024-12-18T18:10, 2024-12-18T18:10, 2024-12-18T18:20, 2024-12-18T18:20, 2024-12-18T18:30, 2024-12-18T18:30, 2024-12-18T18:40, 2024-12-18T18:40, 2024-12-18T18:50, 2024-12-18T18:50, 2024-12-18T19:00, 2024-12-18T19:00, 2024-12-18T19:10, 2024-12-18T19:10, 2024-12-18T19:20, 2024-12-18T19:20, 2024-12-18T19:30, 2024-12-18T19:30, 2024-12-18T19:40, 2024-12-18T19:40, 2024-12-18T19:50, 2024-12-18T19:50, 2024-12-18T20:00, 2024-12-18T20:00, 2024-12-18T20:10, 2024-12-18T20:10, 2024-12-18T20:20, 2024-12-18T20:20, 2024-12-18T20:30, 2024-12-18T20:30, 2024-12-18T20:40, 2024-12-18T20:40, 2024-12-18T20:50, 2024-12-18T20:50, 2024-12-18T21:00, 2024-12-18T21:00, 2024-12-18T21:10, 2024-12-18T21:10, 2024-12-18T21:20, 2024-12-18T21:20, 2024-12-18T21:30, 2024-12-18T21:30, 2024-12-18T21:40, 2024-12-18T21:40, 2024-12-18T21:50, 2024-12-18T21:50, 2024-12-18T22:00, 2024-12-18T22:00, 2024-12-18T22:10, 2024-12-18T22:10, 2024-12-18T22:20, 2024-12-18T22:20, 2024-12-18T22:30, 2024-12-18T22:30, 2024-12-18T22:40, 2024-12-18T22:40, 2024-12-18T22:50, 2024-12-18T22:50, 2024-12-18T23:00, 2024-12-18T23:00, 2024-12-18T23:10, 2024-12-18T23:10, 2024-12-18T23:20, 2024-12-18T23:20, 2024-12-18T23:30, 2024-12-18T23:30, 2024-12-18T23:40, 2024-12-18T23:40, 2024-12-18T23:50, 2024-12-18T23:50, 2024-12-19T00:00, 2024-12-19T00:00, 2024-12-19T00:10, 2024-12-19T00:10, 2024-12-19T00:20, 2024-12-19T00:20, 2024-12-19T00:30, 2024-12-19T00:30, 2024-12-19T00:40, 2024-12-19T00:40, 2024-12-19T00:50, 2024-12-19T00:50, 2024-12-19T01:00, 2024-12-19T01:00, 2024-12-19T01:10, 2024-12-19T01:10, 2024-12-19T01:20, 2024-12-19T01:20, 2024-12-19T01:30, 2024-12-19T01:30, 2024-12-19T01:40, 2024-12-19T01:40, 2024-12-19T01:50, 2024-12-19T01:50, 2024-12-19T02:00, 2024-12-19T02:00, 2024-12-19T02:10, 2024-12-19T02:10, 2024-12-19T02:20, 2024-12-19T02:20, 2024-12-19T02:30, 2024-12-19T02:30, 2024-12-19T02:40, 2024-12-19T02:40, 2024-12-19T02:50, 2024-12-19T02:50, 2024-12-19T03:00, 2024-12-19T03:00, 2024-12-19T03:10, 2024-12-19T03:10, 2024-12-19T03:20, 2024-12-19T03:20, 2024-12-19T03:30, 2024-12-19T03:30, 2024-12-19T03:40, 2024-12-19T03:40, 2024-12-19T03:50, 2024-12-19T03:50, 2024-12-19T04:00, 2024-12-19T04:00, 2024-12-19T04:10, 2024-12-19T04:10, 2024-12-19T04:20, 2024-12-19T04:20, 2024-12-19T04:30, 2024-12-19T04:30, 2024-12-19T04:40, 2024-12-19T04:40, 2024-12-19T04:50, 2024-12-19T04:50, 2024-12-19T05:00, 2024-12-19T05:00, 2024-12-19T05:10, 2024-12-19T05:10, 2024-12-19T05:20, 2024-12-19T05:20, 2024-12-19T05:30, 2024-12-19T05:30, 2024-12-19T05:40, 2024-12-19T05:40, 2024-12-19T05:50, 2024-12-19T05:50, 2024-12-19T06: ...
# Stop 5: 2024-12-18T06:50, 2024-12-18T07:40, 2024-12-18T08:00, 2024-12-18T08:30, 2024-12-18T08:50, 2024-12-18T09:10, 2024-12-18T09:20, 2024-12-18T09:40, 2024-12-18T10:00, 2024-12-18T10:10, 2024-12-18T10:20, 2024-12-18T10:30, 2024-12-18T10:50, 2024-12-18T11:00, 2024-12-18T11:10, 2024-12-18T11:20, 2024-12-18T11:30, 2024-12-18T11:40, 2024-12-18T11:50, 2024-12-18T12:00, 2024-12-18T12:10, 2024-12-18T12:20, 2024-12-18T12:30, 2024-12-18T12:40, 2024-12-18T12:40, 2024-12-18T12:50, 2024-12-18T13:00, 2024-12-18T13:10, 2024-12-18T13:20, 2024-12-18T13:30, 2024-12-18T13:30, 2024-12-18T13:40, 2024-12-18T13:50, 2024-12-18T13:50, 2024-12-18T14:00, 2024-12-18T14:10, 2024-12-18T14:20, 2024-12-18T14:20, 2024-12-18T14:30, 2024-12-18T14:40, 2024-12-18T14:40, 2024-12-18T14:50, 2024-12-18T15:00, 2024-12-18T15:00, 2024-12-18T15:10, 2024-12-18T15:10, 2024-12-18T15:20, 2024-12-18T15:30, 2024-12-18T15:30, 2024-12-18T15:40, 2024-12-18T15:50, 2024-12-18T15:50, 2024-12-18T16:00, 2024-12-18T16:00, 2024-12-18T16:10, 2024-12-18T16:10, 2024-12-18T16:20, 2024-12-18T16:20, 2024-12-18T16:30, 2024-12-18T16:40, 2024-12-18T16:40, 2024-12-18T16:50, 2024-12-18T16:50, 2024-12-18T17:00, 2024-12-18T17:00, 2024-12-18T17:10, 2024-12-18T17:10, 2024-12-18T17:20, 2024-12-18T17:20, 2024-12-18T17:30, 2024-12-18T17:30, 2024-12-18T17:40, 2024-12-18T17:40, 2024-12-18T17:50, 2024-12-18T17:50, 2024-12-18T18:00, 2024-12-18T18:00, 2024-12-18T18:10, 2024-12-18T18:10, 2024-12-18T18:20, 2024-12-18T18:20, 2024-12-18T18:30, 2024-12-18T18:30, 2024-12-18T18:40, 2024-12-18T18:40, 2024-12-18T18:50, 2024-12-18T18:50, 2024-12-18T19:00, 2024-12-18T19:00, 2024-12-18T19:10, 2024-12-18T19:10, 2024-12-18T19:20, 2024-12-18T19:20, 2024-12-18T19:30, 2024-12-18T19:30, 2024-12-18T19:40, 2024-12-18T19:40, 2024-12-18T19:50, 2024-12-18T19:50, 2024-12-18T20:00, 2024-12-18T20:00, 2024-12-18T20:10, 2024-12-18T20:10, 2024-12-18T20:20, 2024-12-18T20:20, 2024-12-18T20:30, 2024-12-18T20:30, 2024-12-18T20:40, 2024-12-18T20:40, 2024-12-18T20:50, 2024-12-18T20:50, 2024-12-18T21:00, 2024-12-18T21:00, 2024-12-18T21:10, 2024-12-18T21:10, 2024-12-18T21:20, 2024-12-18T21:20, 2024-12-18T21:30, 2024-12-18T21:30, 2024-12-18T21:40, 2024-12-18T21:40, 2024-12-18T21:50, 2024-12-18T21:50, 2024-12-18T22:00, 2024-12-18T22:00, 2024-12-18T22:10, 2024-12-18T22:10, 2024-12-18T22:20, 2024-12-18T22:20, 2024-12-18T22:30, 2024-12-18T22:30, 2024-12-18T22:40, 2024-12-18T22:40, 2024-12-18T22:50, 2024-12-18T22:50, 2024-12-18T23:00, 2024-12-18T23:00, 2024-12-18T23:10, 2024-12-18T23:10, 2024-12-18T23:20, 2024-12-18T23:20, 2024-12-18T23:30, 2024-12-18T23:30, 2024-12-18T23:40, 2024-12-18T23:40, 2024-12-18T23:50, 2024-12-18T23:50, 2024-12-19T00:00, 2024-12-19T00:00, 2024-12-19T00:10, 2024-12-19T00:10, 2024-12-19T00:20, 2024-12-19T00:20, 2024-12-19T00:30, 2024-12-19T00:30, 2024-12-19T00:40, 2024-12-19T00:40, 2024-12-19T00:50, 2024-12-19T00:50, 2024-12-19T01:00, 2024-12-19T01:00, 2024-12-19T01:10, 2024-12-19T01:10, 2024-12-19T01:20, 2024-12-19T01:20, 2024-12-19T01:30, 2024-12-19T01:30, 2024-12-19T01:40, 2024-12-19T01:40, 2024-12-19T01:50, 2024-12-19T01:50, 2024-12-19T02:00, 2024-12-19T02:00, 2024-12-19T02:10, 2024-12-19T02:10, 2024-12-19T02:20, 2024-12-19T02:20, 2024-12-19T02:30, 2024-12-19T02:30, 2024-12-19T02:40, 2024-12-19T02:40, 2024-12-19T02:50, 2024-12-19T02:50, 2024-12-19T03:00, 2024-12-19T03:00, 2024-12-19T03:10, 2024-12-19T03:10, 2024-12-19T03:20, 2024-12-19T03:20, 2024-12-19T03:30, 2024-12-19T03:30, 2024-12-19T03:40, 2024-12-19T03:40, 2024-12-19T03:50, 2024-12-19T03:50, 2024-12-19T04:00, 2024-12-19T04:00, 2024-12-19T04:10, 2024-12-19T04:10, 2024-12-19T04:20, 2024-12-19T04:20, 2024-12-19T04:30, 2024-12-19T04:30, 2024-12-19T04:40, 2024-12-19T04:40, 2024-12-19T04:50, 2024-12-19T04:50, 2024-12-19T05:00, 2024-12-19T05:00, 2024-12-19T05:10, 2024-12-19T05:10, 2024-12-19T05:20, 2024-12-19T05:20, 2024-12-19T05:30, 2024-12-19T05:30, 2024-12-19T05:40, 2024-12-19T05:40, 2024-12-19T05:50, 2024-12-19T05:50, 2024-12-19T06:00, 2024-12-19T06:00, 2024-12-19T06: ...
# Stop 6: 2024-12-18T07:00, 2024-12-18T07:50, 2024-12-18T08:10, 2024-12-18T08:40, 2024-12-18T09:00, 2024-12-18T09:20, 2024-12-18T09:30, 2024-12-18T09:50, 2024-12-18T10:10, 2024-12-18T10:20, 2024-12-18T10:30, 2024-12-18T10:40, 2024-12-18T11:00, 2024-12-18T11:10, 2024-12-18T11:20, 2024-12-18T11:30, 2024-12-18T11:40, 2024-12-18T11:50, 2024-12-18T12:00, 2024-12-18T12:10, 2024-12-18T12:20, 2024-12-18T12:30, 2024-12-18T12:40, 2024-12-18T12:50, 2024-12-18T12:50, 2024-12-18T13:00, 2024-12-18T13:10, 2024-12-18T13:20, 2024-12-18T13:30, 2024-12-18T13:40, 2024-12-18T13:40, 2024-12-18T13:50, 2024-12-18T14:00, 2024-12-18T14:00, 2024-12-18T14:10, 2024-12-18T14:20, 2024-12-18T14:30, 2024-12-18T14:30, 2024-12-18T14:40, 2024-12-18T14:50, 2024-12-18T14:50, 2024-12-18T15:00, 2024-12-18T15:10, 2024-12-18T15:10, 2024-12-18T15:20, 2024-12-18T15:20, 2024-12-18T15:30, 2024-12-18T15:40, 2024-12-18T15:40, 2024-12-18T15:50, 2024-12-18T16:00, 2024-12-18T16:00, 2024-12-18T16:10, 2024-12-18T16:10, 2024-12-18T16:20, 2024-12-18T16:20, 2024-12-18T16:30, 2024-12-18T16:30, 2024-12-18T16:40, 2024-12-18T16:50, 2024-12-18T16:50, 2024-12-18T17:00, 2024-12-18T17:00, 2024-12-18T17:10, 2024-12-18T17:10, 2024-12-18T17:20, 2024-12-18T17:20, 2024-12-18T17:30, 2024-12-18T17:30, 2024-12-18T17:40, 2024-12-18T17:40, 2024-12-18T17:50, 2024-12-18T17:50, 2024-12-18T18:00, 2024-12-18T18:00, 2024-12-18T18:10, 2024-12-18T18:10, 2024-12-18T18:20, 2024-12-18T18:20, 2024-12-18T18:30, 2024-12-18T18:30, 2024-12-18T18:40, 2024-12-18T18:40, 2024-12-18T18:50, 2024-12-18T18:50, 2024-12-18T19:00, 2024-12-18T19:00, 2024-12-18T19:10, 2024-12-18T19:10, 2024-12-18T19:20, 2024-12-18T19:20, 2024-12-18T19:30, 2024-12-18T19:30, 2024-12-18T19:40, 2024-12-18T19:40, 2024-12-18T19:50, 2024-12-18T19:50, 2024-12-18T20:00, 2024-12-18T20:00, 2024-12-18T20:10, 2024-12-18T20:10, 2024-12-18T20:20, 2024-12-18T20:20, 2024-12-18T20:30, 2024-12-18T20:30, 2024-12-18T20:40, 2024-12-18T20:40, 2024-12-18T20:50, 2024-12-18T20:50, 2024-12-18T21:00, 2024-12-18T21:00, 2024-12-18T21:10, 2024-12-18T21:10, 2024-12-18T21:20, 2024-12-18T21:20, 2024-12-18T21:30, 2024-12-18T21:30, 2024-12-18T21:40, 2024-12-18T21:40, 2024-12-18T21:50, 2024-12-18T21:50, 2024-12-18T22:00, 2024-12-18T22:00, 2024-12-18T22:10, 2024-12-18T22:10, 2024-12-18T22:20, 2024-12-18T22:20, 2024-12-18T22:30, 2024-12-18T22:30, 2024-12-18T22:40, 2024-12-18T22:40, 2024-12-18T22:50, 2024-12-18T22:50, 2024-12-18T23:00, 2024-12-18T23:00, 2024-12-18T23:10, 2024-12-18T23:10, 2024-12-18T23:20, 2024-12-18T23:20, 2024-12-18T23:30, 2024-12-18T23:30, 2024-12-18T23:40, 2024-12-18T23:40, 2024-12-18T23:50, 2024-12-18T23:50, 2024-12-19T00:00, 2024-12-19T00:00, 2024-12-19T00:10, 2024-12-19T00:10, 2024-12-19T00:20, 2024-12-19T00:20, 2024-12-19T00:30, 2024-12-19T00:30, 2024-12-19T00:40, 2024-12-19T00:40, 2024-12-19T00:50, 2024-12-19T00:50, 2024-12-19T01:00, 2024-12-19T01:00, 2024-12-19T01:10, 2024-12-19T01:10, 2024-12-19T01:20, 2024-12-19T01:20, 2024-12-19T01:30, 2024-12-19T01:30, 2024-12-19T01:40, 2024-12-19T01:40, 2024-12-19T01:50, 2024-12-19T01:50, 2024-12-19T02:00, 2024-12-19T02:00, 2024-12-19T02:10, 2024-12-19T02:10, 2024-12-19T02:20, 2024-12-19T02:20, 2024-12-19T02:30, 2024-12-19T02:30, 2024-12-19T02:40, 2024-12-19T02:40, 2024-12-19T02:50, 2024-12-19T02:50, 2024-12-19T03:00, 2024-12-19T03:00, 2024-12-19T03:10, 2024-12-19T03:10, 2024-12-19T03:20, 2024-12-19T03:20, 2024-12-19T03:30, 2024-12-19T03:30, 2024-12-19T03:40, 2024-12-19T03:40, 2024-12-19T03:50, 2024-12-19T03:50, 2024-12-19T04:00, 2024-12-19T04:00, 2024-12-19T04:10, 2024-12-19T04:10, 2024-12-19T04:20, 2024-12-19T04:20, 2024-12-19T04:30, 2024-12-19T04:30, 2024-12-19T04:40, 2024-12-19T04:40, 2024-12-19T04:50, 2024-12-19T04:50, 2024-12-19T05:00, 2024-12-19T05:00, 2024-12-19T05:10, 2024-12-19T05:10, 2024-12-19T05:20, 2024-12-19T05:20, 2024-12-19T05:30, 2024-12-19T05:30, 2024-12-19T05:40, 2024-12-19T05:40, 2024-12-19T05:50, 2024-12-19T05:50, 2024-12-19T06:00, 2024-12-19T06:00, 2024-12-19T06:10, 2024-12-19T06:10, 2024-12-19T06: ...
# Saved Stop 0 (Weekday) schedule to file: weekday_schedule_Stop_0_Weekday.csv
# Saved Stop 1 (Weekday) schedule to file: weekday_schedule_Stop_1_Weekday.csv
# Saved Stop 2 (Weekday) schedule to file: weekday_schedule_Stop_2_Weekday.csv
# Saved Stop 3 (Weekday) schedule to file: weekday_schedule_Stop_3_Weekday.csv
# Saved Stop 4 (Weekday) schedule to file: weekday_schedule_Stop_4_Weekday.csv
# Saved Stop 5 (Weekday) schedule to file: weekday_schedule_Stop_5_Weekday.csv
# Saved Stop 6 (Weekday) schedule to file: weekday_schedule_Stop_6_Weekday.csv
# Saved Stop 0 (Weekend) schedule to file: weekend_schedule_Stop_0_Weekend.csv
# Saved Stop 1 (Weekend) schedule to file: weekend_schedule_Stop_1_Weekend.csv
# Saved Stop 2 (Weekend) schedule to file: weekend_schedule_Stop_2_Weekend.csv
# Saved Stop 3 (Weekend) schedule to file: weekend_schedule_Stop_3_Weekend.csv
# Saved Stop 4 (Weekend) schedule to file: weekend_schedule_Stop_4_Weekend.csv
# Saved Stop 5 (Weekend) schedule to file: weekend_schedule_Stop_5_Weekend.csv
# Saved Stop 6 (Weekend) schedule to file: weekend_schedule_Stop_6_Weekend.csv
