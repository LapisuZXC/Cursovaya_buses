# %%
import random
import numpy as np
import time
from datetime import timedelta, datetime


class BusStop:
    def __init__(self, passengers_waiting: int):
        self.passengers_waiting = passengers_waiting

    def board_passengers(self, available_seats: int) -> int:
        board_count = min(self.passengers_waiting, available_seats)
        self.passengers_waiting -= board_count
        return board_count

    def add_passengers(self, peak: bool):
        chance = random.random()
        if peak:
            if chance < 0.7:  # Higher probability during peak
                self.passengers_waiting += random.randint(3, 7)
        else:
            if chance < 0.3:  # Lower probability off-peak
                self.passengers_waiting += random.randint(1, 3)

class Route:
    def __init__(self, bus_stops_num: int, route_duration: int, peak: bool, upper_limit: int):
        self.num_stops = bus_stops_num
        self.time_between_stops = route_duration // bus_stops_num  # Calculate average time between stops
        self.bus_stops = [
            BusStop(random.randint(0, int(upper_limit * (0.7 if peak else 0.3))))
            for _ in range(bus_stops_num)
        ]
class Driver:
    def __init__(self, name: str, shift_duration: int, break_duration: int, schedule_type: str):
        self.name = name
        self.shift_duration = shift_duration
        self.break_duration = break_duration
        self.schedule_type = schedule_type  # "standard" or "night"
        self.time_worked = 0
        self.on_break = False
        self.break_time_remaining = 0

    def work(self, is_peak: bool = False):
        if self.on_break:
            self.break_time_remaining -= 1
            if self.break_time_remaining <= 0:
                self.on_break = False
            return False

        self.time_worked += 1

        if self.schedule_type == "standard":
            if self.time_worked >= self.shift_duration:
                self.start_break()
        elif self.schedule_type == "night":
            if self.time_worked % 120 == 0 and not is_peak:  # 2 hours of work, no breaks during peak
                self.start_break()
        return True

    def start_break(self):
        self.on_break = True
        self.break_time_remaining = self.break_duration
        self.time_worked = 0 if self.schedule_type == "standard" else self.time_worked  # Reset only for standard
class Bus:
    def __init__(self, capacity: int = 20, driver: Driver = None):
        self.capacity = capacity
        self.currently_onboard = 0
        self.driver = driver

    def load_passengers(self, bus_stop):
        if self.driver and not self.driver.work():
            #print(f"Driver {self.driver.name} is on break. Bus cannot load passengers.")
            return 0

        available_seats = self.capacity - self.currently_onboard
        boarding_passengers = bus_stop.board_passengers(available_seats=available_seats)
        self.currently_onboard += boarding_passengers
        return boarding_passengers

    def unload_all_passengers(self):
        exiting_passengers = self.currently_onboard
        self.currently_onboard = 0
        return exiting_passengers
class Simulation:
    def __init__(
        self,
        bus_num: int,
        route_duration: int,
        bus_stops_num: int,
        start_time: np.datetime64,
        end_time: np.datetime64,
        tag: str,
        driver_schedule_type: str,
        driver_shift_duration: int,
        driver_break_duration: int,
    ):
        self.tag = tag
        self.tick = 0
        self.route = Route(bus_stops_num, route_duration, tag in {"monday", "tuesday", "wednesday", "thursday", "friday"}, 100)
        self.time_between_stops = self.route.time_between_stops
        self.end_tick = ((end_time - start_time).astype("timedelta64[m]").item().seconds // self.time_between_stops)
        self.drivers = [
            Driver(
                name=f"Driver {i}",
                shift_duration=driver_shift_duration,
                break_duration=driver_break_duration,
                schedule_type=driver_schedule_type,
            )
            for i in range(bus_num)
        ]
        self.buses = [Bus(driver=self.drivers[i]) for i in range(bus_num)]
        self.bus_positions = [0 for _ in range(bus_num)]
        self.bus_intervals = route_duration // bus_num
        self.start_time = start_time

        self.schedule = {i: [] for i in range(self.route.num_stops)}
        self.bus_start_ticks = [i * self.bus_intervals for i in range(bus_num)]

    def play_simulation(self):
        total_passengers_dropped = 0
        while self.tick < self.end_tick:
            current_time_in_seconds = int((self.start_time + np.timedelta64(self.tick * self.time_between_stops, 'm')).astype("timedelta64[s]").item().seconds % 86400)
            current_hour = current_time_in_seconds // 3600
            is_peak = (7 <= current_hour < 9) or (17 <= current_hour < 19)

            for stop in self.route.bus_stops:
                stop.add_passengers(peak=is_peak if self.tag not in {"saturday", "sunday"} else random.random() < 0.5)

            for i, bus in enumerate(self.buses):
                if self.tick < self.bus_start_ticks[i]:
                    continue

                stop_index = self.bus_positions[i]
                current_time = self.start_time + np.timedelta64(self.tick * self.time_between_stops, 'm')
                self.schedule[stop_index].append(str(current_time))

                if stop_index == len(self.route.bus_stops) - 1:
                    total_passengers_dropped += bus.unload_all_passengers()

                if not bus.driver.work(is_peak):
                    continue

                boarding = bus.load_passengers(self.route.bus_stops[stop_index])
                self.bus_positions[i] = (stop_index + 1) % self.route.num_stops

            self.tick += 1

        remaining_passengers = sum(stop.passengers_waiting for stop in self.route.bus_stops)
        print(f"Simulation finished. Total passengers dropped: {total_passengers_dropped}. Remaining passengers: {remaining_passengers}.")

    def print_schedule(self):
        print("\nBus Schedule:")
        for stop, times in self.schedule.items():
            print(f"Stop {stop}: {', '.join(times)}")

def simulate_with_parameters(bus_num, driver_num, driver_schedule_type, route_duration, bus_stops_num, start_time, end_time, driver_shift_duration, driver_break_duration):
    if driver_num < bus_num: 
        return float("inf") 
    sim = Simulation(
        bus_num=bus_num,
        route_duration=route_duration,
        bus_stops_num=bus_stops_num,
        start_time=start_time,
        end_time=end_time,
        tag="monday",  # Use weekday for peak load
        driver_schedule_type=driver_schedule_type,
        driver_shift_duration=driver_shift_duration,
        driver_break_duration=driver_break_duration,
    )
    sim.play_simulation()

    remaining_passengers = sum(stop.passengers_waiting for stop in sim.route.bus_stops)
    return remaining_passengers

def brute_force_optimization(route_duration, bus_stops_num, start_time, end_time, driver_shift_duration, driver_break_duration):
    best_bus_num = None
    best_driver_num = None
    min_remaining_passengers = float("inf")
    start_time_exec = time.time()

    with open("brute_force_results.txt", "w") as f, open("best_results_brute_force.txt", "w") as best_f:
        for bus_num in range(8, 21):
            for driver_num in range(bus_num, 21):  # Ensure drivers >= buses
                for schedule_type in ["standard", "night"]:
                    remaining_passengers = simulate_with_parameters(
                        bus_num=bus_num,
                        driver_num=driver_num,
                        driver_schedule_type=schedule_type,
                        route_duration=route_duration,
                        bus_stops_num=bus_stops_num,
                        start_time=start_time,
                        end_time=end_time,
                        driver_shift_duration=driver_shift_duration,
                        driver_break_duration=driver_break_duration,
                    )

                    if remaining_passengers < min_remaining_passengers:
                        best_bus_num = bus_num
                        best_driver_num = driver_num
                        min_remaining_passengers = remaining_passengers

                    f.write(f"Buses: {bus_num}, Drivers: {driver_num}, Type: {schedule_type}, Remaining: {remaining_passengers}\n")

        exec_time = time.time() - start_time_exec
        best_f.write(f"Best Buses: {best_bus_num}, Best Drivers: {best_driver_num}, Execution Time: {exec_time:.2f} seconds\n")
    return best_bus_num, best_driver_num

def genetic_algorithm_optimization(
    route_duration, 
    bus_stops_num, 
    start_time, 
    end_time, 
    driver_shift_duration, 
    driver_break_duration, 
    population_size=10, 
    generations=50, 
    patience=10, 
    log_file="genetic_algorithm_log.txt"
):
    start_time_exec = time.time()

    population = [
        {
            "bus_num": random.randint(1, 20),
            "driver_num": random.randint(1, 20),
            "schedule_type": random.choice(["standard", "night"]),
        }
        for _ in range(population_size)
    ]

    best_solution = None
    best_fitness = float("inf")
    generations_without_improvement = 0

    with open(log_file, "w") as log, open("best_results_genetic_algorithm.txt", "w") as best_f:
        log.write("Generation,Bus_Num,Driver_Num,Schedule_Type,Remaining_Passengers\n")

        for generation in range(generations):
            fitness_scores = []
            for individual in population:
                if individual["driver_num"] < individual["bus_num"]:  # Ensure drivers >= buses
                    fitness_scores.append((individual, float("inf")))
                    continue

                remaining_passengers = simulate_with_parameters(
                    bus_num=individual["bus_num"],
                    driver_num=individual["driver_num"],
                    driver_schedule_type=individual["schedule_type"],
                    route_duration=route_duration,
                    bus_stops_num=bus_stops_num,
                    start_time=start_time,
                    end_time=end_time,
                    driver_shift_duration=driver_shift_duration,
                    driver_break_duration=driver_break_duration,
                )

                fitness_scores.append((individual, remaining_passengers))

                if remaining_passengers < best_fitness:
                    best_solution = individual
                    best_fitness = remaining_passengers
                    generations_without_improvement = 0

            fitness_scores.sort(key=lambda x: x[1])

            top_individuals = [fs[0] for fs in fitness_scores[: population_size // 2]]

            new_population = []
            for _ in range(population_size):
                parent1, parent2 = random.sample(top_individuals, 2)
                child = {
                    "bus_num": max(1, (parent1["bus_num"] + parent2["bus_num"]) // 2),
                    "driver_num": max(parent1["bus_num"], (parent1["driver_num"] + parent2["driver_num"]) // 2),
                    "schedule_type": random.choice([parent1["schedule_type"], parent2["schedule_type"]]),
                }

                if random.random() < 0.1:
                    child["bus_num"] = max(1, min(20, child["bus_num"] + random.choice([-1, 1])))
                    child["driver_num"] = max(child["bus_num"], min(20, child["driver_num"] + random.choice([-1, 1])))

                new_population.append(child)

            population = new_population
            generations_without_improvement += 1

            if generations_without_improvement >= patience:
                break

        exec_time = time.time() - start_time_exec
        best_f.write(f"Best Solution: {best_solution}, Execution Time: {exec_time:.2f} seconds\n")

    return best_solution

route_duration = 70
bus_stops_num = 7
start_time = np.datetime64('2024-12-14T06:00')
end_time = np.datetime64('2024-12-15T03:00')
driver_shift_duration = 420
driver_break_duration = 60

best_bus_num, best_driver_num = brute_force_optimization(
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
)
print(f"Best configuration from brute force: Buses = {best_bus_num}, Drivers = {best_driver_num}")

best_solution = genetic_algorithm_optimization(
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
)
print(f"Best configuration from genetic algorithm: {best_solution}")
# Out:
# Simulation finished. Total passengers dropped: 58830. Remaining passengers: 2679.
# Simulation finished. Total passengers dropped: 53095. Remaining passengers: 7816.
# Simulation finished. Total passengers dropped: 58050. Remaining passengers: 2888.
# Simulation finished. Total passengers dropped: 53352. Remaining passengers: 8071.
# Simulation finished. Total passengers dropped: 59165. Remaining passengers: 2756.
# Simulation finished. Total passengers dropped: 53086. Remaining passengers: 8209.
# Simulation finished. Total passengers dropped: 58337. Remaining passengers: 2592.
# Simulation finished. Total passengers dropped: 53016. Remaining passengers: 8246.
# Simulation finished. Total passengers dropped: 58357. Remaining passengers: 2922.
# Simulation finished. Total passengers dropped: 52706. Remaining passengers: 8065.
# Simulation finished. Total passengers dropped: 58357. Remaining passengers: 2387.
# Simulation finished. Total passengers dropped: 52930. Remaining passengers: 8495.
# Simulation finished. Total passengers dropped: 58476. Remaining passengers: 2667.
# Simulation finished. Total passengers dropped: 53259. Remaining passengers: 7988.
# Simulation finished. Total passengers dropped: 58017. Remaining passengers: 2480.
# Simulation finished. Total passengers dropped: 53559. Remaining passengers: 8324.
# Simulation finished. Total passengers dropped: 58504. Remaining passengers: 2599.
# Simulation finished. Total passengers dropped: 53672. Remaining passengers: 7986.
# Simulation finished. Total passengers dropped: 58118. Remaining passengers: 2777.
# Simulation finished. Total passengers dropped: 53056. Remaining passengers: 7960.
# Simulation finished. Total passengers dropped: 58453. Remaining passengers: 2841.
# Simulation finished. Total passengers dropped: 52889. Remaining passengers: 8251.
# Simulation finished. Total passengers dropped: 58727. Remaining passengers: 2886.
# Simulation finished. Total passengers dropped: 53495. Remaining passengers: 8152.
# Simulation finished. Total passengers dropped: 58371. Remaining passengers: 2828.
# Simulation finished. Total passengers dropped: 53464. Remaining passengers: 8173.
# Simulation finished. Total passengers dropped: 60731. Remaining passengers: 673.
# Simulation finished. Total passengers dropped: 54388. Remaining passengers: 7226.
# Simulation finished. Total passengers dropped: 60072. Remaining passengers: 1250.
# Simulation finished. Total passengers dropped: 53933. Remaining passengers: 6847.
# Simulation finished. Total passengers dropped: 59694. Remaining passengers: 765.
# Simulation finished. Total passengers dropped: 54045. Remaining passengers: 7031.
# Simulation finished. Total passengers dropped: 60144. Remaining passengers: 680.
# Simulation finished. Total passengers dropped: 53999. Remaining passengers: 6806.
# Simulation finished. Total passengers dropped: 60688. Remaining passengers: 772.
# Simulation finished. Total passengers dropped: 53622. Remaining passengers: 7047.
# Simulation finished. Total passengers dropped: 60089. Remaining passengers: 732.
# Simulation finished. Total passengers dropped: 54908. Remaining passengers: 6929.
# Simulation finished. Total passengers dropped: 60388. Remaining passengers: 875.
# Simulation finished. Total passengers dropped: 54129. Remaining passengers: 7273.
# Simulation finished. Total passengers dropped: 60205. Remaining passengers: 1017.
# Simulation finished. Total passengers dropped: 54315. Remaining passengers: 6934.
# Simulation finished. Total passengers dropped: 60839. Remaining passengers: 852.
# Simulation finished. Total passengers dropped: 54488. Remaining passengers: 6758.
# Simulation finished. Total passengers dropped: 60115. Remaining passengers: 784.
# Simulation finished. Total passengers dropped: 54063. Remaining passengers: 6749.
# Simulation finished. Total passengers dropped: 60164. Remaining passengers: 670.
# Simulation finished. Total passengers dropped: 54172. Remaining passengers: 7197.
# Simulation finished. Total passengers dropped: 60729. Remaining passengers: 605.
# Simulation finished. Total passengers dropped: 54021. Remaining passengers: 7006.
# Simulation finished. Total passengers dropped: 60177. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 55754. Remaining passengers: 5517.
# Simulation finished. Total passengers dropped: 61401. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 55102. Remaining passengers: 5491.
# Simulation finished. Total passengers dropped: 60868. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 55415. Remaining passengers: 5397.
# Simulation finished. Total passengers dropped: 60794. Remaining passengers: 7.
# Simulation finished. Total passengers dropped: 55266. Remaining passengers: 5424.
# Simulation finished. Total passengers dropped: 60723. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 55156. Remaining passengers: 5485.
# Simulation finished. Total passengers dropped: 60861. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 55660. Remaining passengers: 5325.
# Simulation finished. Total passengers dropped: 61102. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 55834. Remaining passengers: 5380.
# Simulation finished. Total passengers dropped: 61694. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 55763. Remaining passengers: 5676.
# Simulation finished. Total passengers dropped: 60614. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 56019. Remaining passengers: 5836.
# Simulation finished. Total passengers dropped: 61467. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 55596. Remaining passengers: 5777.
# Simulation finished. Total passengers dropped: 60944. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 55876. Remaining passengers: 5508.
# Simulation finished. Total passengers dropped: 61031. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 56540. Remaining passengers: 4236.
# Simulation finished. Total passengers dropped: 61415. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 57032. Remaining passengers: 4571.
# Simulation finished. Total passengers dropped: 61301. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 56523. Remaining passengers: 3977.
# Simulation finished. Total passengers dropped: 61802. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 56930. Remaining passengers: 4378.
# Simulation finished. Total passengers dropped: 61473. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 57318. Remaining passengers: 4078.
# Simulation finished. Total passengers dropped: 61034. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 56950. Remaining passengers: 4275.
# Simulation finished. Total passengers dropped: 61476. Remaining passengers: 28.
# Simulation finished. Total passengers dropped: 56482. Remaining passengers: 4322.
# Simulation finished. Total passengers dropped: 61357. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 56496. Remaining passengers: 4518.
# Simulation finished. Total passengers dropped: 61568. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 57222. Remaining passengers: 4333.
# Simulation finished. Total passengers dropped: 61288. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 56548. Remaining passengers: 4657.
# Simulation finished. Total passengers dropped: 61403. Remaining passengers: 33.
# Simulation finished. Total passengers dropped: 58261. Remaining passengers: 3356.
# Simulation finished. Total passengers dropped: 60798. Remaining passengers: 35.
# Simulation finished. Total passengers dropped: 57536. Remaining passengers: 3313.
# Simulation finished. Total passengers dropped: 60967. Remaining passengers: 43.
# Simulation finished. Total passengers dropped: 58218. Remaining passengers: 3089.
# Simulation finished. Total passengers dropped: 61995. Remaining passengers: 42.
# Simulation finished. Total passengers dropped: 58241. Remaining passengers: 3153.
# Simulation finished. Total passengers dropped: 61215. Remaining passengers: 36.
# Simulation finished. Total passengers dropped: 57891. Remaining passengers: 3083.
# Simulation finished. Total passengers dropped: 61626. Remaining passengers: 55.
# Simulation finished. Total passengers dropped: 57920. Remaining passengers: 3283.
# Simulation finished. Total passengers dropped: 61181. Remaining passengers: 46.
# Simulation finished. Total passengers dropped: 58063. Remaining passengers: 3002.
# Simulation finished. Total passengers dropped: 61519. Remaining passengers: 41.
# Simulation finished. Total passengers dropped: 58375. Remaining passengers: 3193.
# Simulation finished. Total passengers dropped: 61308. Remaining passengers: 50.
# Simulation finished. Total passengers dropped: 58235. Remaining passengers: 3188.
# Simulation finished. Total passengers dropped: 61628. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 59600. Remaining passengers: 1685.
# Simulation finished. Total passengers dropped: 60715. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 59440. Remaining passengers: 1684.
# Simulation finished. Total passengers dropped: 61199. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 59433. Remaining passengers: 2081.
# Simulation finished. Total passengers dropped: 61022. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 59399. Remaining passengers: 2011.
# Simulation finished. Total passengers dropped: 61401. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 59339. Remaining passengers: 1668.
# Simulation finished. Total passengers dropped: 60968. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 59430. Remaining passengers: 1555.
# Simulation finished. Total passengers dropped: 61696. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 59244. Remaining passengers: 1935.
# Simulation finished. Total passengers dropped: 61350. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 59429. Remaining passengers: 1767.
# Simulation finished. Total passengers dropped: 61316. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 60819. Remaining passengers: 436.
# Simulation finished. Total passengers dropped: 60868. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 60053. Remaining passengers: 367.
# Simulation finished. Total passengers dropped: 60932. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 61002. Remaining passengers: 499.
# Simulation finished. Total passengers dropped: 61197. Remaining passengers: 4.
# Simulation finished. Total passengers dropped: 60658. Remaining passengers: 882.
# Simulation finished. Total passengers dropped: 60685. Remaining passengers: 4.
# Simulation finished. Total passengers dropped: 60585. Remaining passengers: 747.
# Simulation finished. Total passengers dropped: 61586. Remaining passengers: 7.
# Simulation finished. Total passengers dropped: 61075. Remaining passengers: 542.
# Simulation finished. Total passengers dropped: 61294. Remaining passengers: 3.
# Simulation finished. Total passengers dropped: 60447. Remaining passengers: 384.
# Simulation finished. Total passengers dropped: 61671. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 61473. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 61610. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 61318. Remaining passengers: 33.
# Simulation finished. Total passengers dropped: 60350. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 60966. Remaining passengers: 36.
# Simulation finished. Total passengers dropped: 61041. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 61375. Remaining passengers: 44.
# Simulation finished. Total passengers dropped: 61164. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61237. Remaining passengers: 38.
# Simulation finished. Total passengers dropped: 61115. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 60918. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 60767. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61328. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60608. Remaining passengers: 7.
# Simulation finished. Total passengers dropped: 61104. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 60943. Remaining passengers: 4.
# Simulation finished. Total passengers dropped: 61340. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61499. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 60691. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61416. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61114. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 60925. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 61203. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 61498. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 61651. Remaining passengers: 1.
# Simulation finished. Total passengers dropped: 61190. Remaining passengers: 2.
# Simulation finished. Total passengers dropped: 61263. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 61374. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 60973. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 61459. Remaining passengers: 40.
# Simulation finished. Total passengers dropped: 61454. Remaining passengers: 62.
# Simulation finished. Total passengers dropped: 61900. Remaining passengers: 35.
# Simulation finished. Total passengers dropped: 61474. Remaining passengers: 47.
# Simulation finished. Total passengers dropped: 61473. Remaining passengers: 68.
# Simulation finished. Total passengers dropped: 61022. Remaining passengers: 50.
# Simulation finished. Total passengers dropped: 61362. Remaining passengers: 35.
# Simulation finished. Total passengers dropped: 61420. Remaining passengers: 42.
# Simulation finished. Total passengers dropped: 61070. Remaining passengers: 39.
# Simulation finished. Total passengers dropped: 60992. Remaining passengers: 35.
# Simulation finished. Total passengers dropped: 61164. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61346. Remaining passengers: 30.
# Best configuration from brute force: Buses = 17, Drivers = 18
# Simulation finished. Total passengers dropped: 50814. Remaining passengers: 10633.
# Simulation finished. Total passengers dropped: 50202. Remaining passengers: 10969.
# Simulation finished. Total passengers dropped: 60847. Remaining passengers: 30.
# Simulation finished. Total passengers dropped: 10800. Remaining passengers: 50478.
# Simulation finished. Total passengers dropped: 49360. Remaining passengers: 11988.
# Simulation finished. Total passengers dropped: 32370. Remaining passengers: 28502.
# Simulation finished. Total passengers dropped: 32206. Remaining passengers: 29029.
# Simulation finished. Total passengers dropped: 55454. Remaining passengers: 5658.
# Simulation finished. Total passengers dropped: 53095. Remaining passengers: 8488.
# Simulation finished. Total passengers dropped: 55008. Remaining passengers: 5362.
# Simulation finished. Total passengers dropped: 21600. Remaining passengers: 39847.
# Simulation finished. Total passengers dropped: 55575. Remaining passengers: 5403.
# Simulation finished. Total passengers dropped: 33165. Remaining passengers: 27704.
# Simulation finished. Total passengers dropped: 53107. Remaining passengers: 8494.
# Simulation finished. Total passengers dropped: 53374. Remaining passengers: 7920.
# Simulation finished. Total passengers dropped: 55854. Remaining passengers: 5603.
# Simulation finished. Total passengers dropped: 54267. Remaining passengers: 6794.
# Simulation finished. Total passengers dropped: 54081. Remaining passengers: 6768.
# Simulation finished. Total passengers dropped: 55470. Remaining passengers: 5581.
# Simulation finished. Total passengers dropped: 54189. Remaining passengers: 6749.
# Simulation finished. Total passengers dropped: 55742. Remaining passengers: 5592.
# Simulation finished. Total passengers dropped: 54169. Remaining passengers: 6912.
# Simulation finished. Total passengers dropped: 55850. Remaining passengers: 5585.
# Simulation finished. Total passengers dropped: 56289. Remaining passengers: 5547.
# Simulation finished. Total passengers dropped: 54086. Remaining passengers: 6868.
# Simulation finished. Total passengers dropped: 55170. Remaining passengers: 5576.
# Simulation finished. Total passengers dropped: 55613. Remaining passengers: 5631.
# Simulation finished. Total passengers dropped: 55692. Remaining passengers: 5673.
# Simulation finished. Total passengers dropped: 57082. Remaining passengers: 4443.
# Simulation finished. Total passengers dropped: 55733. Remaining passengers: 5648.
# Simulation finished. Total passengers dropped: 55260. Remaining passengers: 5683.
# Simulation finished. Total passengers dropped: 56246. Remaining passengers: 5380.
# Simulation finished. Total passengers dropped: 55400. Remaining passengers: 5903.
# Simulation finished. Total passengers dropped: 55779. Remaining passengers: 5748.
# Simulation finished. Total passengers dropped: 55377. Remaining passengers: 5525.
# Simulation finished. Total passengers dropped: 56477. Remaining passengers: 4439.
# Simulation finished. Total passengers dropped: 55630. Remaining passengers: 5645.
# Simulation finished. Total passengers dropped: 55664. Remaining passengers: 5558.
# Simulation finished. Total passengers dropped: 55632. Remaining passengers: 5917.
# Simulation finished. Total passengers dropped: 55829. Remaining passengers: 5455.
# Simulation finished. Total passengers dropped: 55599. Remaining passengers: 5681.
# Simulation finished. Total passengers dropped: 55767. Remaining passengers: 5731.
# Simulation finished. Total passengers dropped: 55515. Remaining passengers: 5405.
# Simulation finished. Total passengers dropped: 55594. Remaining passengers: 5936.
# Simulation finished. Total passengers dropped: 55542. Remaining passengers: 5651.
# Simulation finished. Total passengers dropped: 55676. Remaining passengers: 5571.
# Simulation finished. Total passengers dropped: 55697. Remaining passengers: 5750.
# Simulation finished. Total passengers dropped: 56887. Remaining passengers: 4395.
# Simulation finished. Total passengers dropped: 53999. Remaining passengers: 6990.
# Simulation finished. Total passengers dropped: 55658. Remaining passengers: 5922.
# Simulation finished. Total passengers dropped: 55343. Remaining passengers: 5577.
# Simulation finished. Total passengers dropped: 53962. Remaining passengers: 7184.
# Simulation finished. Total passengers dropped: 55789. Remaining passengers: 5746.
# Simulation finished. Total passengers dropped: 55642. Remaining passengers: 5689.
# Simulation finished. Total passengers dropped: 53700. Remaining passengers: 7257.
# Simulation finished. Total passengers dropped: 55581. Remaining passengers: 5509.
# Simulation finished. Total passengers dropped: 55618. Remaining passengers: 5638.
# Simulation finished. Total passengers dropped: 55445. Remaining passengers: 5703.
# Simulation finished. Total passengers dropped: 55666. Remaining passengers: 5760.
# Simulation finished. Total passengers dropped: 55734. Remaining passengers: 5641.
# Simulation finished. Total passengers dropped: 55440. Remaining passengers: 5373.
# Simulation finished. Total passengers dropped: 54411. Remaining passengers: 7093.
# Simulation finished. Total passengers dropped: 55622. Remaining passengers: 5844.
# Simulation finished. Total passengers dropped: 55229. Remaining passengers: 5635.
# Simulation finished. Total passengers dropped: 55688. Remaining passengers: 5596.
# Simulation finished. Total passengers dropped: 55812. Remaining passengers: 5980.
# Simulation finished. Total passengers dropped: 55477. Remaining passengers: 5727.
# Simulation finished. Total passengers dropped: 55662. Remaining passengers: 5519.
# Simulation finished. Total passengers dropped: 55462. Remaining passengers: 5542.
# Simulation finished. Total passengers dropped: 55195. Remaining passengers: 5592.
# Simulation finished. Total passengers dropped: 56837. Remaining passengers: 4341.
# Simulation finished. Total passengers dropped: 55399. Remaining passengers: 5523.
# Simulation finished. Total passengers dropped: 54816. Remaining passengers: 5643.
# Simulation finished. Total passengers dropped: 56620. Remaining passengers: 4502.
# Simulation finished. Total passengers dropped: 55229. Remaining passengers: 5463.
# Simulation finished. Total passengers dropped: 56334. Remaining passengers: 4369.
# Simulation finished. Total passengers dropped: 55887. Remaining passengers: 5726.
# Simulation finished. Total passengers dropped: 55565. Remaining passengers: 5554.
# Simulation finished. Total passengers dropped: 56899. Remaining passengers: 4026.
# Simulation finished. Total passengers dropped: 55695. Remaining passengers: 5709.
# Simulation finished. Total passengers dropped: 55392. Remaining passengers: 5616.
# Simulation finished. Total passengers dropped: 55540. Remaining passengers: 5926.
# Simulation finished. Total passengers dropped: 55816. Remaining passengers: 5644.
# Simulation finished. Total passengers dropped: 55429. Remaining passengers: 5473.
# Simulation finished. Total passengers dropped: 56480. Remaining passengers: 4540.
# Simulation finished. Total passengers dropped: 57122. Remaining passengers: 4396.
# Simulation finished. Total passengers dropped: 54799. Remaining passengers: 5560.
# Simulation finished. Total passengers dropped: 55716. Remaining passengers: 5696.
# Simulation finished. Total passengers dropped: 55323. Remaining passengers: 5542.
# Simulation finished. Total passengers dropped: 54992. Remaining passengers: 5857.
# Simulation finished. Total passengers dropped: 55129. Remaining passengers: 5592.
# Simulation finished. Total passengers dropped: 55676. Remaining passengers: 5906.
# Simulation finished. Total passengers dropped: 55395. Remaining passengers: 5706.
# Simulation finished. Total passengers dropped: 55851. Remaining passengers: 5762.
# Simulation finished. Total passengers dropped: 55378. Remaining passengers: 5579.
# Best configuration from genetic algorithm: {'bus_num': 15, 'driver_num': 17, 'schedule_type': 'night'}

# %%
def simulate_week_with_parameters(bus_num, driver_num, driver_schedule_type, route_duration, bus_stops_num, start_time, end_time, driver_shift_duration, driver_break_duration):
    days = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]
    total_remaining_passengers = 0  # Суммируем оставшихся пассажиров за неделю

    for day in days:
        sim = Simulation(
            bus_num=bus_num,
            route_duration=route_duration,
            bus_stops_num=bus_stops_num,
            start_time=start_time,
            end_time=end_time,
            tag=day,
            driver_schedule_type=driver_schedule_type,
            driver_shift_duration=driver_shift_duration,
            driver_break_duration=driver_break_duration,
        )
        sim.play_simulation()
        total_remaining_passengers += sum(stop.passengers_waiting for stop in sim.route.bus_stops)

    return total_remaining_passengers

def brute_force_optimization(route_duration, bus_stops_num, start_time, end_time, driver_shift_duration, driver_break_duration):
    best_bus_num = None
    best_driver_num = None
    best_schedule_type = None
    min_remaining_passengers = float("inf")
    start_time_exec = time.time()

    with open("brute_force_weekly_results.txt", "w") as f, open("best_results_brute_force_weekly.txt", "w") as best_f:
        for bus_num in range(8, 21):
            for driver_num in range(bus_num, 21):  # Ensure drivers >= buses
                for schedule_type in ["standard", "night"]:
                    remaining_passengers = simulate_week_with_parameters(
                        bus_num=bus_num,
                        driver_num=driver_num,
                        driver_schedule_type=schedule_type,
                        route_duration=route_duration,
                        bus_stops_num=bus_stops_num,
                        start_time=start_time,
                        end_time=end_time,
                        driver_shift_duration=driver_shift_duration,
                        driver_break_duration=driver_break_duration,
                    )

                    if remaining_passengers < min_remaining_passengers:
                        best_bus_num = bus_num
                        best_driver_num = driver_num
                        best_schedule_type = schedule_type
                        min_remaining_passengers = remaining_passengers

                    f.write(f"Buses: {bus_num}, Drivers: {driver_num}, Type: {schedule_type}, Remaining: {remaining_passengers}\n")

        exec_time = time.time() - start_time_exec
        best_f.write(f"Best Buses: {best_bus_num}, Best Drivers: {best_driver_num}, Type: {best_schedule_type}, Execution Time: {exec_time:.2f} seconds\n")
    return best_bus_num, best_driver_num, best_schedule_type

def genetic_algorithm_optimization(
    route_duration, 
    bus_stops_num, 
    start_time, 
    end_time, 
    driver_shift_duration, 
    driver_break_duration, 
    population_size=10, 
    generations=50, 
    patience=10, 
    log_file="genetic_algorithm_weekly_log.txt"
):
    start_time_exec = time.time()

    population = [
        {
            "bus_num": random.randint(1, 20),
            "driver_num": random.randint(1, 20),
            "schedule_type": random.choice(["standard", "night"]),
        }
        for _ in range(population_size)
    ]

    best_solution = None
    best_fitness = float("inf")
    generations_without_improvement = 0

    with open(log_file, "w") as log, open("best_results_genetic_algorithm_weekly.txt", "w") as best_f:
        log.write("Generation,Bus_Num,Driver_Num,Schedule_Type,Remaining_Passengers\n")

        for generation in range(generations):
            fitness_scores = []
            for individual in population:
                if individual["driver_num"] < individual["bus_num"]:  # Ensure drivers >= buses
                    fitness_scores.append((individual, float("inf")))
                    continue

                remaining_passengers = simulate_week_with_parameters(
                    bus_num=individual["bus_num"],
                    driver_num=individual["driver_num"],
                    driver_schedule_type=individual["schedule_type"],
                    route_duration=route_duration,
                    bus_stops_num=bus_stops_num,
                    start_time=start_time,
                    end_time=end_time,
                    driver_shift_duration=driver_shift_duration,
                    driver_break_duration=driver_break_duration,
                )

                fitness_scores.append((individual, remaining_passengers))

                if remaining_passengers < best_fitness:
                    best_solution = individual
                    best_fitness = remaining_passengers
                    generations_without_improvement = 0

            fitness_scores.sort(key=lambda x: x[1])

            top_individuals = [fs[0] for fs in fitness_scores[: population_size // 2]]

            new_population = []
            for _ in range(population_size):
                parent1, parent2 = random.sample(top_individuals, 2)
                child = {
                    "bus_num": max(1, (parent1["bus_num"] + parent2["bus_num"]) // 2),
                    "driver_num": max(parent1["bus_num"], (parent1["driver_num"] + parent2["driver_num"]) // 2),
                    "schedule_type": random.choice([parent1["schedule_type"], parent2["schedule_type"]]),
                }

                if random.random() < 0.1:
                    child["bus_num"] = max(1, min(20, child["bus_num"] + random.choice([-1, 1])))
                    child["driver_num"] = max(child["bus_num"], min(20, child["driver_num"] + random.choice([-1, 1])))

                new_population.append(child)

            population = new_population
            generations_without_improvement += 1

            if generations_without_improvement >= patience:
                break

        exec_time = time.time() - start_time_exec
        best_f.write(f"Best Solution: {best_solution}, Execution Time: {exec_time:.2f} seconds\n")

    return best_solution

# %%
best_bus_num, best_driver_num, best_schedule_type = brute_force_optimization(
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
)

print(f"Лучший результат brute-force:")
print(f"Автобусы: {best_bus_num}, Водители: {best_driver_num}, Тип расписания: {best_schedule_type}")
best_solution = genetic_algorithm_optimization(
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
    population_size=10,  
    generations=50,  
    patience=10  
)

print(f"Лучший результат генетического алгоритма:")
print(best_solution)
simulation = Simulation(
    bus_num=best_solution["bus_num"],
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    tag="monday",  # Пример дня для анализа
    driver_schedule_type=best_solution["schedule_type"],
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
)

simulation.play_simulation()
simulation.print_schedule()
with open("results_summary.txt", "w") as f:
    f.write(f"Brute-force: Buses = {best_bus_num}, Drivers = {best_driver_num}, Schedule Type = {best_schedule_type}\n")
    f.write(f"Genetic Algorithm: {best_solution}\n")
# Out:
# Simulation finished. Total passengers dropped: 58583. Remaining passengers: 2812.
# Simulation finished. Total passengers dropped: 58276. Remaining passengers: 3092.
# Simulation finished. Total passengers dropped: 58901. Remaining passengers: 2786.
# Simulation finished. Total passengers dropped: 58430. Remaining passengers: 2813.
# Simulation finished. Total passengers dropped: 57595. Remaining passengers: 2668.
# Simulation finished. Total passengers dropped: 108944. Remaining passengers: 243.
# Simulation finished. Total passengers dropped: 108163. Remaining passengers: 289.
# Simulation finished. Total passengers dropped: 52933. Remaining passengers: 8318.
# Simulation finished. Total passengers dropped: 53676. Remaining passengers: 7852.
# Simulation finished. Total passengers dropped: 53502. Remaining passengers: 8154.
# Simulation finished. Total passengers dropped: 52453. Remaining passengers: 8147.
# Simulation finished. Total passengers dropped: 52926. Remaining passengers: 8459.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21572.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21825.
# Simulation finished. Total passengers dropped: 58625. Remaining passengers: 2744.
# Simulation finished. Total passengers dropped: 58570. Remaining passengers: 2751.
# Simulation finished. Total passengers dropped: 57998. Remaining passengers: 2731.
# Simulation finished. Total passengers dropped: 58472. Remaining passengers: 2511.
# Simulation finished. Total passengers dropped: 58206. Remaining passengers: 2848.
# Simulation finished. Total passengers dropped: 108786. Remaining passengers: 233.
# Simulation finished. Total passengers dropped: 108113. Remaining passengers: 269.
# Simulation finished. Total passengers dropped: 53079. Remaining passengers: 8181.
# Simulation finished. Total passengers dropped: 52455. Remaining passengers: 7961.
# Simulation finished. Total passengers dropped: 52909. Remaining passengers: 8215.
# Simulation finished. Total passengers dropped: 53610. Remaining passengers: 7923.
# Simulation finished. Total passengers dropped: 53149. Remaining passengers: 8210.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21924.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22413.
# Simulation finished. Total passengers dropped: 58982. Remaining passengers: 2726.
# Simulation finished. Total passengers dropped: 58619. Remaining passengers: 2856.
# Simulation finished. Total passengers dropped: 58543. Remaining passengers: 2618.
# Simulation finished. Total passengers dropped: 59036. Remaining passengers: 2596.
# Simulation finished. Total passengers dropped: 58411. Remaining passengers: 2508.
# Simulation finished. Total passengers dropped: 107620. Remaining passengers: 274.
# Simulation finished. Total passengers dropped: 109027. Remaining passengers: 247.
# Simulation finished. Total passengers dropped: 53005. Remaining passengers: 8310.
# Simulation finished. Total passengers dropped: 52938. Remaining passengers: 8088.
# Simulation finished. Total passengers dropped: 52820. Remaining passengers: 8122.
# Simulation finished. Total passengers dropped: 53332. Remaining passengers: 8138.
# Simulation finished. Total passengers dropped: 53068. Remaining passengers: 8230.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 23054.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22833.
# Simulation finished. Total passengers dropped: 58607. Remaining passengers: 2859.
# Simulation finished. Total passengers dropped: 58143. Remaining passengers: 2835.
# Simulation finished. Total passengers dropped: 58380. Remaining passengers: 2917.
# Simulation finished. Total passengers dropped: 58636. Remaining passengers: 2704.
# Simulation finished. Total passengers dropped: 58488. Remaining passengers: 2718.
# Simulation finished. Total passengers dropped: 107036. Remaining passengers: 294.
# Simulation finished. Total passengers dropped: 107961. Remaining passengers: 255.
# Simulation finished. Total passengers dropped: 53255. Remaining passengers: 8355.
# Simulation finished. Total passengers dropped: 52871. Remaining passengers: 8280.
# Simulation finished. Total passengers dropped: 52702. Remaining passengers: 8071.
# Simulation finished. Total passengers dropped: 53331. Remaining passengers: 8095.
# Simulation finished. Total passengers dropped: 53322. Remaining passengers: 7963.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22773.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22139.
# Simulation finished. Total passengers dropped: 58352. Remaining passengers: 2975.
# Simulation finished. Total passengers dropped: 58713. Remaining passengers: 2604.
# Simulation finished. Total passengers dropped: 58448. Remaining passengers: 2983.
# Simulation finished. Total passengers dropped: 58627. Remaining passengers: 2611.
# Simulation finished. Total passengers dropped: 58645. Remaining passengers: 2803.
# Simulation finished. Total passengers dropped: 108294. Remaining passengers: 273.
# Simulation finished. Total passengers dropped: 109171. Remaining passengers: 265.
# Simulation finished. Total passengers dropped: 53223. Remaining passengers: 8093.
# Simulation finished. Total passengers dropped: 52907. Remaining passengers: 8167.
# Simulation finished. Total passengers dropped: 52597. Remaining passengers: 7968.
# Simulation finished. Total passengers dropped: 53066. Remaining passengers: 8391.
# Simulation finished. Total passengers dropped: 53272. Remaining passengers: 8139.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21789.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21641.
# Simulation finished. Total passengers dropped: 58203. Remaining passengers: 2829.
# Simulation finished. Total passengers dropped: 58761. Remaining passengers: 2748.
# Simulation finished. Total passengers dropped: 58695. Remaining passengers: 2616.
# Simulation finished. Total passengers dropped: 58379. Remaining passengers: 2654.
# Simulation finished. Total passengers dropped: 58722. Remaining passengers: 2565.
# Simulation finished. Total passengers dropped: 108040. Remaining passengers: 271.
# Simulation finished. Total passengers dropped: 108360. Remaining passengers: 307.
# Simulation finished. Total passengers dropped: 53339. Remaining passengers: 8530.
# Simulation finished. Total passengers dropped: 52857. Remaining passengers: 8429.
# Simulation finished. Total passengers dropped: 53008. Remaining passengers: 8170.
# Simulation finished. Total passengers dropped: 52923. Remaining passengers: 7869.
# Simulation finished. Total passengers dropped: 53325. Remaining passengers: 8140.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22453.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22679.
# Simulation finished. Total passengers dropped: 58518. Remaining passengers: 2524.
# Simulation finished. Total passengers dropped: 58293. Remaining passengers: 2455.
# Simulation finished. Total passengers dropped: 58793. Remaining passengers: 2916.
# Simulation finished. Total passengers dropped: 58720. Remaining passengers: 2642.
# Simulation finished. Total passengers dropped: 59067. Remaining passengers: 2839.
# Simulation finished. Total passengers dropped: 108456. Remaining passengers: 229.
# Simulation finished. Total passengers dropped: 108112. Remaining passengers: 240.
# Simulation finished. Total passengers dropped: 53113. Remaining passengers: 8320.
# Simulation finished. Total passengers dropped: 53018. Remaining passengers: 8146.
# Simulation finished. Total passengers dropped: 53239. Remaining passengers: 8269.
# Simulation finished. Total passengers dropped: 52567. Remaining passengers: 8246.
# Simulation finished. Total passengers dropped: 52956. Remaining passengers: 8264.
# Simulation finished. Total passengers dropped: 86387. Remaining passengers: 22146.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21560.
# Simulation finished. Total passengers dropped: 58654. Remaining passengers: 2438.
# Simulation finished. Total passengers dropped: 58100. Remaining passengers: 2614.
# Simulation finished. Total passengers dropped: 58602. Remaining passengers: 2679.
# Simulation finished. Total passengers dropped: 58271. Remaining passengers: 2851.
# Simulation finished. Total passengers dropped: 58908. Remaining passengers: 2347.
# Simulation finished. Total passengers dropped: 107941. Remaining passengers: 260.
# Simulation finished. Total passengers dropped: 108101. Remaining passengers: 284.
# Simulation finished. Total passengers dropped: 52770. Remaining passengers: 8202.
# Simulation finished. Total passengers dropped: 53100. Remaining passengers: 8159.
# Simulation finished. Total passengers dropped: 52636. Remaining passengers: 7888.
# Simulation finished. Total passengers dropped: 53642. Remaining passengers: 7943.
# Simulation finished. Total passengers dropped: 53065. Remaining passengers: 8030.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21577.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22195.
# Simulation finished. Total passengers dropped: 58824. Remaining passengers: 2779.
# Simulation finished. Total passengers dropped: 58510. Remaining passengers: 2760.
# Simulation finished. Total passengers dropped: 57786. Remaining passengers: 2725.
# Simulation finished. Total passengers dropped: 59026. Remaining passengers: 2490.
# Simulation finished. Total passengers dropped: 58519. Remaining passengers: 2646.
# Simulation finished. Total passengers dropped: 108711. Remaining passengers: 321.
# Simulation finished. Total passengers dropped: 108881. Remaining passengers: 235.
# Simulation finished. Total passengers dropped: 52915. Remaining passengers: 8077.
# Simulation finished. Total passengers dropped: 53260. Remaining passengers: 8049.
# Simulation finished. Total passengers dropped: 52826. Remaining passengers: 8188.
# Simulation finished. Total passengers dropped: 53523. Remaining passengers: 8253.
# Simulation finished. Total passengers dropped: 52920. Remaining passengers: 8048.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22703.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21809.
# Simulation finished. Total passengers dropped: 58753. Remaining passengers: 2594.
# Simulation finished. Total passengers dropped: 58585. Remaining passengers: 2780.
# Simulation finished. Total passengers dropped: 58310. Remaining passengers: 2661.
# Simulation finished. Total passengers dropped: 58429. Remaining passengers: 2994.
# Simulation finished. Total passengers dropped: 58668. Remaining passengers: 2391.
# Simulation finished. Total passengers dropped: 107251. Remaining passengers: 320.
# Simulation finished. Total passengers dropped: 108601. Remaining passengers: 347.
# Simulation finished. Total passengers dropped: 52837. Remaining passengers: 7962.
# Simulation finished. Total passengers dropped: 52791. Remaining passengers: 8119.
# Simulation finished. Total passengers dropped: 53181. Remaining passengers: 8248.
# Simulation finished. Total passengers dropped: 53029. Remaining passengers: 8401.
# Simulation finished. Total passengers dropped: 53168. Remaining passengers: 8168.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21674.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 23124.
# Simulation finished. Total passengers dropped: 58167. Remaining passengers: 2897.
# Simulation finished. Total passengers dropped: 58400. Remaining passengers: 2248.
# Simulation finished. Total passengers dropped: 58491. Remaining passengers: 2594.
# Simulation finished. Total passengers dropped: 58586. Remaining passengers: 2732.
# Simulation finished. Total passengers dropped: 59088. Remaining passengers: 2579.
# Simulation finished. Total passengers dropped: 107510. Remaining passengers: 243.
# Simulation finished. Total passengers dropped: 108067. Remaining passengers: 257.
# Simulation finished. Total passengers dropped: 53175. Remaining passengers: 8048.
# Simulation finished. Total passengers dropped: 53200. Remaining passengers: 8287.
# Simulation finished. Total passengers dropped: 53262. Remaining passengers: 8251.
# Simulation finished. Total passengers dropped: 52695. Remaining passengers: 7978.
# Simulation finished. Total passengers dropped: 53285. Remaining passengers: 8172.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22410.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21927.
# Simulation finished. Total passengers dropped: 58568. Remaining passengers: 2560.
# Simulation finished. Total passengers dropped: 58392. Remaining passengers: 2524.
# Simulation finished. Total passengers dropped: 58111. Remaining passengers: 2633.
# Simulation finished. Total passengers dropped: 58114. Remaining passengers: 2364.
# Simulation finished. Total passengers dropped: 58712. Remaining passengers: 2266.
# Simulation finished. Total passengers dropped: 108311. Remaining passengers: 298.
# Simulation finished. Total passengers dropped: 106980. Remaining passengers: 266.
# Simulation finished. Total passengers dropped: 52996. Remaining passengers: 8041.
# Simulation finished. Total passengers dropped: 53338. Remaining passengers: 7854.
# Simulation finished. Total passengers dropped: 52424. Remaining passengers: 8273.
# Simulation finished. Total passengers dropped: 53437. Remaining passengers: 8223.
# Simulation finished. Total passengers dropped: 53237. Remaining passengers: 8294.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 23277.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22119.
# Simulation finished. Total passengers dropped: 58445. Remaining passengers: 2704.
# Simulation finished. Total passengers dropped: 58286. Remaining passengers: 2662.
# Simulation finished. Total passengers dropped: 58627. Remaining passengers: 2509.
# Simulation finished. Total passengers dropped: 58514. Remaining passengers: 2314.
# Simulation finished. Total passengers dropped: 58012. Remaining passengers: 2572.
# Simulation finished. Total passengers dropped: 108249. Remaining passengers: 268.
# Simulation finished. Total passengers dropped: 108668. Remaining passengers: 319.
# Simulation finished. Total passengers dropped: 52963. Remaining passengers: 8199.
# Simulation finished. Total passengers dropped: 52911. Remaining passengers: 8556.
# Simulation finished. Total passengers dropped: 53293. Remaining passengers: 7980.
# Simulation finished. Total passengers dropped: 53287. Remaining passengers: 7988.
# Simulation finished. Total passengers dropped: 52714. Remaining passengers: 8275.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21646.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22207.
# Simulation finished. Total passengers dropped: 60422. Remaining passengers: 478.
# Simulation finished. Total passengers dropped: 60577. Remaining passengers: 655.
# Simulation finished. Total passengers dropped: 60412. Remaining passengers: 940.
# Simulation finished. Total passengers dropped: 60664. Remaining passengers: 1158.
# Simulation finished. Total passengers dropped: 60170. Remaining passengers: 883.
# Simulation finished. Total passengers dropped: 108936. Remaining passengers: 305.
# Simulation finished. Total passengers dropped: 108855. Remaining passengers: 227.
# Simulation finished. Total passengers dropped: 54454. Remaining passengers: 6474.
# Simulation finished. Total passengers dropped: 54337. Remaining passengers: 6734.
# Simulation finished. Total passengers dropped: 54328. Remaining passengers: 6666.
# Simulation finished. Total passengers dropped: 54499. Remaining passengers: 6848.
# Simulation finished. Total passengers dropped: 54299. Remaining passengers: 7206.
# Simulation finished. Total passengers dropped: 97145. Remaining passengers: 11338.
# Simulation finished. Total passengers dropped: 97079. Remaining passengers: 10308.
# Simulation finished. Total passengers dropped: 60444. Remaining passengers: 1081.
# Simulation finished. Total passengers dropped: 60173. Remaining passengers: 622.
# Simulation finished. Total passengers dropped: 60477. Remaining passengers: 704.
# Simulation finished. Total passengers dropped: 60404. Remaining passengers: 786.
# Simulation finished. Total passengers dropped: 60547. Remaining passengers: 579.
# Simulation finished. Total passengers dropped: 109557. Remaining passengers: 270.
# Simulation finished. Total passengers dropped: 108073. Remaining passengers: 235.
# Simulation finished. Total passengers dropped: 54056. Remaining passengers: 7074.
# Simulation finished. Total passengers dropped: 54139. Remaining passengers: 7207.
# Simulation finished. Total passengers dropped: 54662. Remaining passengers: 6910.
# Simulation finished. Total passengers dropped: 54444. Remaining passengers: 6857.
# Simulation finished. Total passengers dropped: 53997. Remaining passengers: 6716.
# Simulation finished. Total passengers dropped: 97193. Remaining passengers: 11485.
# Simulation finished. Total passengers dropped: 97110. Remaining passengers: 10321.
# Simulation finished. Total passengers dropped: 60440. Remaining passengers: 869.
# Simulation finished. Total passengers dropped: 60634. Remaining passengers: 1098.
# Simulation finished. Total passengers dropped: 60185. Remaining passengers: 954.
# Simulation finished. Total passengers dropped: 60523. Remaining passengers: 704.
# Simulation finished. Total passengers dropped: 60368. Remaining passengers: 1081.
# Simulation finished. Total passengers dropped: 108128. Remaining passengers: 215.
# Simulation finished. Total passengers dropped: 108859. Remaining passengers: 287.
# Simulation finished. Total passengers dropped: 53930. Remaining passengers: 7021.
# Simulation finished. Total passengers dropped: 54226. Remaining passengers: 7151.
# Simulation finished. Total passengers dropped: 54610. Remaining passengers: 6783.
# Simulation finished. Total passengers dropped: 53865. Remaining passengers: 6860.
# Simulation finished. Total passengers dropped: 54571. Remaining passengers: 6836.
# Simulation finished. Total passengers dropped: 97103. Remaining passengers: 11470.
# Simulation finished. Total passengers dropped: 97108. Remaining passengers: 10240.
# Simulation finished. Total passengers dropped: 60335. Remaining passengers: 722.
# Simulation finished. Total passengers dropped: 60619. Remaining passengers: 501.
# Simulation finished. Total passengers dropped: 60421. Remaining passengers: 604.
# Simulation finished. Total passengers dropped: 60353. Remaining passengers: 989.
# Simulation finished. Total passengers dropped: 61141. Remaining passengers: 784.
# Simulation finished. Total passengers dropped: 109018. Remaining passengers: 296.
# Simulation finished. Total passengers dropped: 107897. Remaining passengers: 309.
# Simulation finished. Total passengers dropped: 54219. Remaining passengers: 6572.
# Simulation finished. Total passengers dropped: 54260. Remaining passengers: 7350.
# Simulation finished. Total passengers dropped: 54429. Remaining passengers: 6990.
# Simulation finished. Total passengers dropped: 54417. Remaining passengers: 7068.
# Simulation finished. Total passengers dropped: 53700. Remaining passengers: 6833.
# Simulation finished. Total passengers dropped: 97059. Remaining passengers: 12195.
# Simulation finished. Total passengers dropped: 97096. Remaining passengers: 11421.
# Simulation finished. Total passengers dropped: 60570. Remaining passengers: 804.
# Simulation finished. Total passengers dropped: 60077. Remaining passengers: 724.
# Simulation finished. Total passengers dropped: 60003. Remaining passengers: 761.
# Simulation finished. Total passengers dropped: 60078. Remaining passengers: 748.
# Simulation finished. Total passengers dropped: 60316. Remaining passengers: 704.
# Simulation finished. Total passengers dropped: 108864. Remaining passengers: 239.
# Simulation finished. Total passengers dropped: 108286. Remaining passengers: 243.
# Simulation finished. Total passengers dropped: 54260. Remaining passengers: 7044.
# Simulation finished. Total passengers dropped: 54296. Remaining passengers: 7012.
# Simulation finished. Total passengers dropped: 54217. Remaining passengers: 7109.
# Simulation finished. Total passengers dropped: 54698. Remaining passengers: 6907.
# Simulation finished. Total passengers dropped: 54478. Remaining passengers: 6937.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 11428.
# Simulation finished. Total passengers dropped: 97137. Remaining passengers: 12098.
# Simulation finished. Total passengers dropped: 60155. Remaining passengers: 1300.
# Simulation finished. Total passengers dropped: 59979. Remaining passengers: 862.
# Simulation finished. Total passengers dropped: 61077. Remaining passengers: 1339.
# Simulation finished. Total passengers dropped: 60266. Remaining passengers: 1187.
# Simulation finished. Total passengers dropped: 60243. Remaining passengers: 963.
# Simulation finished. Total passengers dropped: 109230. Remaining passengers: 242.
# Simulation finished. Total passengers dropped: 109058. Remaining passengers: 289.
# Simulation finished. Total passengers dropped: 53872. Remaining passengers: 7156.
# Simulation finished. Total passengers dropped: 54282. Remaining passengers: 6659.
# Simulation finished. Total passengers dropped: 54272. Remaining passengers: 6948.
# Simulation finished. Total passengers dropped: 54154. Remaining passengers: 6649.
# Simulation finished. Total passengers dropped: 54520. Remaining passengers: 7021.
# Simulation finished. Total passengers dropped: 97112. Remaining passengers: 11182.
# Simulation finished. Total passengers dropped: 97100. Remaining passengers: 11284.
# Simulation finished. Total passengers dropped: 60532. Remaining passengers: 950.
# Simulation finished. Total passengers dropped: 60176. Remaining passengers: 459.
# Simulation finished. Total passengers dropped: 60490. Remaining passengers: 1064.
# Simulation finished. Total passengers dropped: 60470. Remaining passengers: 754.
# Simulation finished. Total passengers dropped: 60260. Remaining passengers: 981.
# Simulation finished. Total passengers dropped: 108574. Remaining passengers: 289.
# Simulation finished. Total passengers dropped: 109331. Remaining passengers: 197.
# Simulation finished. Total passengers dropped: 54597. Remaining passengers: 7185.
# Simulation finished. Total passengers dropped: 54236. Remaining passengers: 6987.
# Simulation finished. Total passengers dropped: 54475. Remaining passengers: 6860.
# Simulation finished. Total passengers dropped: 54078. Remaining passengers: 6847.
# Simulation finished. Total passengers dropped: 54276. Remaining passengers: 7023.
# Simulation finished. Total passengers dropped: 97033. Remaining passengers: 12055.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 11628.
# Simulation finished. Total passengers dropped: 60664. Remaining passengers: 670.
# Simulation finished. Total passengers dropped: 60543. Remaining passengers: 1230.
# Simulation finished. Total passengers dropped: 59688. Remaining passengers: 730.
# Simulation finished. Total passengers dropped: 60184. Remaining passengers: 848.
# Simulation finished. Total passengers dropped: 60816. Remaining passengers: 781.
# Simulation finished. Total passengers dropped: 107754. Remaining passengers: 179.
# Simulation finished. Total passengers dropped: 108232. Remaining passengers: 201.
# Simulation finished. Total passengers dropped: 54073. Remaining passengers: 6997.
# Simulation finished. Total passengers dropped: 54260. Remaining passengers: 6749.
# Simulation finished. Total passengers dropped: 54947. Remaining passengers: 6835.
# Simulation finished. Total passengers dropped: 54425. Remaining passengers: 6709.
# Simulation finished. Total passengers dropped: 54204. Remaining passengers: 6750.
# Simulation finished. Total passengers dropped: 97070. Remaining passengers: 11421.
# Simulation finished. Total passengers dropped: 97109. Remaining passengers: 10730.
# Simulation finished. Total passengers dropped: 60231. Remaining passengers: 865.
# Simulation finished. Total passengers dropped: 60564. Remaining passengers: 951.
# Simulation finished. Total passengers dropped: 60010. Remaining passengers: 1023.
# Simulation finished. Total passengers dropped: 60153. Remaining passengers: 820.
# Simulation finished. Total passengers dropped: 60545. Remaining passengers: 579.
# Simulation finished. Total passengers dropped: 108660. Remaining passengers: 235.
# Simulation finished. Total passengers dropped: 108999. Remaining passengers: 180.
# Simulation finished. Total passengers dropped: 53874. Remaining passengers: 6796.
# Simulation finished. Total passengers dropped: 54233. Remaining passengers: 6939.
# Simulation finished. Total passengers dropped: 54236. Remaining passengers: 7345.
# Simulation finished. Total passengers dropped: 54536. Remaining passengers: 7114.
# Simulation finished. Total passengers dropped: 53842. Remaining passengers: 6765.
# Simulation finished. Total passengers dropped: 97163. Remaining passengers: 11502.
# Simulation finished. Total passengers dropped: 97076. Remaining passengers: 10912.
# Simulation finished. Total passengers dropped: 60175. Remaining passengers: 1087.
# Simulation finished. Total passengers dropped: 60463. Remaining passengers: 734.
# Simulation finished. Total passengers dropped: 60396. Remaining passengers: 700.
# Simulation finished. Total passengers dropped: 60517. Remaining passengers: 750.
# Simulation finished. Total passengers dropped: 61082. Remaining passengers: 998.
# Simulation finished. Total passengers dropped: 108404. Remaining passengers: 294.
# Simulation finished. Total passengers dropped: 108006. Remaining passengers: 306.
# Simulation finished. Total passengers dropped: 54243. Remaining passengers: 7221.
# Simulation finished. Total passengers dropped: 54242. Remaining passengers: 6960.
# Simulation finished. Total passengers dropped: 53635. Remaining passengers: 6766.
# Simulation finished. Total passengers dropped: 53987. Remaining passengers: 6912.
# Simulation finished. Total passengers dropped: 54523. Remaining passengers: 6925.
# Simulation finished. Total passengers dropped: 97199. Remaining passengers: 11449.
# Simulation finished. Total passengers dropped: 97106. Remaining passengers: 11036.
# Simulation finished. Total passengers dropped: 60690. Remaining passengers: 954.
# Simulation finished. Total passengers dropped: 60432. Remaining passengers: 714.
# Simulation finished. Total passengers dropped: 60269. Remaining passengers: 730.
# Simulation finished. Total passengers dropped: 59772. Remaining passengers: 646.
# Simulation finished. Total passengers dropped: 61054. Remaining passengers: 978.
# Simulation finished. Total passengers dropped: 108032. Remaining passengers: 290.
# Simulation finished. Total passengers dropped: 109470. Remaining passengers: 250.
# Simulation finished. Total passengers dropped: 54408. Remaining passengers: 7043.
# Simulation finished. Total passengers dropped: 54184. Remaining passengers: 6830.
# Simulation finished. Total passengers dropped: 54201. Remaining passengers: 7096.
# Simulation finished. Total passengers dropped: 54035. Remaining passengers: 7141.
# Simulation finished. Total passengers dropped: 54294. Remaining passengers: 7270.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 10670.
# Simulation finished. Total passengers dropped: 96973. Remaining passengers: 11529.
# Simulation finished. Total passengers dropped: 60328. Remaining passengers: 938.
# Simulation finished. Total passengers dropped: 60323. Remaining passengers: 811.
# Simulation finished. Total passengers dropped: 60046. Remaining passengers: 668.
# Simulation finished. Total passengers dropped: 60819. Remaining passengers: 774.
# Simulation finished. Total passengers dropped: 59984. Remaining passengers: 876.
# Simulation finished. Total passengers dropped: 107735. Remaining passengers: 262.
# Simulation finished. Total passengers dropped: 108685. Remaining passengers: 302.
# Simulation finished. Total passengers dropped: 54243. Remaining passengers: 6641.
# Simulation finished. Total passengers dropped: 54419. Remaining passengers: 7308.
# Simulation finished. Total passengers dropped: 54471. Remaining passengers: 6764.
# Simulation finished. Total passengers dropped: 53961. Remaining passengers: 6964.
# Simulation finished. Total passengers dropped: 54086. Remaining passengers: 6884.
# Simulation finished. Total passengers dropped: 97170. Remaining passengers: 10761.
# Simulation finished. Total passengers dropped: 97116. Remaining passengers: 11203.
# Simulation finished. Total passengers dropped: 61424. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60733. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61039. Remaining passengers: 23.
# Simulation finished. Total passengers dropped: 61291. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61410. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 107253. Remaining passengers: 147.
# Simulation finished. Total passengers dropped: 107870. Remaining passengers: 126.
# Simulation finished. Total passengers dropped: 55745. Remaining passengers: 5819.
# Simulation finished. Total passengers dropped: 55907. Remaining passengers: 5752.
# Simulation finished. Total passengers dropped: 55419. Remaining passengers: 5438.
# Simulation finished. Total passengers dropped: 55013. Remaining passengers: 5475.
# Simulation finished. Total passengers dropped: 55700. Remaining passengers: 5786.
# Simulation finished. Total passengers dropped: 107624. Remaining passengers: 863.
# Simulation finished. Total passengers dropped: 106915. Remaining passengers: 391.
# Simulation finished. Total passengers dropped: 61167. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61229. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61249. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61982. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 60760. Remaining passengers: 23.
# Simulation finished. Total passengers dropped: 108521. Remaining passengers: 201.
# Simulation finished. Total passengers dropped: 107714. Remaining passengers: 134.
# Simulation finished. Total passengers dropped: 55274. Remaining passengers: 5801.
# Simulation finished. Total passengers dropped: 54810. Remaining passengers: 5569.
# Simulation finished. Total passengers dropped: 55469. Remaining passengers: 5551.
# Simulation finished. Total passengers dropped: 55351. Remaining passengers: 5535.
# Simulation finished. Total passengers dropped: 55570. Remaining passengers: 5548.
# Simulation finished. Total passengers dropped: 107491. Remaining passengers: 565.
# Simulation finished. Total passengers dropped: 107509. Remaining passengers: 515.
# Simulation finished. Total passengers dropped: 61488. Remaining passengers: 23.
# Simulation finished. Total passengers dropped: 61027. Remaining passengers: 7.
# Simulation finished. Total passengers dropped: 60850. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 60980. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61310. Remaining passengers: 28.
# Simulation finished. Total passengers dropped: 108700. Remaining passengers: 195.
# Simulation finished. Total passengers dropped: 108959. Remaining passengers: 131.
# Simulation finished. Total passengers dropped: 55638. Remaining passengers: 5533.
# Simulation finished. Total passengers dropped: 55549. Remaining passengers: 5522.
# Simulation finished. Total passengers dropped: 55625. Remaining passengers: 5573.
# Simulation finished. Total passengers dropped: 55267. Remaining passengers: 5521.
# Simulation finished. Total passengers dropped: 55222. Remaining passengers: 5164.
# Simulation finished. Total passengers dropped: 107483. Remaining passengers: 220.
# Simulation finished. Total passengers dropped: 107490. Remaining passengers: 1166.
# Simulation finished. Total passengers dropped: 60803. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 60938. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61044. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61818. Remaining passengers: 4.
# Simulation finished. Total passengers dropped: 61401. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 107899. Remaining passengers: 203.
# Simulation finished. Total passengers dropped: 107688. Remaining passengers: 184.
# Simulation finished. Total passengers dropped: 55934. Remaining passengers: 5612.
# Simulation finished. Total passengers dropped: 55044. Remaining passengers: 5471.
# Simulation finished. Total passengers dropped: 55645. Remaining passengers: 5736.
# Simulation finished. Total passengers dropped: 55145. Remaining passengers: 5392.
# Simulation finished. Total passengers dropped: 55446. Remaining passengers: 5863.
# Simulation finished. Total passengers dropped: 107580. Remaining passengers: 668.
# Simulation finished. Total passengers dropped: 107504. Remaining passengers: 985.
# Simulation finished. Total passengers dropped: 60795. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61455. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60983. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60681. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 61069. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 108850. Remaining passengers: 155.
# Simulation finished. Total passengers dropped: 109256. Remaining passengers: 138.
# Simulation finished. Total passengers dropped: 55511. Remaining passengers: 5181.
# Simulation finished. Total passengers dropped: 55757. Remaining passengers: 5782.
# Simulation finished. Total passengers dropped: 55629. Remaining passengers: 5370.
# Simulation finished. Total passengers dropped: 55791. Remaining passengers: 5696.
# Simulation finished. Total passengers dropped: 56221. Remaining passengers: 5543.
# Simulation finished. Total passengers dropped: 107786. Remaining passengers: 1188.
# Simulation finished. Total passengers dropped: 107650. Remaining passengers: 595.
# Simulation finished. Total passengers dropped: 60743. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 61163. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61377. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61760. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61301. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 108011. Remaining passengers: 199.
# Simulation finished. Total passengers dropped: 107859. Remaining passengers: 189.
# Simulation finished. Total passengers dropped: 55284. Remaining passengers: 5469.
# Simulation finished. Total passengers dropped: 55493. Remaining passengers: 5972.
# Simulation finished. Total passengers dropped: 55517. Remaining passengers: 5504.
# Simulation finished. Total passengers dropped: 55332. Remaining passengers: 5747.
# Simulation finished. Total passengers dropped: 55405. Remaining passengers: 5555.
# Simulation finished. Total passengers dropped: 107690. Remaining passengers: 808.
# Simulation finished. Total passengers dropped: 107700. Remaining passengers: 496.
# Simulation finished. Total passengers dropped: 61881. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61689. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61028. Remaining passengers: 27.
# Simulation finished. Total passengers dropped: 61221. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61286. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 108886. Remaining passengers: 105.
# Simulation finished. Total passengers dropped: 109651. Remaining passengers: 232.
# Simulation finished. Total passengers dropped: 55614. Remaining passengers: 5729.
# Simulation finished. Total passengers dropped: 56001. Remaining passengers: 5687.
# Simulation finished. Total passengers dropped: 55485. Remaining passengers: 5354.
# Simulation finished. Total passengers dropped: 55982. Remaining passengers: 5593.
# Simulation finished. Total passengers dropped: 55410. Remaining passengers: 5481.
# Simulation finished. Total passengers dropped: 107634. Remaining passengers: 1004.
# Simulation finished. Total passengers dropped: 107778. Remaining passengers: 1229.
# Simulation finished. Total passengers dropped: 60926. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61233. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61192. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61416. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61323. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 107743. Remaining passengers: 191.
# Simulation finished. Total passengers dropped: 108027. Remaining passengers: 162.
# Simulation finished. Total passengers dropped: 55503. Remaining passengers: 5798.
# Simulation finished. Total passengers dropped: 55930. Remaining passengers: 5855.
# Simulation finished. Total passengers dropped: 55765. Remaining passengers: 5701.
# Simulation finished. Total passengers dropped: 56370. Remaining passengers: 5651.
# Simulation finished. Total passengers dropped: 56135. Remaining passengers: 5561.
# Simulation finished. Total passengers dropped: 107305. Remaining passengers: 386.
# Simulation finished. Total passengers dropped: 107877. Remaining passengers: 318.
# Simulation finished. Total passengers dropped: 61095. Remaining passengers: 23.
# Simulation finished. Total passengers dropped: 60908. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 60898. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 60897. Remaining passengers: 7.
# Simulation finished. Total passengers dropped: 61152. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 108932. Remaining passengers: 167.
# Simulation finished. Total passengers dropped: 107935. Remaining passengers: 145.
# Simulation finished. Total passengers dropped: 55632. Remaining passengers: 5800.
# Simulation finished. Total passengers dropped: 55780. Remaining passengers: 5813.
# Simulation finished. Total passengers dropped: 55552. Remaining passengers: 5436.
# Simulation finished. Total passengers dropped: 55460. Remaining passengers: 5593.
# Simulation finished. Total passengers dropped: 55622. Remaining passengers: 5683.
# Simulation finished. Total passengers dropped: 107829. Remaining passengers: 354.
# Simulation finished. Total passengers dropped: 107609. Remaining passengers: 1060.
# Simulation finished. Total passengers dropped: 61153. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 60977. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 60537. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60941. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 60906. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 108027. Remaining passengers: 191.
# Simulation finished. Total passengers dropped: 108864. Remaining passengers: 116.
# Simulation finished. Total passengers dropped: 55233. Remaining passengers: 5253.
# Simulation finished. Total passengers dropped: 55294. Remaining passengers: 5369.
# Simulation finished. Total passengers dropped: 55678. Remaining passengers: 5506.
# Simulation finished. Total passengers dropped: 56057. Remaining passengers: 5766.
# Simulation finished. Total passengers dropped: 55151. Remaining passengers: 5711.
# Simulation finished. Total passengers dropped: 107332. Remaining passengers: 420.
# Simulation finished. Total passengers dropped: 107743. Remaining passengers: 619.
# Simulation finished. Total passengers dropped: 61694. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60866. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 61396. Remaining passengers: 7.
# Simulation finished. Total passengers dropped: 61081. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 61354. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 107512. Remaining passengers: 159.
# Simulation finished. Total passengers dropped: 108145. Remaining passengers: 244.
# Simulation finished. Total passengers dropped: 55492. Remaining passengers: 5724.
# Simulation finished. Total passengers dropped: 56001. Remaining passengers: 5952.
# Simulation finished. Total passengers dropped: 55522. Remaining passengers: 5672.
# Simulation finished. Total passengers dropped: 55593. Remaining passengers: 5401.
# Simulation finished. Total passengers dropped: 55541. Remaining passengers: 5571.
# Simulation finished. Total passengers dropped: 107061. Remaining passengers: 317.
# Simulation finished. Total passengers dropped: 107763. Remaining passengers: 949.
# Simulation finished. Total passengers dropped: 61050. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61129. Remaining passengers: 23.
# Simulation finished. Total passengers dropped: 60571. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61102. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60753. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 107362. Remaining passengers: 182.
# Simulation finished. Total passengers dropped: 108344. Remaining passengers: 138.
# Simulation finished. Total passengers dropped: 57256. Remaining passengers: 4053.
# Simulation finished. Total passengers dropped: 56828. Remaining passengers: 4474.
# Simulation finished. Total passengers dropped: 57060. Remaining passengers: 4523.
# Simulation finished. Total passengers dropped: 56484. Remaining passengers: 4714.
# Simulation finished. Total passengers dropped: 57222. Remaining passengers: 4531.
# Simulation finished. Total passengers dropped: 108019. Remaining passengers: 217.
# Simulation finished. Total passengers dropped: 107863. Remaining passengers: 230.
# Simulation finished. Total passengers dropped: 61635. Remaining passengers: 28.
# Simulation finished. Total passengers dropped: 61881. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61421. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 60872. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 60978. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 108714. Remaining passengers: 176.
# Simulation finished. Total passengers dropped: 108757. Remaining passengers: 157.
# Simulation finished. Total passengers dropped: 57051. Remaining passengers: 4594.
# Simulation finished. Total passengers dropped: 56854. Remaining passengers: 4092.
# Simulation finished. Total passengers dropped: 56512. Remaining passengers: 4221.
# Simulation finished. Total passengers dropped: 57061. Remaining passengers: 4087.
# Simulation finished. Total passengers dropped: 57161. Remaining passengers: 4168.
# Simulation finished. Total passengers dropped: 109333. Remaining passengers: 207.
# Simulation finished. Total passengers dropped: 108466. Remaining passengers: 197.
# Simulation finished. Total passengers dropped: 61334. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 61346. Remaining passengers: 30.
# Simulation finished. Total passengers dropped: 60844. Remaining passengers: 34.
# Simulation finished. Total passengers dropped: 60918. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60822. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 108185. Remaining passengers: 191.
# Simulation finished. Total passengers dropped: 108716. Remaining passengers: 242.
# Simulation finished. Total passengers dropped: 56977. Remaining passengers: 4292.
# Simulation finished. Total passengers dropped: 57031. Remaining passengers: 4284.
# Simulation finished. Total passengers dropped: 56252. Remaining passengers: 4217.
# Simulation finished. Total passengers dropped: 57015. Remaining passengers: 4323.
# Simulation finished. Total passengers dropped: 57205. Remaining passengers: 4433.
# Simulation finished. Total passengers dropped: 107954. Remaining passengers: 199.
# Simulation finished. Total passengers dropped: 107863. Remaining passengers: 136.
# Simulation finished. Total passengers dropped: 61374. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 60950. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61522. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 61018. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61484. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 107432. Remaining passengers: 199.
# Simulation finished. Total passengers dropped: 107745. Remaining passengers: 170.
# Simulation finished. Total passengers dropped: 56599. Remaining passengers: 4490.
# Simulation finished. Total passengers dropped: 57189. Remaining passengers: 3954.
# Simulation finished. Total passengers dropped: 56820. Remaining passengers: 4428.
# Simulation finished. Total passengers dropped: 57334. Remaining passengers: 4222.
# Simulation finished. Total passengers dropped: 56807. Remaining passengers: 4541.
# Simulation finished. Total passengers dropped: 109347. Remaining passengers: 176.
# Simulation finished. Total passengers dropped: 108847. Remaining passengers: 201.
# Simulation finished. Total passengers dropped: 61852. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 61187. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 60852. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 60987. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 60717. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 108385. Remaining passengers: 157.
# Simulation finished. Total passengers dropped: 108794. Remaining passengers: 217.
# Simulation finished. Total passengers dropped: 56942. Remaining passengers: 4405.
# Simulation finished. Total passengers dropped: 56982. Remaining passengers: 4638.
# Simulation finished. Total passengers dropped: 56760. Remaining passengers: 4245.
# Simulation finished. Total passengers dropped: 57583. Remaining passengers: 4276.
# Simulation finished. Total passengers dropped: 56713. Remaining passengers: 3929.
# Simulation finished. Total passengers dropped: 107746. Remaining passengers: 236.
# Simulation finished. Total passengers dropped: 108851. Remaining passengers: 195.
# Simulation finished. Total passengers dropped: 61503. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 60882. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 60833. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 60976. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61041. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 108181. Remaining passengers: 189.
# Simulation finished. Total passengers dropped: 108321. Remaining passengers: 176.
# Simulation finished. Total passengers dropped: 56816. Remaining passengers: 4386.
# Simulation finished. Total passengers dropped: 56803. Remaining passengers: 4314.
# Simulation finished. Total passengers dropped: 56477. Remaining passengers: 3905.
# Simulation finished. Total passengers dropped: 56520. Remaining passengers: 4340.
# Simulation finished. Total passengers dropped: 57106. Remaining passengers: 4122.
# Simulation finished. Total passengers dropped: 108788. Remaining passengers: 213.
# ...
# Stop 4: 2024-12-14T06:40, 2024-12-14T07:20, 2024-12-14T07:50, 2024-12-14T08:00, 2024-12-14T08:30, 2024-12-14T08:40, 2024-12-14T09:00, 2024-12-14T09:10, 2024-12-14T09:20, 2024-12-14T09:40, 2024-12-14T09:50, 2024-12-14T10:00, 2024-12-14T10:10, 2024-12-14T10:20, 2024-12-14T10:30, 2024-12-14T10:40, 2024-12-14T10:50, 2024-12-14T11:00, 2024-12-14T11:10, 2024-12-14T11:20, 2024-12-14T11:20, 2024-12-14T11:30, 2024-12-14T11:40, 2024-12-14T11:50, 2024-12-14T12:00, 2024-12-14T12:00, 2024-12-14T12:10, 2024-12-14T12:20, 2024-12-14T12:30, 2024-12-14T12:30, 2024-12-14T12:40, 2024-12-14T12:40, 2024-12-14T12:50, 2024-12-14T13:00, 2024-12-14T13:10, 2024-12-14T13:10, 2024-12-14T13:20, 2024-12-14T13:20, 2024-12-14T13:30, 2024-12-14T13:40, 2024-12-14T13:40, 2024-12-14T13:50, 2024-12-14T13:50, 2024-12-14T14:00, 2024-12-14T14:00, 2024-12-14T14:10, 2024-12-14T14:20, 2024-12-14T14:20, 2024-12-14T14:30, 2024-12-14T14:30, 2024-12-14T14:40, 2024-12-14T14:40, 2024-12-14T14:50, 2024-12-14T14:50, 2024-12-14T15:00, 2024-12-14T15:00, 2024-12-14T15:10, 2024-12-14T15:10, 2024-12-14T15:20, 2024-12-14T15:20, 2024-12-14T15:30, 2024-12-14T15:30, 2024-12-14T15:40, 2024-12-14T15:40, 2024-12-14T15:50, 2024-12-14T15:50, 2024-12-14T16:00, 2024-12-14T16:00, 2024-12-14T16:00, 2024-12-14T16:10, 2024-12-14T16:10, 2024-12-14T16:10, 2024-12-14T16:20, 2024-12-14T16:20, 2024-12-14T16:20, 2024-12-14T16:30, 2024-12-14T16:30, 2024-12-14T16:30, 2024-12-14T16:40, 2024-12-14T16:40, 2024-12-14T16:40, 2024-12-14T16:40, 2024-12-14T16:50, 2024-12-14T16:50, 2024-12-14T16:50, 2024-12-14T16:50, 2024-12-14T17:00, 2024-12-14T17:00, 2024-12-14T17:00, 2024-12-14T17:00, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T17:40, 2024-12-14T17:40, 2024-12-14T17:40, 2024-12-14T17:40, 2024-12-14T17:40, 2024-12-14T17:50, 2024-12-14T17:50, 2024-12-14T17:50, 2024-12-14T17:50, 2024-12-14T17:50, 2024-12-14T18:00, 2024-12-14T18:00, 2024-12-14T18:00, 2024-12-14T18:00, 2024-12-14T18:00, 2024-12-14T18:10, 2024-12-14T18:10, 2024-12-14T18:10, 2024-12-14T18:10, 2024-12-14T18:10, 2024-12-14T18:10, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:50, 2024-12-14T18:50, 2024-12-14T18:50, 2024-12-14T18:50, 2024-12-14T18:50, 2024-12-14T18:50, 2024-12-14T18:50, 2024-12-14T19:00, 2024-12-14T19:00, 2024-12-14T19:00, 2024-12-14T19:00, 2024-12-14T19:00, 2024-12-14T19:00, 2024-12-14T19:00, 2024-12-14T19:10, 2024-12-14T19:10, 2024-12-14T19:10, 2024-12-14T19:10, 2024-12-14T19:10, 2024-12-14T19:10, 2024-12-14T19:20, 2024-12-14T19:20, 2024-12-14T19:20, 2024-12-14T19:20, 2024-12-14T19:20, 2024-12-14T19:20, 2024-12-14T19:20, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:30, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T20:00, 2024-12-14T20:00, 2024-12-14T20:00, 2024-12-14T20:00, 2024-12-14T20:00, 2024-12-14T20:00, 2024-12-14T20:00, 2024-12-14T20:00, 2024-12-14T20:10, 2024-12-14T20:10, 2024-12-14T20:10, 2024-12-14T20:10, 2024-12-14T20:10, 2024-12-14T20:10, 2024-12-14T20:10, 2024-12-14T20:10, 2024-12-14T20:10, 2024-12-14T20:20, 2024-12-14T20:20, 2024-12-14T20:20, 2024-12-14T20:20, 2024-12-14T20:20, 2024-12-14T20:20, 2024-12-14T20:20, 2024-12-14T20:20, 2024-12-14T20:30, 2024-12-14T20:30, 2024-12-14T20:30, 2024-12-14T20:30, 2024-12-14T20:30, 2024-12-14T20:30, 2024-12-14T20: ...
# Stop 5: 2024-12-14T06:50, 2024-12-14T07:30, 2024-12-14T08:00, 2024-12-14T08:10, 2024-12-14T08:40, 2024-12-14T08:50, 2024-12-14T09:10, 2024-12-14T09:20, 2024-12-14T09:30, 2024-12-14T09:50, 2024-12-14T10:00, 2024-12-14T10:10, 2024-12-14T10:20, 2024-12-14T10:30, 2024-12-14T10:40, 2024-12-14T10:50, 2024-12-14T11:00, 2024-12-14T11:10, 2024-12-14T11:20, 2024-12-14T11:30, 2024-12-14T11:30, 2024-12-14T11:40, 2024-12-14T11:50, 2024-12-14T12:00, 2024-12-14T12:10, 2024-12-14T12:10, 2024-12-14T12:20, 2024-12-14T12:30, 2024-12-14T12:40, 2024-12-14T12:40, 2024-12-14T12:50, 2024-12-14T12:50, 2024-12-14T13:00, 2024-12-14T13:10, 2024-12-14T13:20, 2024-12-14T13:20, 2024-12-14T13:30, 2024-12-14T13:30, 2024-12-14T13:40, 2024-12-14T13:50, 2024-12-14T13:50, 2024-12-14T14:00, 2024-12-14T14:00, 2024-12-14T14:10, 2024-12-14T14:10, 2024-12-14T14:20, 2024-12-14T14:30, 2024-12-14T14:30, 2024-12-14T14:40, 2024-12-14T14:40, 2024-12-14T14:50, 2024-12-14T14:50, 2024-12-14T15:00, 2024-12-14T15:00, 2024-12-14T15:10, 2024-12-14T15:10, 2024-12-14T15:20, 2024-12-14T15:20, 2024-12-14T15:30, 2024-12-14T15:30, 2024-12-14T15:40, 2024-12-14T15:40, 2024-12-14T15:50, 2024-12-14T15:50, 2024-12-14T16:00, 2024-12-14T16:00, 2024-12-14T16:10, 2024-12-14T16:10, 2024-12-14T16:20, 2024-12-14T16:20, 2024-12-14T16:30, 2024-12-14T16:30, 2024-12-14T16:40, 2024-12-14T16:40, 2024-12-14T16:50, 2024-12-14T16:50, 2024-12-14T17:00, 2024-12-14T17:00, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T17:30, 2024-12-14T17:40, 2024-12-14T17:40, 2024-12-14T17:50, 2024-12-14T17:50, 2024-12-14T18:00, 2024-12-14T18:00, 2024-12-14T18:10, 2024-12-14T18:20, 2024-12-14T18:20, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:40, 2024-12-14T18:50, 2024-12-14T19:00, 2024-12-14T19:00, 2024-12-14T19:10, 2024-12-14T19:10, 2024-12-14T19:20, 2024-12-14T19:30, 2024-12-14T19:40, 2024-12-14T19:40, 2024-12-14T19:50, 2024-12-14T20:00, 2024-12-14T20:10, 2024-12-14T20:20, 2024-12-14T20:20, 2024-12-14T20:30, 2024-12-14T20:40, 2024-12-14T20:50, 2024-12-14T21:00, 2024-12-14T21:10, 2024-12-14T21:20, 2024-12-14T21:30, 2024-12-14T21:40, 2024-12-14T21:50, 2024-12-14T22:00, 2024-12-14T22:20, 2024-12-14T22:30, 2024-12-14T22:40, 2024-12-14T23:00, 2024-12-14T23:10, 2024-12-14T23:40, 2024-12-14T23:50, 2024-12-15T00:20, 2024-12-15T01:00, 2024-12-15T02:10, 2024-12-15T02:50, 2024-12-15T03:20, 2024-12-15T03:30, 2024-12-15T04:00, 2024-12-15T04:10, 2024-12-15T04:30, 2024-12-15T04:40, 2024-12-15T04:50, 2024-12-15T05:10, 2024-12-15T05:20, 2024-12-15T05:30, 2024-12-15T05:40, 2024-12-15T05:50, 2024-12-15T06:00, 2024-12-15T06:10, 2024-12-15T06:20, 2024-12-15T06:30, 2024-12-15T06:40, 2024-12-15T06:50, 2024-12-15T06:50, 2024-12-15T07:00, 2024-12-15T07:10, 2024-12-15T07:20, 2024-12-15T07:30, 2024-12-15T07:30, 2024-12-15T07:40, 2024-12-15T07:50, 2024-12-15T08:00, 2024-12-15T08:00, 2024-12-15T08:10, 2024-12-15T08:10, 2024-12-15T08:20, 2024-12-15T08:30, 2024-12-15T08:40, 2024-12-15T08:40, 2024-12-15T08:50, 2024-12-15T08:50, 2024-12-15T09:00, 2024-12-15T09:10, 2024-12-15T09:10, 2024-12-15T09:20, 2024-12-15T09:20, 2024-12-15T09:30, 2024-12-15T09:30, 2024-12-15T09:40, 2024-12-15T09:50, 2024-12-15T09:50, 2024-12-15T10:00, 2024-12-15T10:00, 2024-12-15T10:10, 2024-12-15T10:10, 2024-12-15T10:20, 2024-12-15T10:20, 2024-12-15T10:30, 2024-12-15T10:30, 2024-12-15T10:40, 2024-12-15T10:40, 2024-12-15T10:50, 2024-12-15T10:50, 2024-12-15T11:00, 2024-12-15T11:00, 2024-12-15T11:10, 2024-12-15T11:10, 2024-12-15T11:20, 2024-12-15T11:20, 2024-12-15T11:30, 2024-12-15T11:30, 2024-12-15T11:30, 2024-12-15T11:40, 2024-12-15T11:40, 2024-12-15T11:50, 2024-12-15T11:50, 2024-12-15T12:00, 2024-12-15T12:00, 2024-12-15T12:10, 2024-12-15T12:10, 2024-12-15T12:10, 2024-12-15T12:20, 2024-12-15T12:20, 2024-12-15T12:30, 2024-12-15T12:30, 2024-12-15T12:40, 2024-12-15T12:40, 2024-12-15T12:50, 2024-12-15T12:50, 2024-12-15T13:00, 2024-12-15T13:00, 2024-12-15T13:10, 2024-12-15T13:10, 2024-12-15T13:20, 2024-12-15T13:20, 2024-12-15T13:30, 2024-12-15T13: ...
# Stop 6: 2024-12-14T07:00, 2024-12-14T07:40, 2024-12-14T08:10, 2024-12-14T08:20, 2024-12-14T08:50, 2024-12-14T09:00, 2024-12-14T09:20, 2024-12-14T09:30, 2024-12-14T09:40, 2024-12-14T10:00, 2024-12-14T10:10, 2024-12-14T10:20, 2024-12-14T10:30, 2024-12-14T10:40, 2024-12-14T10:50, 2024-12-14T11:00, 2024-12-14T11:10, 2024-12-14T11:20, 2024-12-14T11:30, 2024-12-14T11:40, 2024-12-14T11:40, 2024-12-14T11:50, 2024-12-14T12:00, 2024-12-14T12:10, 2024-12-14T12:20, 2024-12-14T12:20, 2024-12-14T12:30, 2024-12-14T12:40, 2024-12-14T12:50, 2024-12-14T12:50, 2024-12-14T13:00, 2024-12-14T13:00, 2024-12-14T13:10, 2024-12-14T13:20, 2024-12-14T13:30, 2024-12-14T13:30, 2024-12-14T13:40, 2024-12-14T13:40, 2024-12-14T13:50, 2024-12-14T14:00, 2024-12-14T14:00, 2024-12-14T14:10, 2024-12-14T14:10, 2024-12-14T14:20, 2024-12-14T14:20, 2024-12-14T14:30, 2024-12-14T14:40, 2024-12-14T14:40, 2024-12-14T14:50, 2024-12-14T14:50, 2024-12-14T15:00, 2024-12-14T15:00, 2024-12-14T15:10, 2024-12-14T15:10, 2024-12-14T15:20, 2024-12-14T15:20, 2024-12-14T15:30, 2024-12-14T15:30, 2024-12-14T15:40, 2024-12-14T15:40, 2024-12-14T15:50, 2024-12-14T15:50, 2024-12-14T16:00, 2024-12-14T16:00, 2024-12-14T16:10, 2024-12-14T16:10, 2024-12-14T16:20, 2024-12-14T16:20, 2024-12-14T16:30, 2024-12-14T16:30, 2024-12-14T16:40, 2024-12-14T16:40, 2024-12-14T16:50, 2024-12-14T16:50, 2024-12-14T17:00, 2024-12-14T17:00, 2024-12-14T17:10, 2024-12-14T17:10, 2024-12-14T17:20, 2024-12-14T17:20, 2024-12-14T17:30, 2024-12-14T17:30, 2024-12-14T17:40, 2024-12-14T17:50, 2024-12-14T17:50, 2024-12-14T18:00, 2024-12-14T18:00, 2024-12-14T18:10, 2024-12-14T18:10, 2024-12-14T18:20, 2024-12-14T18:30, 2024-12-14T18:30, 2024-12-14T18:40, 2024-12-14T18:40, 2024-12-14T18:50, 2024-12-14T19:00, 2024-12-14T19:10, 2024-12-14T19:10, 2024-12-14T19:20, 2024-12-14T19:20, 2024-12-14T19:30, 2024-12-14T19:40, 2024-12-14T19:50, 2024-12-14T19:50, 2024-12-14T20:00, 2024-12-14T20:10, 2024-12-14T20:20, 2024-12-14T20:30, 2024-12-14T20:30, 2024-12-14T20:40, 2024-12-14T20:50, 2024-12-14T21:00, 2024-12-14T21:10, 2024-12-14T21:20, 2024-12-14T21:30, 2024-12-14T21:40, 2024-12-14T21:50, 2024-12-14T22:00, 2024-12-14T22:10, 2024-12-14T22:30, 2024-12-14T22:40, 2024-12-14T22:50, 2024-12-14T23:10, 2024-12-14T23:20, 2024-12-14T23:50, 2024-12-15T00:00, 2024-12-15T00:30, 2024-12-15T01:10, 2024-12-15T02:20, 2024-12-15T03:00, 2024-12-15T03:30, 2024-12-15T03:40, 2024-12-15T04:10, 2024-12-15T04:20, 2024-12-15T04:40, 2024-12-15T04:50, 2024-12-15T05:00, 2024-12-15T05:20, 2024-12-15T05:30, 2024-12-15T05:40, 2024-12-15T05:50, 2024-12-15T06:00, 2024-12-15T06:10, 2024-12-15T06:20, 2024-12-15T06:30, 2024-12-15T06:40, 2024-12-15T06:50, 2024-12-15T07:00, 2024-12-15T07:00, 2024-12-15T07:10, 2024-12-15T07:20, 2024-12-15T07:30, 2024-12-15T07:40, 2024-12-15T07:40, 2024-12-15T07:50, 2024-12-15T08:00, 2024-12-15T08:10, 2024-12-15T08:10, 2024-12-15T08:20, 2024-12-15T08:20, 2024-12-15T08:30, 2024-12-15T08:40, 2024-12-15T08:50, 2024-12-15T08:50, 2024-12-15T09:00, 2024-12-15T09:00, 2024-12-15T09:10, 2024-12-15T09:20, 2024-12-15T09:20, 2024-12-15T09:30, 2024-12-15T09:30, 2024-12-15T09:40, 2024-12-15T09:40, 2024-12-15T09:50, 2024-12-15T10:00, 2024-12-15T10:00, 2024-12-15T10:10, 2024-12-15T10:10, 2024-12-15T10:20, 2024-12-15T10:20, 2024-12-15T10:30, 2024-12-15T10:30, 2024-12-15T10:40, 2024-12-15T10:40, 2024-12-15T10:50, 2024-12-15T10:50, 2024-12-15T11:00, 2024-12-15T11:00, 2024-12-15T11:10, 2024-12-15T11:10, 2024-12-15T11:20, 2024-12-15T11:20, 2024-12-15T11:30, 2024-12-15T11:30, 2024-12-15T11:40, 2024-12-15T11:40, 2024-12-15T11:40, 2024-12-15T11:50, 2024-12-15T11:50, 2024-12-15T12:00, 2024-12-15T12:00, 2024-12-15T12:10, 2024-12-15T12:10, 2024-12-15T12:20, 2024-12-15T12:20, 2024-12-15T12:20, 2024-12-15T12:30, 2024-12-15T12:30, 2024-12-15T12:40, 2024-12-15T12:40, 2024-12-15T12:50, 2024-12-15T12:50, 2024-12-15T13:00, 2024-12-15T13:00, 2024-12-15T13:10, 2024-12-15T13:10, 2024-12-15T13:20, 2024-12-15T13:20, 2024-12-15T13:30, 2024-12-15T13:30, 2024-12-15T13:40, 2024-12-15T13: ...

# %%
import pandas as pd

def generate_schedule_tables(simulation, is_weekday=True):
    day_type = "Weekday" if is_weekday else "Weekend"
    schedule_tables = {}
    
    for stop, times in simulation.schedule.items():
        filtered_times = []
        for time in times:
            time_obj = pd.Timestamp(time)
            hour = time_obj.hour
            if (6 <= hour < 24) or (hour < 3):  # Рабочие часы: с 6 утра до 3 ночи
                filtered_times.append(time_obj.strftime("%H:%M"))
        
        # Удаляем дубликаты и сортируем
        unique_times = sorted(set(filtered_times))

        # Создаем DataFrame для расписания
        df = pd.DataFrame({"Time": unique_times})
        schedule_tables[f"Stop {stop} ({day_type})"] = df

    return schedule_tables


def save_schedule_to_file(schedule_tables, filename_prefix):
    for stop, table in schedule_tables.items():
        filename = f"{filename_prefix}_{stop.replace(' ', '_').replace('(', '').replace(')', '')}.csv"
        table.to_csv(filename, index=False, encoding="utf-8")
        print(f"Saved {stop} schedule to file: {filename}")

weekday_tables = generate_schedule_tables(simulation, is_weekday=True)
save_schedule_to_file(weekday_tables, filename_prefix="weekday_schedule")


weekend_tables = generate_schedule_tables(simulation, is_weekday=False)
save_schedule_to_file(weekend_tables, filename_prefix="weekend_schedule")
# Out:
# Saved Stop 0 (Weekday) schedule to file: weekday_schedule_Stop_0_Weekday.csv
# Saved Stop 1 (Weekday) schedule to file: weekday_schedule_Stop_1_Weekday.csv
# Saved Stop 2 (Weekday) schedule to file: weekday_schedule_Stop_2_Weekday.csv
# Saved Stop 3 (Weekday) schedule to file: weekday_schedule_Stop_3_Weekday.csv
# Saved Stop 4 (Weekday) schedule to file: weekday_schedule_Stop_4_Weekday.csv
# Saved Stop 5 (Weekday) schedule to file: weekday_schedule_Stop_5_Weekday.csv
# Saved Stop 6 (Weekday) schedule to file: weekday_schedule_Stop_6_Weekday.csv
# Saved Stop 0 (Weekend) schedule to file: weekend_schedule_Stop_0_Weekend.csv
# Saved Stop 1 (Weekend) schedule to file: weekend_schedule_Stop_1_Weekend.csv
# Saved Stop 2 (Weekend) schedule to file: weekend_schedule_Stop_2_Weekend.csv
# Saved Stop 3 (Weekend) schedule to file: weekend_schedule_Stop_3_Weekend.csv
# Saved Stop 4 (Weekend) schedule to file: weekend_schedule_Stop_4_Weekend.csv
# Saved Stop 5 (Weekend) schedule to file: weekend_schedule_Stop_5_Weekend.csv
# Saved Stop 6 (Weekend) schedule to file: weekend_schedule_Stop_6_Weekend.csv
