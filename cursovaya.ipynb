# %%
import random
import numpy as np
import time
from datetime import timedelta, datetime


class BusStop:
    def __init__(self, passengers_waiting: int):
        self.passengers_waiting = passengers_waiting

    def board_passengers(self, available_seats: int) -> int:
        board_count = min(self.passengers_waiting, available_seats)
        self.passengers_waiting -= board_count
        return board_count

    def add_passengers(self, peak: bool):
        chance = random.random()
        if peak:
            if chance < 0.7:  
                self.passengers_waiting += random.randint(3, 7)
        else:
            if chance < 0.3:  
                self.passengers_waiting += random.randint(1, 3)

class Route:
    def __init__(self, bus_stops_num: int, route_duration: int, peak: bool, upper_limit: int):
        self.num_stops = bus_stops_num
        self.time_between_stops = route_duration // bus_stops_num  
        self.bus_stops = [
            BusStop(random.randint(0, int(upper_limit * (0.7 if peak else 0.3))))
            for _ in range(bus_stops_num)
        ]
class Driver:
    def __init__(self, name: str, shift_duration: int, break_duration: int, schedule_type: str):
        self.name = name
        self.shift_duration = shift_duration
        self.break_duration = break_duration
        self.schedule_type = schedule_type  
        self.time_worked = 0
        self.on_break = False
        self.break_time_remaining = 0

    def work(self, is_peak: bool = False):
        if self.on_break:
            self.break_time_remaining -= 1
            if self.break_time_remaining <= 0:
                self.on_break = False
            return False

        self.time_worked += 1

        if self.schedule_type == "standard":
            if self.time_worked >= self.shift_duration:
                self.start_break()
        elif self.schedule_type == "night":
            if self.time_worked % 120 == 0 and not is_peak: 
                self.start_break()
        return True

    def start_break(self):
        self.on_break = True
        self.break_time_remaining = self.break_duration
        self.time_worked = 0 if self.schedule_type == "standard" else self.time_worked  
class Bus:
    def __init__(self, capacity: int = 20, driver: Driver = None):
        self.capacity = capacity
        self.currently_onboard = 0
        self.driver = driver

    def load_passengers(self, bus_stop):
        if self.driver and not self.driver.work():
            #print(f"Driver {self.driver.name} is on break. Bus cannot load passengers.")
            return 0

        available_seats = self.capacity - self.currently_onboard
        boarding_passengers = bus_stop.board_passengers(available_seats=available_seats)
        self.currently_onboard += boarding_passengers
        return boarding_passengers

    def unload_all_passengers(self):
        exiting_passengers = self.currently_onboard
        self.currently_onboard = 0
        return exiting_passengers
class Simulation:
    def __init__(
        self,
        bus_num: int,
        route_duration: int,
        bus_stops_num: int,
        start_time: np.datetime64,
        end_time: np.datetime64,
        tag: str,
        driver_schedule_type: str,
        driver_shift_duration: int,
        driver_break_duration: int,
        driver_num: int,
    ):
        self.tag = tag
        self.tick = 0
        self.route = Route(bus_stops_num, route_duration, tag in {"monday", "tuesday", "wednesday", "thursday", "friday"}, 100)
        self.time_between_stops = self.route.time_between_stops
        self.end_tick = ((end_time - start_time).astype("timedelta64[m]").item().seconds // self.time_between_stops)
        self.drivers = [
            Driver(
                name=f"Driver {i}",
                shift_duration=driver_shift_duration,
                break_duration=driver_break_duration,
                schedule_type=driver_schedule_type,
            )
            for i in range(driver_num)
        ]
        self.buses = [Bus(driver=self.drivers[i]) for i in range(bus_num)]
        self.bus_positions = [0 for _ in range(bus_num)]
        self.bus_intervals = route_duration // bus_num
        self.start_time = start_time

        self.schedule = {i: [] for i in range(self.route.num_stops)}
        self.bus_start_ticks = [i * self.bus_intervals for i in range(bus_num)]

    def play_simulation(self):
        total_passengers_dropped = 0
        while self.tick < self.end_tick:
            current_time_in_seconds = int((self.start_time + np.timedelta64(self.tick * self.time_between_stops, 'm')).astype("timedelta64[s]").item().seconds % 86400)
            current_hour = current_time_in_seconds // 3600
            is_peak = (7 <= current_hour < 9) or (17 <= current_hour < 19)

            for stop in self.route.bus_stops:
                stop.add_passengers(peak=is_peak if self.tag not in {"saturday", "sunday"} else random.random() < 0.5)

            for i, bus in enumerate(self.buses):
                if self.tick < self.bus_start_ticks[i]:
                    continue

                stop_index = self.bus_positions[i]
                current_time = self.start_time + np.timedelta64(self.tick * self.time_between_stops, 'm')
                self.schedule[stop_index].append(str(current_time))

                if stop_index == len(self.route.bus_stops) - 1:
                    total_passengers_dropped += bus.unload_all_passengers()

                if not bus.driver.work(is_peak):
                    continue

                boarding = bus.load_passengers(self.route.bus_stops[stop_index])
                self.bus_positions[i] = (stop_index + 1) % self.route.num_stops

            self.tick += 1

        remaining_passengers = sum(stop.passengers_waiting for stop in self.route.bus_stops)
        print(f"Simulation finished. Total passengers dropped: {total_passengers_dropped}. Remaining passengers: {remaining_passengers}.")

    def print_schedule(self):
        print("\nBus Schedule:")
        for stop, times in self.schedule.items():
            print(f"Stop {stop}: {', '.join(times)}")

def simulate_with_parameters(bus_num, driver_num, driver_schedule_type, route_duration, bus_stops_num, start_time, end_time, driver_shift_duration, driver_break_duration):
    if driver_num < bus_num: 
        return float("inf") 
    sim = Simulation(
        bus_num=bus_num,
        route_duration=route_duration,
        bus_stops_num=bus_stops_num,
        start_time=start_time,
        end_time=end_time,
        tag="monday",  # Use weekday for peak load
        driver_schedule_type=driver_schedule_type,
        driver_shift_duration=driver_shift_duration,
        driver_break_duration=driver_break_duration,
        driver_num=driver_num
    )
    sim.play_simulation()

    remaining_passengers = sum(stop.passengers_waiting for stop in sim.route.bus_stops)
    return remaining_passengers

def brute_force_optimization(route_duration, bus_stops_num, start_time, end_time, driver_shift_duration, driver_break_duration):
    best_bus_num = None
    best_driver_num = None
    min_remaining_passengers = float("inf")
    start_time_exec = time.time()

    with open("brute_force_results.txt", "w") as f, open("best_results_brute_force.txt", "w") as best_f:
        for bus_num in range(8, 21):
            for driver_num in range(bus_num, 21):  # Ensure drivers >= buses
                for schedule_type in ["standard", "night"]:
                    remaining_passengers = simulate_with_parameters(
                        bus_num=bus_num,
                        driver_num=driver_num,
                        driver_schedule_type=schedule_type,
                        route_duration=route_duration,
                        bus_stops_num=bus_stops_num,
                        start_time=start_time,
                        end_time=end_time,
                        driver_shift_duration=driver_shift_duration,
                        driver_break_duration=driver_break_duration,
                    )

                    if remaining_passengers < min_remaining_passengers:
                        best_bus_num = bus_num
                        best_driver_num = driver_num
                        min_remaining_passengers = remaining_passengers

                    f.write(f"Buses: {bus_num}, Drivers: {driver_num}, Type: {schedule_type}, Remaining: {remaining_passengers}\n")

        exec_time = time.time() - start_time_exec
        best_f.write(f"Best Buses: {best_bus_num}, Best Drivers: {best_driver_num}, Execution Time: {exec_time:.2f} seconds\n")
    return best_bus_num, best_driver_num

def genetic_algorithm_optimization(
    route_duration, 
    bus_stops_num, 
    start_time, 
    end_time, 
    driver_shift_duration, 
    driver_break_duration,
    population_size=10, 
    generations=50, 
    patience=10, 
    log_file="genetic_algorithm_log.txt",
):
    start_time_exec = time.time()

    population = [
        {
            "bus_num": random.randint(bus_stops_num, 20),
            "driver_num": random.randint(bus_stops_num, 20),
            "schedule_type": random.choice(["standard", "night"]),
        }
        for _ in range(population_size)
    ]

    best_solution = None
    best_fitness = float("inf")
    generations_without_improvement = 0

    with open(log_file, "w") as log, open("best_results_genetic_algorithm.txt", "w") as best_f:
        log.write("Generation,Bus_Num,Driver_Num,Schedule_Type,Remaining_Passengers\n")

        for generation in range(generations):
            fitness_scores = []
            for individual in population:
                if individual["driver_num"] < individual["bus_num"]:  # Ensure drivers >= buses
                    fitness_scores.append((individual, float("inf")))
                    continue

                remaining_passengers = simulate_with_parameters(
                    bus_num=individual["bus_num"],
                    driver_num=individual["driver_num"],
                    driver_schedule_type=individual["schedule_type"],
                    route_duration=route_duration,
                    bus_stops_num=bus_stops_num,
                    start_time=start_time,
                    end_time=end_time,
                    driver_shift_duration=driver_shift_duration,
                    driver_break_duration=driver_break_duration,
                )

                fitness_scores.append((individual, remaining_passengers))

                if remaining_passengers < best_fitness:
                    best_solution = individual
                    best_fitness = remaining_passengers
                    generations_without_improvement = 0

            fitness_scores.sort(key=lambda x: x[1])

            top_individuals = [fs[0] for fs in fitness_scores[: population_size // 2]]

            new_population = []
            for _ in range(population_size):
                parent1, parent2 = random.sample(top_individuals, 2)
                child = {
                    "bus_num": max(1, (parent1["bus_num"] + parent2["bus_num"]) // 2),
                    "driver_num": max(parent1["bus_num"], (parent1["driver_num"] + parent2["driver_num"]) // 2),
                    "schedule_type": random.choice([parent1["schedule_type"], parent2["schedule_type"]]),
                }

                if random.random() < 0.1:
                    child["bus_num"] = max(1, min(20, child["bus_num"] + random.choice([-1, 1])))
                    child["driver_num"] = max(child["bus_num"], min(20, child["driver_num"] + random.choice([-1, 1])))

                new_population.append(child)

            population = new_population
            generations_without_improvement += 1

            if generations_without_improvement >= patience:
                break

        exec_time = time.time() - start_time_exec
        best_f.write(f"Best Solution: {best_solution}, Execution Time: {exec_time:.2f} seconds\n")

    return best_solution

route_duration = 70
bus_stops_num = 7
start_time = np.datetime64('2024-12-14T06:00')
end_time = np.datetime64('2024-12-15T03:00')
driver_shift_duration = 420
driver_break_duration = 60

best_bus_num, best_driver_num = brute_force_optimization(
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
)
print(f"Best configuration from brute force: Buses = {best_bus_num}, Drivers = {best_driver_num}")

best_solution = genetic_algorithm_optimization(
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
)
print(f"Best configuration from genetic algorithm: {best_solution}")
# Out:
# Simulation finished. Total passengers dropped: 58387. Remaining passengers: 2858.
# Simulation finished. Total passengers dropped: 51972. Remaining passengers: 8299.
# Simulation finished. Total passengers dropped: 58269. Remaining passengers: 2470.
# Simulation finished. Total passengers dropped: 52802. Remaining passengers: 8436.
# Simulation finished. Total passengers dropped: 58664. Remaining passengers: 2829.
# Simulation finished. Total passengers dropped: 53045. Remaining passengers: 7990.
# Simulation finished. Total passengers dropped: 58398. Remaining passengers: 2416.
# Simulation finished. Total passengers dropped: 53201. Remaining passengers: 8107.
# Simulation finished. Total passengers dropped: 58837. Remaining passengers: 2776.
# Simulation finished. Total passengers dropped: 53085. Remaining passengers: 8270.
# Simulation finished. Total passengers dropped: 58391. Remaining passengers: 2611.
# Simulation finished. Total passengers dropped: 53221. Remaining passengers: 8071.
# Simulation finished. Total passengers dropped: 58142. Remaining passengers: 2834.
# Simulation finished. Total passengers dropped: 53011. Remaining passengers: 7858.
# Simulation finished. Total passengers dropped: 58277. Remaining passengers: 2980.
# Simulation finished. Total passengers dropped: 53550. Remaining passengers: 7949.
# Simulation finished. Total passengers dropped: 57898. Remaining passengers: 2704.
# Simulation finished. Total passengers dropped: 53061. Remaining passengers: 8389.
# Simulation finished. Total passengers dropped: 58490. Remaining passengers: 2954.
# Simulation finished. Total passengers dropped: 53121. Remaining passengers: 8075.
# Simulation finished. Total passengers dropped: 58991. Remaining passengers: 2627.
# Simulation finished. Total passengers dropped: 53607. Remaining passengers: 8041.
# Simulation finished. Total passengers dropped: 58422. Remaining passengers: 2458.
# Simulation finished. Total passengers dropped: 52871. Remaining passengers: 8112.
# Simulation finished. Total passengers dropped: 58340. Remaining passengers: 2861.
# Simulation finished. Total passengers dropped: 53366. Remaining passengers: 8003.
# Simulation finished. Total passengers dropped: 60432. Remaining passengers: 998.
# Simulation finished. Total passengers dropped: 54716. Remaining passengers: 6685.
# Simulation finished. Total passengers dropped: 59994. Remaining passengers: 724.
# Simulation finished. Total passengers dropped: 54542. Remaining passengers: 6734.
# Simulation finished. Total passengers dropped: 60452. Remaining passengers: 819.
# Simulation finished. Total passengers dropped: 54076. Remaining passengers: 6997.
# Simulation finished. Total passengers dropped: 60203. Remaining passengers: 736.
# Simulation finished. Total passengers dropped: 54314. Remaining passengers: 7079.
# Simulation finished. Total passengers dropped: 60450. Remaining passengers: 820.
# Simulation finished. Total passengers dropped: 54451. Remaining passengers: 6940.
# Simulation finished. Total passengers dropped: 60735. Remaining passengers: 741.
# Simulation finished. Total passengers dropped: 54060. Remaining passengers: 6908.
# Simulation finished. Total passengers dropped: 60277. Remaining passengers: 599.
# Simulation finished. Total passengers dropped: 54082. Remaining passengers: 7076.
# Simulation finished. Total passengers dropped: 61040. Remaining passengers: 723.
# Simulation finished. Total passengers dropped: 54071. Remaining passengers: 6724.
# Simulation finished. Total passengers dropped: 60655. Remaining passengers: 848.
# Simulation finished. Total passengers dropped: 53916. Remaining passengers: 6987.
# Simulation finished. Total passengers dropped: 60126. Remaining passengers: 805.
# Simulation finished. Total passengers dropped: 54283. Remaining passengers: 6719.
# Simulation finished. Total passengers dropped: 60411. Remaining passengers: 813.
# Simulation finished. Total passengers dropped: 54609. Remaining passengers: 7026.
# Simulation finished. Total passengers dropped: 60659. Remaining passengers: 1010.
# Simulation finished. Total passengers dropped: 54642. Remaining passengers: 6977.
# Simulation finished. Total passengers dropped: 60911. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 55858. Remaining passengers: 5591.
# Simulation finished. Total passengers dropped: 61015. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 55658. Remaining passengers: 5663.
# Simulation finished. Total passengers dropped: 61367. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 55302. Remaining passengers: 5685.
# Simulation finished. Total passengers dropped: 60821. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 55375. Remaining passengers: 5594.
# Simulation finished. Total passengers dropped: 60412. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 55518. Remaining passengers: 5155.
# Simulation finished. Total passengers dropped: 61380. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 55595. Remaining passengers: 6212.
# Simulation finished. Total passengers dropped: 61055. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 55797. Remaining passengers: 5533.
# Simulation finished. Total passengers dropped: 61974. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 55711. Remaining passengers: 5330.
# Simulation finished. Total passengers dropped: 61556. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 55324. Remaining passengers: 6103.
# Simulation finished. Total passengers dropped: 61865. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 55374. Remaining passengers: 5712.
# Simulation finished. Total passengers dropped: 61019. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 55287. Remaining passengers: 5681.
# Simulation finished. Total passengers dropped: 61652. Remaining passengers: 24.
# Simulation finished. Total passengers dropped: 57098. Remaining passengers: 4286.
# Simulation finished. Total passengers dropped: 61167. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 56970. Remaining passengers: 4227.
# Simulation finished. Total passengers dropped: 61023. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 57087. Remaining passengers: 4367.
# Simulation finished. Total passengers dropped: 60772. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 57135. Remaining passengers: 4381.
# Simulation finished. Total passengers dropped: 61455. Remaining passengers: 31.
# Simulation finished. Total passengers dropped: 56626. Remaining passengers: 4403.
# Simulation finished. Total passengers dropped: 60855. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 56743. Remaining passengers: 4404.
# Simulation finished. Total passengers dropped: 61225. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 57189. Remaining passengers: 4294.
# Simulation finished. Total passengers dropped: 61496. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 56709. Remaining passengers: 4075.
# Simulation finished. Total passengers dropped: 60837. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 56833. Remaining passengers: 4302.
# Simulation finished. Total passengers dropped: 61275. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 57214. Remaining passengers: 4371.
# Simulation finished. Total passengers dropped: 61494. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 58235. Remaining passengers: 3091.
# Simulation finished. Total passengers dropped: 61363. Remaining passengers: 36.
# Simulation finished. Total passengers dropped: 57793. Remaining passengers: 3367.
# Simulation finished. Total passengers dropped: 61375. Remaining passengers: 38.
# Simulation finished. Total passengers dropped: 58253. Remaining passengers: 3352.
# Simulation finished. Total passengers dropped: 61195. Remaining passengers: 50.
# Simulation finished. Total passengers dropped: 58504. Remaining passengers: 3344.
# Simulation finished. Total passengers dropped: 61007. Remaining passengers: 38.
# Simulation finished. Total passengers dropped: 58692. Remaining passengers: 3131.
# Simulation finished. Total passengers dropped: 60745. Remaining passengers: 23.
# Simulation finished. Total passengers dropped: 58017. Remaining passengers: 3283.
# Simulation finished. Total passengers dropped: 60992. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 57443. Remaining passengers: 2859.
# Simulation finished. Total passengers dropped: 60858. Remaining passengers: 43.
# Simulation finished. Total passengers dropped: 57639. Remaining passengers: 3356.
# Simulation finished. Total passengers dropped: 61403. Remaining passengers: 31.
# Simulation finished. Total passengers dropped: 58262. Remaining passengers: 3208.
# Simulation finished. Total passengers dropped: 61443. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 59311. Remaining passengers: 1915.
# Simulation finished. Total passengers dropped: 61534. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 59435. Remaining passengers: 1819.
# Simulation finished. Total passengers dropped: 61040. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 59341. Remaining passengers: 1660.
# Simulation finished. Total passengers dropped: 60908. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 59327. Remaining passengers: 1842.
# Simulation finished. Total passengers dropped: 61122. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 58972. Remaining passengers: 1672.
# Simulation finished. Total passengers dropped: 61318. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 59844. Remaining passengers: 1947.
# Simulation finished. Total passengers dropped: 60780. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 59636. Remaining passengers: 1765.
# Simulation finished. Total passengers dropped: 61209. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 59470. Remaining passengers: 2017.
# Simulation finished. Total passengers dropped: 61061. Remaining passengers: 4.
# Simulation finished. Total passengers dropped: 60621. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 60831. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60465. Remaining passengers: 682.
# Simulation finished. Total passengers dropped: 60326. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 61145. Remaining passengers: 557.
# Simulation finished. Total passengers dropped: 61791. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60728. Remaining passengers: 398.
# Simulation finished. Total passengers dropped: 61167. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 60506. Remaining passengers: 374.
# Simulation finished. Total passengers dropped: 61211. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60732. Remaining passengers: 408.
# Simulation finished. Total passengers dropped: 61216. Remaining passengers: 7.
# Simulation finished. Total passengers dropped: 60293. Remaining passengers: 416.
# Simulation finished. Total passengers dropped: 61624. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 60578. Remaining passengers: 28.
# Simulation finished. Total passengers dropped: 61025. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 61046. Remaining passengers: 35.
# Simulation finished. Total passengers dropped: 61087. Remaining passengers: 30.
# Simulation finished. Total passengers dropped: 61078. Remaining passengers: 23.
# Simulation finished. Total passengers dropped: 61400. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 60831. Remaining passengers: 44.
# Simulation finished. Total passengers dropped: 60957. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 61324. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 60539. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 60924. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61014. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61045. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60797. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 61119. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61519. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61074. Remaining passengers: 4.
# Simulation finished. Total passengers dropped: 61266. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61832. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61337. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61685. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60932. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61821. Remaining passengers: 2.
# Simulation finished. Total passengers dropped: 61215. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60702. Remaining passengers: 4.
# Simulation finished. Total passengers dropped: 61525. Remaining passengers: 3.
# Simulation finished. Total passengers dropped: 61472. Remaining passengers: 3.
# Simulation finished. Total passengers dropped: 61587. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61505. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61829. Remaining passengers: 38.
# Simulation finished. Total passengers dropped: 61532. Remaining passengers: 47.
# Simulation finished. Total passengers dropped: 61533. Remaining passengers: 50.
# Simulation finished. Total passengers dropped: 61504. Remaining passengers: 61.
# Simulation finished. Total passengers dropped: 61758. Remaining passengers: 40.
# Simulation finished. Total passengers dropped: 61197. Remaining passengers: 53.
# Simulation finished. Total passengers dropped: 60822. Remaining passengers: 28.
# Simulation finished. Total passengers dropped: 61272. Remaining passengers: 39.
# Simulation finished. Total passengers dropped: 61340. Remaining passengers: 35.
# Simulation finished. Total passengers dropped: 61422. Remaining passengers: 24.
# Simulation finished. Total passengers dropped: 61371. Remaining passengers: 29.
# Simulation finished. Total passengers dropped: 60963. Remaining passengers: 26.
# Best configuration from brute force: Buses = 17, Drivers = 17
# Simulation finished. Total passengers dropped: 33226. Remaining passengers: 28228.
# Simulation finished. Total passengers dropped: 61140. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 52223. Remaining passengers: 8607.
# Simulation finished. Total passengers dropped: 60845. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 50493. Remaining passengers: 10510.
# Simulation finished. Total passengers dropped: 52121. Remaining passengers: 9419.
# Simulation finished. Total passengers dropped: 58034. Remaining passengers: 3093.
# Simulation finished. Total passengers dropped: 56674. Remaining passengers: 4441.
# Simulation finished. Total passengers dropped: 58196. Remaining passengers: 2755.
# Simulation finished. Total passengers dropped: 54506. Remaining passengers: 6849.
# Simulation finished. Total passengers dropped: 56709. Remaining passengers: 4271.
# Simulation finished. Total passengers dropped: 58887. Remaining passengers: 2493.
# Simulation finished. Total passengers dropped: 61254. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61747. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 61226. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 57023. Remaining passengers: 4444.
# Simulation finished. Total passengers dropped: 61323. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60639. Remaining passengers: 869.
# Simulation finished. Total passengers dropped: 58562. Remaining passengers: 2833.
# Simulation finished. Total passengers dropped: 61768. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61425. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 61629. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60492. Remaining passengers: 612.
# Simulation finished. Total passengers dropped: 60302. Remaining passengers: 854.
# Simulation finished. Total passengers dropped: 60240. Remaining passengers: 792.
# Simulation finished. Total passengers dropped: 61250. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61329. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61003. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61245. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 60996. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61375. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61444. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 61290. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61216. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 60642. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61202. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 60989. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61131. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61372. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 61213. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61050. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61531. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60875. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61509. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 60570. Remaining passengers: 792.
# Simulation finished. Total passengers dropped: 61624. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 60230. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61435. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61107. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60999. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 60178. Remaining passengers: 994.
# Simulation finished. Total passengers dropped: 61507. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61583. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 61310. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 60657. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 61116. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 61012. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 60951. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61188. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 61230. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 60876. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 61144. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 61184. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 60995. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61071. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 60584. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 61778. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 60936. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61477. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 61495. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61345. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 61090. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 60689. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61024. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60843. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61400. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61551. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61259. Remaining passengers: 7.
# Simulation finished. Total passengers dropped: 60708. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 60836. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61103. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 60815. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61098. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61310. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 60496. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60976. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61044. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61472. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61024. Remaining passengers: 23.
# Simulation finished. Total passengers dropped: 61186. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61446. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61056. Remaining passengers: 28.
# Simulation finished. Total passengers dropped: 61243. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61116. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 60790. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61465. Remaining passengers: 13.
# Best configuration from genetic algorithm: {'bus_num': 10, 'driver_num': 11, 'schedule_type': 'standard'}

# %%
def simulate_week_with_parameters(bus_num, driver_num, driver_schedule_type, route_duration, bus_stops_num, start_time, end_time, driver_shift_duration, driver_break_duration):
    days = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]
    total_remaining_passengers = 0  # Суммируем оставшихся пассажиров за неделю

    for day in days:
        sim = Simulation(
            bus_num=bus_num,
            route_duration=route_duration,
            bus_stops_num=bus_stops_num,
            start_time=start_time,
            end_time=end_time,
            tag=day,
            driver_schedule_type=driver_schedule_type,
            driver_shift_duration=driver_shift_duration,
            driver_break_duration=driver_break_duration,
            driver_num=driver_num
        )
        sim.play_simulation()
        total_remaining_passengers += sum(stop.passengers_waiting for stop in sim.route.bus_stops)

    return total_remaining_passengers

def brute_force_optimization(route_duration, bus_stops_num, start_time, end_time, driver_shift_duration, driver_break_duration):
    best_bus_num = None
    best_driver_num = None
    best_schedule_type = None
    min_remaining_passengers = float("inf")
    start_time_exec = time.time()

    with open("brute_force_weekly_results.txt", "w") as f, open("best_results_brute_force_weekly.txt", "w") as best_f:
        for bus_num in range(8, 21):
            for driver_num in range(bus_num, 21):  # Ensure drivers >= buses
                for schedule_type in ["standard", "night"]:
                    remaining_passengers = simulate_week_with_parameters(
                        bus_num=bus_num,
                        driver_num=driver_num,
                        driver_schedule_type=schedule_type,
                        route_duration=route_duration,
                        bus_stops_num=bus_stops_num,
                        start_time=start_time,
                        end_time=end_time,
                        driver_shift_duration=driver_shift_duration,
                        driver_break_duration=driver_break_duration,
                    )

                    if remaining_passengers < min_remaining_passengers:
                        best_bus_num = bus_num
                        best_driver_num = driver_num
                        best_schedule_type = schedule_type
                        min_remaining_passengers = remaining_passengers

                    f.write(f"Buses: {bus_num}, Drivers: {driver_num}, Type: {schedule_type}, Remaining: {remaining_passengers}\n")

        exec_time = time.time() - start_time_exec
        best_f.write(f"Best Buses: {best_bus_num}, Best Drivers: {best_driver_num}, Type: {best_schedule_type}, Execution Time: {exec_time:.2f} seconds\n")
    return best_bus_num, best_driver_num, best_schedule_type

def genetic_algorithm_optimization(
    route_duration, 
    bus_stops_num, 
    start_time, 
    end_time, 
    driver_shift_duration, 
    driver_break_duration, 
    population_size=10, 
    generations=50, 
    patience=10, 
    log_file="genetic_algorithm_weekly_log.txt"
):
    start_time_exec = time.time()

    population = [
        {
            "bus_num": random.randint(1, 20),
            "driver_num": random.randint(1, 20),
            "schedule_type": random.choice(["standard", "night"]),
        }
        for _ in range(population_size)
    ]

    best_solution = None
    best_fitness = float("inf")
    generations_without_improvement = 0

    with open(log_file, "w") as log, open("best_results_genetic_algorithm_weekly.txt", "w") as best_f:
        log.write("Generation,Bus_Num,Driver_Num,Schedule_Type,Remaining_Passengers\n")

        for generation in range(generations):
            fitness_scores = []
            for individual in population:
                if individual["driver_num"] < individual["bus_num"]:  # Ensure drivers >= buses
                    fitness_scores.append((individual, float("inf")))
                    continue

                remaining_passengers = simulate_week_with_parameters(
                    bus_num=individual["bus_num"],
                    driver_num=individual["driver_num"],
                    driver_schedule_type=individual["schedule_type"],
                    route_duration=route_duration,
                    bus_stops_num=bus_stops_num,
                    start_time=start_time,
                    end_time=end_time,
                    driver_shift_duration=driver_shift_duration,
                    driver_break_duration=driver_break_duration,
                )

                fitness_scores.append((individual, remaining_passengers))

                if remaining_passengers < best_fitness:
                    best_solution = individual
                    best_fitness = remaining_passengers
                    generations_without_improvement = 0

            fitness_scores.sort(key=lambda x: x[1])

            top_individuals = [fs[0] for fs in fitness_scores[: population_size // 2]]

            new_population = []
            for _ in range(population_size):
                parent1, parent2 = random.sample(top_individuals, 2)
                child = {
                    "bus_num": max(1, (parent1["bus_num"] + parent2["bus_num"]) // 2),
                    "driver_num": max(parent1["bus_num"], (parent1["driver_num"] + parent2["driver_num"]) // 2),
                    "schedule_type": random.choice([parent1["schedule_type"], parent2["schedule_type"]]),
                }

                if random.random() < 0.1:
                    child["bus_num"] = max(1, min(20, child["bus_num"] + random.choice([-1, 1])))
                    child["driver_num"] = max(child["bus_num"], min(20, child["driver_num"] + random.choice([-1, 1])))

                new_population.append(child)

            population = new_population
            generations_without_improvement += 1

            if generations_without_improvement >= patience:
                break

        exec_time = time.time() - start_time_exec
        best_f.write(f"Best Solution: {best_solution}, Execution Time: {exec_time:.2f} seconds\n")

    return best_solution

# %%
best_bus_num, best_driver_num, best_schedule_type = brute_force_optimization(
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
)

print(f"Лучший результат brute-force:")
print(f"Автобусы: {best_bus_num}, Водители: {best_driver_num}, Тип расписания: {best_schedule_type}")
best_solution = genetic_algorithm_optimization(
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    end_time=end_time,
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
    population_size=10,  
    generations=50,  
    patience=10  
)

print(f"Лучший результат генетического алгоритма:")
print(best_solution)
simulation = Simulation(
    bus_num=best_solution["bus_num"],
    route_duration=route_duration,
    bus_stops_num=bus_stops_num,
    start_time=start_time,
    driver_num=best_solution['driver_num'],
    end_time=end_time,
    tag="monday",  # Пример дня для анализа
    driver_schedule_type=best_solution["schedule_type"],
    driver_shift_duration=driver_shift_duration,
    driver_break_duration=driver_break_duration,
)

simulation.play_simulation()
simulation.print_schedule()
with open("results_summary.txt", "w") as f:
    f.write(f"Brute-force: Buses = {best_bus_num}, Drivers = {best_driver_num}, Schedule Type = {best_schedule_type}\n")
    f.write(f"Genetic Algorithm: {best_solution}\n")
# Out:
# Simulation finished. Total passengers dropped: 58390. Remaining passengers: 2898.
# Simulation finished. Total passengers dropped: 58483. Remaining passengers: 2951.
# Simulation finished. Total passengers dropped: 58511. Remaining passengers: 2678.
# Simulation finished. Total passengers dropped: 58226. Remaining passengers: 3045.
# Simulation finished. Total passengers dropped: 58426. Remaining passengers: 2662.
# Simulation finished. Total passengers dropped: 108560. Remaining passengers: 239.
# Simulation finished. Total passengers dropped: 108554. Remaining passengers: 307.
# Simulation finished. Total passengers dropped: 53519. Remaining passengers: 7880.
# Simulation finished. Total passengers dropped: 53093. Remaining passengers: 8527.
# Simulation finished. Total passengers dropped: 53315. Remaining passengers: 8329.
# Simulation finished. Total passengers dropped: 52667. Remaining passengers: 8074.
# Simulation finished. Total passengers dropped: 52823. Remaining passengers: 8038.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21770.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21875.
# Simulation finished. Total passengers dropped: 57973. Remaining passengers: 2956.
# Simulation finished. Total passengers dropped: 58491. Remaining passengers: 2520.
# Simulation finished. Total passengers dropped: 58346. Remaining passengers: 2465.
# Simulation finished. Total passengers dropped: 57868. Remaining passengers: 2906.
# Simulation finished. Total passengers dropped: 58930. Remaining passengers: 2972.
# Simulation finished. Total passengers dropped: 109292. Remaining passengers: 354.
# Simulation finished. Total passengers dropped: 108169. Remaining passengers: 326.
# Simulation finished. Total passengers dropped: 53686. Remaining passengers: 8155.
# Simulation finished. Total passengers dropped: 53383. Remaining passengers: 8283.
# Simulation finished. Total passengers dropped: 52825. Remaining passengers: 7990.
# Simulation finished. Total passengers dropped: 53148. Remaining passengers: 8320.
# Simulation finished. Total passengers dropped: 53160. Remaining passengers: 7835.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21701.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22250.
# Simulation finished. Total passengers dropped: 58924. Remaining passengers: 2496.
# Simulation finished. Total passengers dropped: 58651. Remaining passengers: 2970.
# Simulation finished. Total passengers dropped: 58725. Remaining passengers: 2639.
# Simulation finished. Total passengers dropped: 58267. Remaining passengers: 2409.
# Simulation finished. Total passengers dropped: 58166. Remaining passengers: 2341.
# Simulation finished. Total passengers dropped: 108599. Remaining passengers: 311.
# Simulation finished. Total passengers dropped: 108269. Remaining passengers: 236.
# Simulation finished. Total passengers dropped: 53121. Remaining passengers: 8229.
# Simulation finished. Total passengers dropped: 52759. Remaining passengers: 8463.
# Simulation finished. Total passengers dropped: 52385. Remaining passengers: 8018.
# Simulation finished. Total passengers dropped: 53198. Remaining passengers: 7884.
# Simulation finished. Total passengers dropped: 53042. Remaining passengers: 7948.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22657.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 23351.
# Simulation finished. Total passengers dropped: 58910. Remaining passengers: 2582.
# Simulation finished. Total passengers dropped: 58090. Remaining passengers: 2448.
# Simulation finished. Total passengers dropped: 59298. Remaining passengers: 2585.
# Simulation finished. Total passengers dropped: 59084. Remaining passengers: 2606.
# Simulation finished. Total passengers dropped: 58831. Remaining passengers: 2542.
# Simulation finished. Total passengers dropped: 108766. Remaining passengers: 207.
# Simulation finished. Total passengers dropped: 108437. Remaining passengers: 246.
# Simulation finished. Total passengers dropped: 52568. Remaining passengers: 8394.
# Simulation finished. Total passengers dropped: 52837. Remaining passengers: 8103.
# Simulation finished. Total passengers dropped: 53164. Remaining passengers: 8138.
# Simulation finished. Total passengers dropped: 53330. Remaining passengers: 8353.
# Simulation finished. Total passengers dropped: 52970. Remaining passengers: 8669.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21510.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21862.
# Simulation finished. Total passengers dropped: 58114. Remaining passengers: 2673.
# Simulation finished. Total passengers dropped: 58761. Remaining passengers: 2657.
# Simulation finished. Total passengers dropped: 58814. Remaining passengers: 2576.
# Simulation finished. Total passengers dropped: 58632. Remaining passengers: 2724.
# Simulation finished. Total passengers dropped: 58750. Remaining passengers: 2621.
# Simulation finished. Total passengers dropped: 109411. Remaining passengers: 305.
# Simulation finished. Total passengers dropped: 109012. Remaining passengers: 257.
# Simulation finished. Total passengers dropped: 53037. Remaining passengers: 8070.
# Simulation finished. Total passengers dropped: 53266. Remaining passengers: 8121.
# Simulation finished. Total passengers dropped: 53211. Remaining passengers: 8252.
# Simulation finished. Total passengers dropped: 52909. Remaining passengers: 7825.
# Simulation finished. Total passengers dropped: 53498. Remaining passengers: 7940.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22487.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21998.
# Simulation finished. Total passengers dropped: 58261. Remaining passengers: 2816.
# Simulation finished. Total passengers dropped: 58658. Remaining passengers: 2583.
# Simulation finished. Total passengers dropped: 58723. Remaining passengers: 2812.
# Simulation finished. Total passengers dropped: 58956. Remaining passengers: 2514.
# Simulation finished. Total passengers dropped: 58380. Remaining passengers: 2964.
# Simulation finished. Total passengers dropped: 107907. Remaining passengers: 233.
# Simulation finished. Total passengers dropped: 107488. Remaining passengers: 248.
# Simulation finished. Total passengers dropped: 53482. Remaining passengers: 8503.
# Simulation finished. Total passengers dropped: 53312. Remaining passengers: 8027.
# Simulation finished. Total passengers dropped: 52719. Remaining passengers: 7594.
# Simulation finished. Total passengers dropped: 53360. Remaining passengers: 7895.
# Simulation finished. Total passengers dropped: 53390. Remaining passengers: 8282.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 20485.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22103.
# Simulation finished. Total passengers dropped: 58422. Remaining passengers: 2411.
# Simulation finished. Total passengers dropped: 58329. Remaining passengers: 2479.
# Simulation finished. Total passengers dropped: 58693. Remaining passengers: 2860.
# Simulation finished. Total passengers dropped: 58577. Remaining passengers: 3118.
# Simulation finished. Total passengers dropped: 58214. Remaining passengers: 2519.
# Simulation finished. Total passengers dropped: 107330. Remaining passengers: 270.
# Simulation finished. Total passengers dropped: 108331. Remaining passengers: 291.
# Simulation finished. Total passengers dropped: 53264. Remaining passengers: 8125.
# Simulation finished. Total passengers dropped: 52916. Remaining passengers: 8138.
# Simulation finished. Total passengers dropped: 53100. Remaining passengers: 8039.
# Simulation finished. Total passengers dropped: 53028. Remaining passengers: 7887.
# Simulation finished. Total passengers dropped: 52660. Remaining passengers: 8266.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 23325.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21879.
# Simulation finished. Total passengers dropped: 58450. Remaining passengers: 2791.
# Simulation finished. Total passengers dropped: 58299. Remaining passengers: 2731.
# Simulation finished. Total passengers dropped: 58854. Remaining passengers: 2567.
# Simulation finished. Total passengers dropped: 58570. Remaining passengers: 2680.
# Simulation finished. Total passengers dropped: 58248. Remaining passengers: 2531.
# Simulation finished. Total passengers dropped: 108740. Remaining passengers: 282.
# Simulation finished. Total passengers dropped: 108941. Remaining passengers: 218.
# Simulation finished. Total passengers dropped: 52741. Remaining passengers: 8397.
# Simulation finished. Total passengers dropped: 52581. Remaining passengers: 7867.
# Simulation finished. Total passengers dropped: 52649. Remaining passengers: 8041.
# Simulation finished. Total passengers dropped: 53157. Remaining passengers: 8108.
# Simulation finished. Total passengers dropped: 53233. Remaining passengers: 7772.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22081.
# Simulation finished. Total passengers dropped: 86383. Remaining passengers: 22279.
# Simulation finished. Total passengers dropped: 59014. Remaining passengers: 2605.
# Simulation finished. Total passengers dropped: 58603. Remaining passengers: 2914.
# Simulation finished. Total passengers dropped: 58424. Remaining passengers: 2758.
# Simulation finished. Total passengers dropped: 59054. Remaining passengers: 2310.
# Simulation finished. Total passengers dropped: 58626. Remaining passengers: 3226.
# Simulation finished. Total passengers dropped: 108697. Remaining passengers: 293.
# Simulation finished. Total passengers dropped: 108341. Remaining passengers: 338.
# Simulation finished. Total passengers dropped: 52793. Remaining passengers: 7989.
# Simulation finished. Total passengers dropped: 52775. Remaining passengers: 8227.
# Simulation finished. Total passengers dropped: 52447. Remaining passengers: 7749.
# Simulation finished. Total passengers dropped: 52977. Remaining passengers: 8133.
# Simulation finished. Total passengers dropped: 52958. Remaining passengers: 8480.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22251.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22543.
# Simulation finished. Total passengers dropped: 58397. Remaining passengers: 2616.
# Simulation finished. Total passengers dropped: 58553. Remaining passengers: 2997.
# Simulation finished. Total passengers dropped: 58613. Remaining passengers: 2733.
# Simulation finished. Total passengers dropped: 58637. Remaining passengers: 2561.
# Simulation finished. Total passengers dropped: 59062. Remaining passengers: 2560.
# Simulation finished. Total passengers dropped: 108396. Remaining passengers: 233.
# Simulation finished. Total passengers dropped: 109717. Remaining passengers: 270.
# Simulation finished. Total passengers dropped: 52714. Remaining passengers: 8194.
# Simulation finished. Total passengers dropped: 53262. Remaining passengers: 8093.
# Simulation finished. Total passengers dropped: 53268. Remaining passengers: 8178.
# Simulation finished. Total passengers dropped: 53173. Remaining passengers: 8081.
# Simulation finished. Total passengers dropped: 52977. Remaining passengers: 7941.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21862.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21475.
# Simulation finished. Total passengers dropped: 58445. Remaining passengers: 2686.
# Simulation finished. Total passengers dropped: 58874. Remaining passengers: 2619.
# Simulation finished. Total passengers dropped: 58500. Remaining passengers: 2749.
# Simulation finished. Total passengers dropped: 58546. Remaining passengers: 2819.
# Simulation finished. Total passengers dropped: 58193. Remaining passengers: 2970.
# Simulation finished. Total passengers dropped: 107957. Remaining passengers: 238.
# Simulation finished. Total passengers dropped: 108762. Remaining passengers: 338.
# Simulation finished. Total passengers dropped: 53371. Remaining passengers: 8048.
# Simulation finished. Total passengers dropped: 53065. Remaining passengers: 8425.
# Simulation finished. Total passengers dropped: 52928. Remaining passengers: 8291.
# Simulation finished. Total passengers dropped: 53292. Remaining passengers: 8095.
# Simulation finished. Total passengers dropped: 52964. Remaining passengers: 8307.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22161.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21666.
# Simulation finished. Total passengers dropped: 58543. Remaining passengers: 2715.
# Simulation finished. Total passengers dropped: 58043. Remaining passengers: 2630.
# Simulation finished. Total passengers dropped: 58972. Remaining passengers: 2731.
# Simulation finished. Total passengers dropped: 58770. Remaining passengers: 2366.
# Simulation finished. Total passengers dropped: 58655. Remaining passengers: 2509.
# Simulation finished. Total passengers dropped: 107953. Remaining passengers: 305.
# Simulation finished. Total passengers dropped: 107209. Remaining passengers: 306.
# Simulation finished. Total passengers dropped: 53590. Remaining passengers: 8319.
# Simulation finished. Total passengers dropped: 52618. Remaining passengers: 8133.
# Simulation finished. Total passengers dropped: 53163. Remaining passengers: 7967.
# Simulation finished. Total passengers dropped: 53316. Remaining passengers: 8117.
# Simulation finished. Total passengers dropped: 53258. Remaining passengers: 8143.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22625.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21845.
# Simulation finished. Total passengers dropped: 58318. Remaining passengers: 2558.
# Simulation finished. Total passengers dropped: 58408. Remaining passengers: 2548.
# Simulation finished. Total passengers dropped: 58829. Remaining passengers: 2657.
# Simulation finished. Total passengers dropped: 58194. Remaining passengers: 2512.
# Simulation finished. Total passengers dropped: 58507. Remaining passengers: 2766.
# Simulation finished. Total passengers dropped: 109302. Remaining passengers: 291.
# Simulation finished. Total passengers dropped: 107822. Remaining passengers: 238.
# Simulation finished. Total passengers dropped: 53009. Remaining passengers: 8142.
# Simulation finished. Total passengers dropped: 53182. Remaining passengers: 8259.
# Simulation finished. Total passengers dropped: 52774. Remaining passengers: 8168.
# Simulation finished. Total passengers dropped: 53788. Remaining passengers: 8192.
# Simulation finished. Total passengers dropped: 53128. Remaining passengers: 7970.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 22102.
# Simulation finished. Total passengers dropped: 86400. Remaining passengers: 21686.
# Simulation finished. Total passengers dropped: 60475. Remaining passengers: 1019.
# Simulation finished. Total passengers dropped: 60003. Remaining passengers: 922.
# Simulation finished. Total passengers dropped: 60543. Remaining passengers: 872.
# Simulation finished. Total passengers dropped: 60471. Remaining passengers: 819.
# Simulation finished. Total passengers dropped: 60394. Remaining passengers: 841.
# Simulation finished. Total passengers dropped: 108354. Remaining passengers: 259.
# Simulation finished. Total passengers dropped: 109121. Remaining passengers: 297.
# Simulation finished. Total passengers dropped: 54318. Remaining passengers: 6968.
# Simulation finished. Total passengers dropped: 54313. Remaining passengers: 7026.
# Simulation finished. Total passengers dropped: 53684. Remaining passengers: 7064.
# Simulation finished. Total passengers dropped: 54736. Remaining passengers: 7050.
# Simulation finished. Total passengers dropped: 54516. Remaining passengers: 6953.
# Simulation finished. Total passengers dropped: 96997. Remaining passengers: 11383.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 11700.
# Simulation finished. Total passengers dropped: 60527. Remaining passengers: 546.
# Simulation finished. Total passengers dropped: 60236. Remaining passengers: 873.
# Simulation finished. Total passengers dropped: 60742. Remaining passengers: 694.
# Simulation finished. Total passengers dropped: 60329. Remaining passengers: 722.
# Simulation finished. Total passengers dropped: 60108. Remaining passengers: 758.
# Simulation finished. Total passengers dropped: 108068. Remaining passengers: 246.
# Simulation finished. Total passengers dropped: 107272. Remaining passengers: 272.
# Simulation finished. Total passengers dropped: 54336. Remaining passengers: 7068.
# Simulation finished. Total passengers dropped: 54264. Remaining passengers: 6899.
# Simulation finished. Total passengers dropped: 53889. Remaining passengers: 7189.
# Simulation finished. Total passengers dropped: 54070. Remaining passengers: 6642.
# Simulation finished. Total passengers dropped: 54328. Remaining passengers: 6866.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 11599.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 11397.
# Simulation finished. Total passengers dropped: 60229. Remaining passengers: 346.
# Simulation finished. Total passengers dropped: 60373. Remaining passengers: 797.
# Simulation finished. Total passengers dropped: 60269. Remaining passengers: 929.
# Simulation finished. Total passengers dropped: 60289. Remaining passengers: 994.
# Simulation finished. Total passengers dropped: 60377. Remaining passengers: 838.
# Simulation finished. Total passengers dropped: 109503. Remaining passengers: 192.
# Simulation finished. Total passengers dropped: 106758. Remaining passengers: 238.
# Simulation finished. Total passengers dropped: 55459. Remaining passengers: 6831.
# Simulation finished. Total passengers dropped: 53970. Remaining passengers: 6715.
# Simulation finished. Total passengers dropped: 54019. Remaining passengers: 6690.
# Simulation finished. Total passengers dropped: 53781. Remaining passengers: 6928.
# Simulation finished. Total passengers dropped: 54340. Remaining passengers: 6865.
# Simulation finished. Total passengers dropped: 97114. Remaining passengers: 12193.
# Simulation finished. Total passengers dropped: 97163. Remaining passengers: 12273.
# Simulation finished. Total passengers dropped: 60451. Remaining passengers: 857.
# Simulation finished. Total passengers dropped: 59936. Remaining passengers: 799.
# Simulation finished. Total passengers dropped: 60172. Remaining passengers: 937.
# Simulation finished. Total passengers dropped: 60422. Remaining passengers: 850.
# Simulation finished. Total passengers dropped: 59935. Remaining passengers: 1063.
# Simulation finished. Total passengers dropped: 108045. Remaining passengers: 259.
# Simulation finished. Total passengers dropped: 108674. Remaining passengers: 253.
# Simulation finished. Total passengers dropped: 54587. Remaining passengers: 6605.
# Simulation finished. Total passengers dropped: 54541. Remaining passengers: 6877.
# Simulation finished. Total passengers dropped: 54660. Remaining passengers: 6927.
# Simulation finished. Total passengers dropped: 53694. Remaining passengers: 7114.
# Simulation finished. Total passengers dropped: 53989. Remaining passengers: 6960.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 10819.
# Simulation finished. Total passengers dropped: 97139. Remaining passengers: 11254.
# Simulation finished. Total passengers dropped: 60070. Remaining passengers: 912.
# Simulation finished. Total passengers dropped: 60532. Remaining passengers: 756.
# Simulation finished. Total passengers dropped: 60577. Remaining passengers: 688.
# Simulation finished. Total passengers dropped: 61099. Remaining passengers: 713.
# Simulation finished. Total passengers dropped: 60351. Remaining passengers: 672.
# Simulation finished. Total passengers dropped: 108037. Remaining passengers: 229.
# Simulation finished. Total passengers dropped: 107532. Remaining passengers: 220.
# Simulation finished. Total passengers dropped: 54290. Remaining passengers: 6839.
# Simulation finished. Total passengers dropped: 54182. Remaining passengers: 7012.
# Simulation finished. Total passengers dropped: 54504. Remaining passengers: 6784.
# Simulation finished. Total passengers dropped: 54323. Remaining passengers: 6900.
# Simulation finished. Total passengers dropped: 54108. Remaining passengers: 6691.
# Simulation finished. Total passengers dropped: 96971. Remaining passengers: 11021.
# Simulation finished. Total passengers dropped: 97005. Remaining passengers: 10149.
# Simulation finished. Total passengers dropped: 60524. Remaining passengers: 817.
# Simulation finished. Total passengers dropped: 60478. Remaining passengers: 517.
# Simulation finished. Total passengers dropped: 60256. Remaining passengers: 918.
# Simulation finished. Total passengers dropped: 60329. Remaining passengers: 790.
# Simulation finished. Total passengers dropped: 60813. Remaining passengers: 997.
# Simulation finished. Total passengers dropped: 108862. Remaining passengers: 207.
# Simulation finished. Total passengers dropped: 108677. Remaining passengers: 229.
# Simulation finished. Total passengers dropped: 54512. Remaining passengers: 7101.
# Simulation finished. Total passengers dropped: 54371. Remaining passengers: 7107.
# Simulation finished. Total passengers dropped: 53928. Remaining passengers: 6790.
# Simulation finished. Total passengers dropped: 54107. Remaining passengers: 6879.
# Simulation finished. Total passengers dropped: 54215. Remaining passengers: 6814.
# Simulation finished. Total passengers dropped: 97200. Remaining passengers: 10245.
# Simulation finished. Total passengers dropped: 97165. Remaining passengers: 10678.
# Simulation finished. Total passengers dropped: 60285. Remaining passengers: 901.
# Simulation finished. Total passengers dropped: 60252. Remaining passengers: 1054.
# Simulation finished. Total passengers dropped: 60219. Remaining passengers: 719.
# Simulation finished. Total passengers dropped: 60722. Remaining passengers: 819.
# Simulation finished. Total passengers dropped: 60424. Remaining passengers: 1015.
# Simulation finished. Total passengers dropped: 107810. Remaining passengers: 224.
# Simulation finished. Total passengers dropped: 108151. Remaining passengers: 208.
# Simulation finished. Total passengers dropped: 54435. Remaining passengers: 7162.
# Simulation finished. Total passengers dropped: 54203. Remaining passengers: 6954.
# Simulation finished. Total passengers dropped: 54803. Remaining passengers: 6763.
# Simulation finished. Total passengers dropped: 54014. Remaining passengers: 6866.
# Simulation finished. Total passengers dropped: 54335. Remaining passengers: 6533.
# Simulation finished. Total passengers dropped: 97122. Remaining passengers: 11543.
# Simulation finished. Total passengers dropped: 97165. Remaining passengers: 12157.
# Simulation finished. Total passengers dropped: 60307. Remaining passengers: 915.
# Simulation finished. Total passengers dropped: 59986. Remaining passengers: 581.
# Simulation finished. Total passengers dropped: 60855. Remaining passengers: 607.
# Simulation finished. Total passengers dropped: 59965. Remaining passengers: 679.
# Simulation finished. Total passengers dropped: 60142. Remaining passengers: 863.
# Simulation finished. Total passengers dropped: 108252. Remaining passengers: 226.
# Simulation finished. Total passengers dropped: 108210. Remaining passengers: 299.
# Simulation finished. Total passengers dropped: 53914. Remaining passengers: 6999.
# Simulation finished. Total passengers dropped: 54532. Remaining passengers: 7354.
# Simulation finished. Total passengers dropped: 54581. Remaining passengers: 6632.
# Simulation finished. Total passengers dropped: 54499. Remaining passengers: 6962.
# Simulation finished. Total passengers dropped: 54237. Remaining passengers: 6782.
# Simulation finished. Total passengers dropped: 97187. Remaining passengers: 11362.
# Simulation finished. Total passengers dropped: 97080. Remaining passengers: 10663.
# Simulation finished. Total passengers dropped: 60560. Remaining passengers: 713.
# Simulation finished. Total passengers dropped: 60148. Remaining passengers: 1007.
# Simulation finished. Total passengers dropped: 60507. Remaining passengers: 727.
# Simulation finished. Total passengers dropped: 60507. Remaining passengers: 761.
# Simulation finished. Total passengers dropped: 60589. Remaining passengers: 576.
# Simulation finished. Total passengers dropped: 107806. Remaining passengers: 281.
# Simulation finished. Total passengers dropped: 108013. Remaining passengers: 305.
# Simulation finished. Total passengers dropped: 54099. Remaining passengers: 6840.
# Simulation finished. Total passengers dropped: 54761. Remaining passengers: 7011.
# Simulation finished. Total passengers dropped: 54161. Remaining passengers: 6676.
# Simulation finished. Total passengers dropped: 54142. Remaining passengers: 7003.
# Simulation finished. Total passengers dropped: 54302. Remaining passengers: 6690.
# Simulation finished. Total passengers dropped: 96981. Remaining passengers: 11263.
# Simulation finished. Total passengers dropped: 97157. Remaining passengers: 10480.
# Simulation finished. Total passengers dropped: 60209. Remaining passengers: 1041.
# Simulation finished. Total passengers dropped: 60668. Remaining passengers: 1091.
# Simulation finished. Total passengers dropped: 60244. Remaining passengers: 1083.
# Simulation finished. Total passengers dropped: 60226. Remaining passengers: 706.
# Simulation finished. Total passengers dropped: 60097. Remaining passengers: 882.
# Simulation finished. Total passengers dropped: 108485. Remaining passengers: 256.
# Simulation finished. Total passengers dropped: 108685. Remaining passengers: 227.
# Simulation finished. Total passengers dropped: 54349. Remaining passengers: 7130.
# Simulation finished. Total passengers dropped: 54321. Remaining passengers: 6607.
# Simulation finished. Total passengers dropped: 54746. Remaining passengers: 7284.
# Simulation finished. Total passengers dropped: 54319. Remaining passengers: 6702.
# Simulation finished. Total passengers dropped: 54270. Remaining passengers: 7037.
# Simulation finished. Total passengers dropped: 97106. Remaining passengers: 11630.
# Simulation finished. Total passengers dropped: 97146. Remaining passengers: 10412.
# Simulation finished. Total passengers dropped: 60129. Remaining passengers: 858.
# Simulation finished. Total passengers dropped: 60435. Remaining passengers: 917.
# Simulation finished. Total passengers dropped: 60613. Remaining passengers: 1073.
# Simulation finished. Total passengers dropped: 60317. Remaining passengers: 765.
# Simulation finished. Total passengers dropped: 60539. Remaining passengers: 507.
# Simulation finished. Total passengers dropped: 108700. Remaining passengers: 235.
# Simulation finished. Total passengers dropped: 107656. Remaining passengers: 233.
# Simulation finished. Total passengers dropped: 54319. Remaining passengers: 6878.
# Simulation finished. Total passengers dropped: 54681. Remaining passengers: 6703.
# Simulation finished. Total passengers dropped: 54325. Remaining passengers: 6960.
# Simulation finished. Total passengers dropped: 54088. Remaining passengers: 6799.
# Simulation finished. Total passengers dropped: 54613. Remaining passengers: 6656.
# Simulation finished. Total passengers dropped: 97031. Remaining passengers: 10867.
# Simulation finished. Total passengers dropped: 97099. Remaining passengers: 11429.
# Simulation finished. Total passengers dropped: 59897. Remaining passengers: 873.
# Simulation finished. Total passengers dropped: 60820. Remaining passengers: 815.
# Simulation finished. Total passengers dropped: 60186. Remaining passengers: 600.
# Simulation finished. Total passengers dropped: 60400. Remaining passengers: 878.
# Simulation finished. Total passengers dropped: 60681. Remaining passengers: 1123.
# Simulation finished. Total passengers dropped: 108340. Remaining passengers: 253.
# Simulation finished. Total passengers dropped: 108762. Remaining passengers: 254.
# Simulation finished. Total passengers dropped: 53802. Remaining passengers: 6924.
# Simulation finished. Total passengers dropped: 54364. Remaining passengers: 7151.
# Simulation finished. Total passengers dropped: 53993. Remaining passengers: 6635.
# Simulation finished. Total passengers dropped: 54425. Remaining passengers: 7249.
# Simulation finished. Total passengers dropped: 54228. Remaining passengers: 7122.
# Simulation finished. Total passengers dropped: 97063. Remaining passengers: 10899.
# Simulation finished. Total passengers dropped: 97179. Remaining passengers: 10347.
# Simulation finished. Total passengers dropped: 61110. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61706. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 61501. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60708. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 60845. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 107661. Remaining passengers: 145.
# Simulation finished. Total passengers dropped: 108405. Remaining passengers: 134.
# Simulation finished. Total passengers dropped: 55030. Remaining passengers: 6137.
# Simulation finished. Total passengers dropped: 56105. Remaining passengers: 5331.
# Simulation finished. Total passengers dropped: 55545. Remaining passengers: 5494.
# Simulation finished. Total passengers dropped: 55525. Remaining passengers: 5573.
# Simulation finished. Total passengers dropped: 55839. Remaining passengers: 5771.
# Simulation finished. Total passengers dropped: 106878. Remaining passengers: 182.
# Simulation finished. Total passengers dropped: 107500. Remaining passengers: 508.
# Simulation finished. Total passengers dropped: 61319. Remaining passengers: 1.
# Simulation finished. Total passengers dropped: 61057. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61050. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 61192. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61379. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 108076. Remaining passengers: 148.
# Simulation finished. Total passengers dropped: 107925. Remaining passengers: 172.
# Simulation finished. Total passengers dropped: 55657. Remaining passengers: 5295.
# Simulation finished. Total passengers dropped: 55697. Remaining passengers: 5595.
# Simulation finished. Total passengers dropped: 54984. Remaining passengers: 5462.
# Simulation finished. Total passengers dropped: 55369. Remaining passengers: 5715.
# Simulation finished. Total passengers dropped: 55948. Remaining passengers: 5464.
# Simulation finished. Total passengers dropped: 107414. Remaining passengers: 637.
# Simulation finished. Total passengers dropped: 107072. Remaining passengers: 1636.
# Simulation finished. Total passengers dropped: 61229. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 60905. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 60748. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 61297. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61415. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 108523. Remaining passengers: 130.
# Simulation finished. Total passengers dropped: 108480. Remaining passengers: 174.
# Simulation finished. Total passengers dropped: 55390. Remaining passengers: 5702.
# Simulation finished. Total passengers dropped: 55590. Remaining passengers: 5325.
# Simulation finished. Total passengers dropped: 55766. Remaining passengers: 5366.
# Simulation finished. Total passengers dropped: 55412. Remaining passengers: 5519.
# Simulation finished. Total passengers dropped: 54888. Remaining passengers: 5313.
# Simulation finished. Total passengers dropped: 107498. Remaining passengers: 513.
# Simulation finished. Total passengers dropped: 107337. Remaining passengers: 178.
# Simulation finished. Total passengers dropped: 61518. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61361. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61786. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61490. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 60671. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 108138. Remaining passengers: 165.
# Simulation finished. Total passengers dropped: 107979. Remaining passengers: 193.
# Simulation finished. Total passengers dropped: 55345. Remaining passengers: 5241.
# Simulation finished. Total passengers dropped: 55745. Remaining passengers: 5353.
# Simulation finished. Total passengers dropped: 55971. Remaining passengers: 5713.
# Simulation finished. Total passengers dropped: 55661. Remaining passengers: 5608.
# Simulation finished. Total passengers dropped: 55905. Remaining passengers: 5360.
# Simulation finished. Total passengers dropped: 107723. Remaining passengers: 820.
# Simulation finished. Total passengers dropped: 107126. Remaining passengers: 197.
# Simulation finished. Total passengers dropped: 61267. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61782. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61670. Remaining passengers: 9.
# Simulation finished. Total passengers dropped: 61135. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61228. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 108387. Remaining passengers: 163.
# Simulation finished. Total passengers dropped: 107912. Remaining passengers: 170.
# Simulation finished. Total passengers dropped: 55367. Remaining passengers: 5566.
# Simulation finished. Total passengers dropped: 55285. Remaining passengers: 5439.
# Simulation finished. Total passengers dropped: 56132. Remaining passengers: 5502.
# Simulation finished. Total passengers dropped: 55755. Remaining passengers: 5948.
# Simulation finished. Total passengers dropped: 55949. Remaining passengers: 5739.
# Simulation finished. Total passengers dropped: 107271. Remaining passengers: 1173.
# Simulation finished. Total passengers dropped: 106777. Remaining passengers: 733.
# Simulation finished. Total passengers dropped: 61322. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 61349. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61500. Remaining passengers: 7.
# Simulation finished. Total passengers dropped: 60927. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 60700. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 109229. Remaining passengers: 138.
# Simulation finished. Total passengers dropped: 109378. Remaining passengers: 133.
# Simulation finished. Total passengers dropped: 55336. Remaining passengers: 5653.
# Simulation finished. Total passengers dropped: 55281. Remaining passengers: 5552.
# Simulation finished. Total passengers dropped: 55166. Remaining passengers: 5552.
# Simulation finished. Total passengers dropped: 56038. Remaining passengers: 5571.
# Simulation finished. Total passengers dropped: 55903. Remaining passengers: 5579.
# Simulation finished. Total passengers dropped: 107867. Remaining passengers: 1040.
# Simulation finished. Total passengers dropped: 107790. Remaining passengers: 2515.
# Simulation finished. Total passengers dropped: 60930. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 61373. Remaining passengers: 11.
# Simulation finished. Total passengers dropped: 60984. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61394. Remaining passengers: 6.
# Simulation finished. Total passengers dropped: 60292. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 107058. Remaining passengers: 144.
# Simulation finished. Total passengers dropped: 108309. Remaining passengers: 143.
# Simulation finished. Total passengers dropped: 55157. Remaining passengers: 5672.
# Simulation finished. Total passengers dropped: 55314. Remaining passengers: 5818.
# Simulation finished. Total passengers dropped: 55396. Remaining passengers: 5719.
# Simulation finished. Total passengers dropped: 55647. Remaining passengers: 5645.
# Simulation finished. Total passengers dropped: 55280. Remaining passengers: 5124.
# Simulation finished. Total passengers dropped: 107766. Remaining passengers: 1227.
# Simulation finished. Total passengers dropped: 107335. Remaining passengers: 1256.
# Simulation finished. Total passengers dropped: 61410. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 61384. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 60936. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61410. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 60841. Remaining passengers: 10.
# Simulation finished. Total passengers dropped: 107829. Remaining passengers: 163.
# Simulation finished. Total passengers dropped: 108582. Remaining passengers: 169.
# Simulation finished. Total passengers dropped: 56389. Remaining passengers: 5465.
# Simulation finished. Total passengers dropped: 55343. Remaining passengers: 5491.
# Simulation finished. Total passengers dropped: 55569. Remaining passengers: 5816.
# Simulation finished. Total passengers dropped: 55316. Remaining passengers: 5782.
# Simulation finished. Total passengers dropped: 55208. Remaining passengers: 5731.
# Simulation finished. Total passengers dropped: 107822. Remaining passengers: 1968.
# Simulation finished. Total passengers dropped: 107431. Remaining passengers: 1688.
# Simulation finished. Total passengers dropped: 60998. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 60475. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61721. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61039. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 61122. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 108267. Remaining passengers: 212.
# Simulation finished. Total passengers dropped: 108196. Remaining passengers: 185.
# Simulation finished. Total passengers dropped: 55868. Remaining passengers: 5746.
# Simulation finished. Total passengers dropped: 56079. Remaining passengers: 5653.
# Simulation finished. Total passengers dropped: 55498. Remaining passengers: 5779.
# Simulation finished. Total passengers dropped: 55793. Remaining passengers: 5486.
# Simulation finished. Total passengers dropped: 55559. Remaining passengers: 5464.
# Simulation finished. Total passengers dropped: 107546. Remaining passengers: 957.
# Simulation finished. Total passengers dropped: 107901. Remaining passengers: 1232.
# Simulation finished. Total passengers dropped: 60904. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61715. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61420. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60805. Remaining passengers: 28.
# Simulation finished. Total passengers dropped: 61530. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 108031. Remaining passengers: 182.
# Simulation finished. Total passengers dropped: 109394. Remaining passengers: 127.
# Simulation finished. Total passengers dropped: 56055. Remaining passengers: 5269.
# Simulation finished. Total passengers dropped: 55956. Remaining passengers: 5655.
# Simulation finished. Total passengers dropped: 55724. Remaining passengers: 5744.
# Simulation finished. Total passengers dropped: 55514. Remaining passengers: 5920.
# Simulation finished. Total passengers dropped: 55361. Remaining passengers: 5540.
# Simulation finished. Total passengers dropped: 107495. Remaining passengers: 986.
# Simulation finished. Total passengers dropped: 107609. Remaining passengers: 818.
# Simulation finished. Total passengers dropped: 61135. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 61196. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61294. Remaining passengers: 18.
# Simulation finished. Total passengers dropped: 61780. Remaining passengers: 5.
# Simulation finished. Total passengers dropped: 61277. Remaining passengers: 19.
# Simulation finished. Total passengers dropped: 107832. Remaining passengers: 140.
# Simulation finished. Total passengers dropped: 108321. Remaining passengers: 159.
# Simulation finished. Total passengers dropped: 55608. Remaining passengers: 5403.
# Simulation finished. Total passengers dropped: 56306. Remaining passengers: 5457.
# Simulation finished. Total passengers dropped: 55747. Remaining passengers: 5632.
# Simulation finished. Total passengers dropped: 55778. Remaining passengers: 5938.
# Simulation finished. Total passengers dropped: 55930. Remaining passengers: 5520.
# Simulation finished. Total passengers dropped: 107030. Remaining passengers: 204.
# Simulation finished. Total passengers dropped: 107767. Remaining passengers: 651.
# Simulation finished. Total passengers dropped: 61478. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61285. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 60776. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 61280. Remaining passengers: 40.
# Simulation finished. Total passengers dropped: 61558. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 108601. Remaining passengers: 147.
# Simulation finished. Total passengers dropped: 108693. Remaining passengers: 138.
# Simulation finished. Total passengers dropped: 56504. Remaining passengers: 4581.
# Simulation finished. Total passengers dropped: 56338. Remaining passengers: 4373.
# Simulation finished. Total passengers dropped: 56864. Remaining passengers: 4293.
# Simulation finished. Total passengers dropped: 57080. Remaining passengers: 4173.
# Simulation finished. Total passengers dropped: 57308. Remaining passengers: 4784.
# Simulation finished. Total passengers dropped: 108233. Remaining passengers: 189.
# Simulation finished. Total passengers dropped: 108386. Remaining passengers: 137.
# Simulation finished. Total passengers dropped: 61475. Remaining passengers: 23.
# Simulation finished. Total passengers dropped: 61130. Remaining passengers: 22.
# Simulation finished. Total passengers dropped: 60683. Remaining passengers: 24.
# Simulation finished. Total passengers dropped: 61695. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 61476. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 108087. Remaining passengers: 177.
# Simulation finished. Total passengers dropped: 108867. Remaining passengers: 211.
# Simulation finished. Total passengers dropped: 56878. Remaining passengers: 4541.
# Simulation finished. Total passengers dropped: 57196. Remaining passengers: 4384.
# Simulation finished. Total passengers dropped: 57153. Remaining passengers: 4227.
# Simulation finished. Total passengers dropped: 56374. Remaining passengers: 4537.
# Simulation finished. Total passengers dropped: 57140. Remaining passengers: 4545.
# Simulation finished. Total passengers dropped: 108925. Remaining passengers: 242.
# Simulation finished. Total passengers dropped: 108312. Remaining passengers: 209.
# Simulation finished. Total passengers dropped: 62081. Remaining passengers: 12.
# Simulation finished. Total passengers dropped: 61204. Remaining passengers: 8.
# Simulation finished. Total passengers dropped: 61082. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 61092. Remaining passengers: 17.
# Simulation finished. Total passengers dropped: 60713. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 109097. Remaining passengers: 207.
# Simulation finished. Total passengers dropped: 108570. Remaining passengers: 205.
# Simulation finished. Total passengers dropped: 56652. Remaining passengers: 4217.
# Simulation finished. Total passengers dropped: 56531. Remaining passengers: 4406.
# Simulation finished. Total passengers dropped: 57268. Remaining passengers: 4122.
# Simulation finished. Total passengers dropped: 56658. Remaining passengers: 4271.
# Simulation finished. Total passengers dropped: 56973. Remaining passengers: 4453.
# Simulation finished. Total passengers dropped: 108099. Remaining passengers: 139.
# Simulation finished. Total passengers dropped: 108480. Remaining passengers: 210.
# Simulation finished. Total passengers dropped: 61265. Remaining passengers: 33.
# Simulation finished. Total passengers dropped: 61093. Remaining passengers: 13.
# Simulation finished. Total passengers dropped: 61132. Remaining passengers: 20.
# Simulation finished. Total passengers dropped: 60970. Remaining passengers: 21.
# Simulation finished. Total passengers dropped: 61306. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 107937. Remaining passengers: 126.
# Simulation finished. Total passengers dropped: 108755. Remaining passengers: 97.
# Simulation finished. Total passengers dropped: 56443. Remaining passengers: 4424.
# Simulation finished. Total passengers dropped: 56826. Remaining passengers: 4379.
# Simulation finished. Total passengers dropped: 56626. Remaining passengers: 4017.
# Simulation finished. Total passengers dropped: 56666. Remaining passengers: 4462.
# Simulation finished. Total passengers dropped: 57097. Remaining passengers: 4360.
# Simulation finished. Total passengers dropped: 107958. Remaining passengers: 152.
# Simulation finished. Total passengers dropped: 107085. Remaining passengers: 188.
# Simulation finished. Total passengers dropped: 61517. Remaining passengers: 26.
# Simulation finished. Total passengers dropped: 61419. Remaining passengers: 25.
# Simulation finished. Total passengers dropped: 61390. Remaining passengers: 14.
# Simulation finished. Total passengers dropped: 61554. Remaining passengers: 15.
# Simulation finished. Total passengers dropped: 60951. Remaining passengers: 16.
# Simulation finished. Total passengers dropped: 108719. Remaining passengers: 210.
# Simulation finished. Total passengers dropped: 108236. Remaining passengers: 235.
# Simulation finished. Total passengers dropped: 56597. Remaining passengers: 4393.
# Simulation finished. Total passengers dropped: 57009. Remaining passengers: 4157.
# Simulation finished. Total passengers dropped: 56817. Remaining passengers: 4486.
# Simulation finished. Total passengers dropped: 57404. Remaining passengers: 4216.
# Simulation finished. Total passengers dropped: 56465. Remaining passengers: 4548.
# Simulation finished. Total passengers dropped: 107794. Remaining passengers: 160.
# Simulation finished. Total passengers dropped: 107159. Remaining passengers: 202.
# Simulation finished. Total passengers dropped: 61146. Remaining passengers: 25.
# Simulation finished. Total passengers dropped:
 2024-12-15T12:10, 2024-12-15T12:10, 2024-12-15T12:20, 2024-12-15T12:20, 2024-12-15T12:20, 2024-12-15T12:30, 2024-12-15T12:30, 2024-12-15T12:40, 2024-12-15T12:40, 2024-12-15T12:50, 2024-12-15T12:50, 2024-12-15T13:00, 2024-12-15T13:00, 2024-12-15T13:10, 2024-12-15T13:10, 2024-12-15T13:20, 2024-12-15T13:20, 2024-12-15T13:30, 2024-12-15T13:30, 2024-12-15T13:40, 2024-12-15T13: ...

# %%
import pandas as pd

def generate_schedule_tables(simulation, is_weekday=True):
    day_type = "Weekday" if is_weekday else "Weekend"
    schedule_tables = {}
    
    for stop, times in simulation.schedule.items():
        filtered_times = []
        for time in times:
            time_obj = pd.Timestamp(time)
            hour = time_obj.hour
            if (6 <= hour < 24) or (hour < 3):  # Рабочие часы: с 6 утра до 3 ночи
                filtered_times.append(time_obj.strftime("%H:%M"))
        
        # Удаляем дубликаты и сортируем
        unique_times = sorted(set(filtered_times))

        # Создаем DataFrame для расписания
        df = pd.DataFrame({"Time": unique_times})
        schedule_tables[f"Stop {stop} ({day_type})"] = df

    return schedule_tables


def save_schedule_to_file(schedule_tables, filename_prefix):
    for stop, table in schedule_tables.items():
        filename = f"{filename_prefix}_{stop.replace(' ', '_').replace('(', '').replace(')', '')}.csv"
        table.to_csv(filename, index=False, encoding="utf-8")
        print(f"Saved {stop} schedule to file: {filename}")

def decide(best_bus_num_g, best_driver_num_g, best_schedule_g, best_bus_num_b, best_driver_num_b, best_schedule_b):
    g = best_bus_num_g < best_bus_num_b + best_driver_num_g < best_bus_num_b
    if g>1:
        return best_bus_num_g,best_driver_num_g,best_schedule_g
    else:
        return best_bus_num_b, best_driver_num_b, best_schedule_b
    
bus_num, driver_num, schedule = decide(best_solution['bus_num'],best_solution['driver_num'], best_solution['schedule_type'], best_bus_num,best_driver_num,best_schedule_type)
print(bus_num,driver_num,schedule)
simulation = Simulation(
    bus_num=bus_num,  # Примерное количество автобусов
    route_duration=70,
    bus_stops_num=7,
    start_time=np.datetime64("2024-12-18T06:00"),
    end_time=np.datetime64("2024-12-18T23:00"),
    tag="monday",  # Пример буднего дня
    driver_schedule_type=schedule,
    driver_shift_duration=420,
    driver_break_duration=60,
    driver_num = driver_num
)
simulation.play_simulation()
simulation.print_schedule()
weekday_tables = generate_schedule_tables(simulation, is_weekday=True)
save_schedule_to_file(weekday_tables, filename_prefix="weekday_schedule")


weekend_tables = generate_schedule_tables(simulation, is_weekday=False)
save_schedule_to_file(weekend_tables, filename_prefix="weekend_schedule")
# Out:
# 14 16 standard
# Simulation finished. Total passengers dropped: 40813. Remaining passengers: 0.
#
# Bus Schedule:
# Stop 0: 2024-12-18T06:00, 2024-12-18T06:50, 2024-12-18T07:10, 2024-12-18T07:40, 2024-12-18T08:00, 2024-12-18T08:20, 2024-12-18T08:30, 2024-12-18T08:50, 2024-12-18T09:10, 2024-12-18T09:20, 2024-12-18T09:30, 2024-12-18T09:40, 2024-12-18T10:00, 2024-12-18T10:10, 2024-12-18T10:20, 2024-12-18T10:30, 2024-12-18T10:40, 2024-12-18T10:50, 2024-12-18T11:00, 2024-12-18T11:10, 2024-12-18T11:20, 2024-12-18T11:30, 2024-12-18T11:40, 2024-12-18T11:50, 2024-12-18T11:50, 2024-12-18T12:00, 2024-12-18T12:10, 2024-12-18T12:20, 2024-12-18T12:30, 2024-12-18T12:40, 2024-12-18T12:40, 2024-12-18T12:50, 2024-12-18T13:00, 2024-12-18T13:00, 2024-12-18T13:10, 2024-12-18T13:20, 2024-12-18T13:30, 2024-12-18T13:30, 2024-12-18T13:40, 2024-12-18T13:50, 2024-12-18T13:50, 2024-12-18T14:00, 2024-12-18T14:10, 2024-12-18T14:10, 2024-12-18T14:20, 2024-12-18T14:20, 2024-12-18T14:30, 2024-12-18T14:40, 2024-12-18T14:40, 2024-12-18T14:50, 2024-12-18T15:00, 2024-12-18T15:00, 2024-12-18T15:10, 2024-12-18T15:10, 2024-12-18T15:20, 2024-12-18T15:20, 2024-12-18T15:30, 2024-12-18T15:30, 2024-12-18T15:40, 2024-12-18T15:50, 2024-12-18T15:50, 2024-12-18T16:00, 2024-12-18T16:00, 2024-12-18T16:10, 2024-12-18T16:10, 2024-12-18T16:20, 2024-12-18T16:20, 2024-12-18T16:30, 2024-12-18T16:30, 2024-12-18T16:40, 2024-12-18T16:40, 2024-12-18T16:50, 2024-12-18T16:50, 2024-12-18T17:00, 2024-12-18T17:00, 2024-12-18T17:10, 2024-12-18T17:10, 2024-12-18T17:20, 2024-12-18T17:20, 2024-12-18T17:30, 2024-12-18T17:30, 2024-12-18T17:40, 2024-12-18T17:40, 2024-12-18T17:50, 2024-12-18T17:50, 2024-12-18T18:00, 2024-12-18T18:00, 2024-12-18T18:10, 2024-12-18T18:10, 2024-12-18T18:20, 2024-12-18T18:20, 2024-12-18T18:30, 2024-12-18T18:30, 2024-12-18T18:40, 2024-12-18T18:40, 2024-12-18T18:50, 2024-12-18T18:50, 2024-12-18T19:00, 2024-12-18T19:00, 2024-12-18T19:10, 2024-12-18T19:10, 2024-12-18T19:20, 2024-12-18T19:20, 2024-12-18T19:30, 2024-12-18T19:30, 2024-12-18T19:40, 2024-12-18T19:40, 2024-12-18T19:50, 2024-12-18T19:50, 2024-12-18T20:00, 2024-12-18T20:00, 2024-12-18T20:10, 2024-12-18T20:10, 2024-12-18T20:20, 2024-12-18T20:20, 2024-12-18T20:30, 2024-12-18T20:30, 2024-12-18T20:40, 2024-12-18T20:40, 2024-12-18T20:50, 2024-12-18T20:50, 2024-12-18T21:00, 2024-12-18T21:00, 2024-12-18T21:10, 2024-12-18T21:10, 2024-12-18T21:20, 2024-12-18T21:20, 2024-12-18T21:30, 2024-12-18T21:30, 2024-12-18T21:40, 2024-12-18T21:40, 2024-12-18T21:50, 2024-12-18T21:50, 2024-12-18T22:00, 2024-12-18T22:00, 2024-12-18T22:10, 2024-12-18T22:10, 2024-12-18T22:20, 2024-12-18T22:20, 2024-12-18T22:30, 2024-12-18T22:30, 2024-12-18T22:40, 2024-12-18T22:40, 2024-12-18T22:50, 2024-12-18T22:50, 2024-12-18T23:00, 2024-12-18T23:00, 2024-12-18T23:10, 2024-12-18T23:10, 2024-12-18T23:20, 2024-12-18T23:20, 2024-12-18T23:30, 2024-12-18T23:30, 2024-12-18T23:40, 2024-12-18T23:40, 2024-12-18T23:50, 2024-12-18T23:50, 2024-12-19T00:00, 2024-12-19T00:00, 2024-12-19T00:10, 2024-12-19T00:10, 2024-12-19T00:20, 2024-12-19T00:20, 2024-12-19T00:30, 2024-12-19T00:30, 2024-12-19T00:40, 2024-12-19T00:40, 2024-12-19T00:50, 2024-12-19T00:50, 2024-12-19T01:00, 2024-12-19T01:00, 2024-12-19T01:10, 2024-12-19T01:10, 2024-12-19T01:20, 2024-12-19T01:20, 2024-12-19T01:30, 2024-12-19T01:30, 2024-12-19T01:40, 2024-12-19T01:40, 2024-12-19T01:50, 2024-12-19T01:50, 2024-12-19T02:00, 2024-12-19T02:00, 2024-12-19T02:10, 2024-12-19T02:10, 2024-12-19T02:20, 2024-12-19T02:20, 2024-12-19T02:30, 2024-12-19T02:30, 2024-12-19T02:40, 2024-12-19T02:40, 2024-12-19T02:50, 2024-12-19T02:50, 2024-12-19T03:00, 2024-12-19T03:00, 2024-12-19T03:10, 2024-12-19T03:10, 2024-12-19T03:20, 2024-12-19T03:20, 2024-12-19T03:30, 2024-12-19T03:30, 2024-12-19T03:40, 2024-12-19T03:40, 2024-12-19T03:50, 2024-12-19T03:50, 2024-12-19T04:00, 2024-12-19T04:00, 2024-12-19T04:10, 2024-12-19T04:10, 2024-12-19T04:20, 2024-12-19T04:20, 2024-12-19T04:30, 2024-12-19T04:30, 2024-12-19T04:40, 2024-12-19T04:40, 2024-12-19T04:50, 2024-12-19T04:50, 2024-12-19T05:00, 2024-12-19T05:00, 2024-12-19T05:10, 2024-12-19T05:10, 2024-12-19T